# %%
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report
from minisom import MiniSom
import numpy as np
import time
import matplotlib.pyplot as plt
from joblib import Parallel, delayed
import warnings
import tracemalloc
from collections import Counter

# %%
# Funzione per convertire l'uso della memoria in unità appropriate
def format_memory_usage(mem_usage):
    if mem_usage >= 1024 ** 3:
        return f"{mem_usage / (1024 ** 3):.2f} GB"
    else:
        return f"{mem_usage / (1024 ** 2):.2f} MB"

# Funzione per classificare i dati utilizzando il SOM
def classify2(som, data, training_data, training_labels):
    winmap = som.labels_map(training_data, training_labels)
    default_class = Counter(training_labels).most_common(1)[0][0]
    result = []
    for sample in data:
        winner = som.winner(sample)
        if winner in winmap:
            result.append(winmap[winner].most_common(1)[0][0])
        else:
            result.append(default_class)
    return result

# Funzione per monitorare l'uso della memoria durante una funzione
def monitor_memory_usage(func, *args, **kwargs):
    tracemalloc.start()
    result = func(*args, **kwargs)
    current, peak = tracemalloc.get_traced_memory()
    tracemalloc.stop()
    return result, peak

# Funzione per il training e l'evaluation con monitoraggio della memoria
def train_and_evaluate(train_idx, test_idx, X, y, som_shape, sigma, learning_rate):
    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    som = MiniSom(som_shape[0], som_shape[1], X_train.shape[1], sigma=sigma, learning_rate=learning_rate)

    start_train = time.time()
    _, training_mem_usage = monitor_memory_usage(som.train_random, X_train, X_train.shape[0])
    end_train = time.time()

    start_eval = time.time()
    y_pred, eval_mem_usage = monitor_memory_usage(classify2, som, X_test, X_train, y_train)
    end_eval = time.time()

    report = classification_report(y_test, y_pred, digits=4, output_dict=True, zero_division=0)

    training_time = end_train - start_train
    evaluating_time = end_eval - start_eval
    total_mem_usage = training_mem_usage + eval_mem_usage

    return report, training_time, training_mem_usage, evaluating_time, eval_mem_usage, total_mem_usage

# %%
# Inizializzazione del dataset e dei parametri
DATA_PATH = "/users/mik2002/som/dataset-processed CIC-IDS-2018/"
FILES = ["processed_bot_dataset.csv", "processed_dos_dataset.csv","processed_Ddos_dataset.csv", "processed_bruteforce_dataset.csv"]
df_dataset = pd.concat([pd.read_csv(DATA_PATH + file) for file in FILES], ignore_index=True)

display(df_dataset["Label"].value_counts())
print("Distribution:")
display(df_dataset["Label"].value_counts(normalize=True))
# Out:
# Label
# Benign        4961029
# DDos           576191
# Dos            507715
# Bot            282310
# Bruteforce     156668
# Name: count, dtype: int64
# Distribution:
# Label
# Benign        0.765129
# DDos          0.088865
# Dos           0.078304
# Bot           0.043540
# Bruteforce    0.024163
# Name: proportion, dtype: float64

# %%
# Parametri per le SOM
som_sizes = [(10, 10),(20, 20),(30,30)]
learning_rate = 1.2
sigma = 1.5
sampling_fractions = [0.01, 0.03]  # Diversi frazioni di campionamento
results = []

# %%
# Wrapper function for parallelism
def parallel_train_and_evaluate(train_idx, test_idx, som_shape, data, target, sigma, learning_rate):
    report, training_time, training_mem_usage, evaluating_time, eval_mem_usage, total_mem_usage = train_and_evaluate(train_idx, test_idx, data, target, som_shape, sigma, learning_rate)
    return report, training_time, training_mem_usage, evaluating_time, eval_mem_usage, total_mem_usage

def display_report_and_times(all_reports, all_training_times, all_training_mem_usages, all_evaluating_times, all_eval_mem_usages, all_total_mem_usages):
    print("\nAll Reports and Times for this SOM Shape:")
    
    for i, (report, train_time, train_mem_usage, eval_time, eval_mem_usage, total_mem_usage) in enumerate(zip(all_reports, all_training_times, all_training_mem_usages, all_evaluating_times, all_eval_mem_usages, all_total_mem_usages)):
        print(f"\nReport for Fold {i+1}:")
        for label, metrics in report.items():
            if isinstance(metrics, dict):
                print(f"\nLabel {label}:")
                for metric_name, metric_value in metrics.items():
                    print(f"  {metric_name.capitalize()}: {metric_value:.4f}")
            else:
                print(f"\n{label.capitalize()}: {metrics:.4f}")
        print(f"\nTraining Time: {train_time:.4f} seconds")
        print(f"Training Memory Usage: {format_memory_usage(train_mem_usage)}")
        print(f"Evaluating Time: {eval_time:.4f} seconds")
        print(f"Evaluating Memory Usage: {format_memory_usage(eval_mem_usage)}")
        print(f"Total Memory Usage: {format_memory_usage(total_mem_usage)}")

# KFold initialization
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# Loop over different sampling fractions
for frac in sampling_fractions:
    print(f"Evaluating for sampling fraction: {frac}")
    
    # Perform stratified random sampling maintaining class proportions
    with warnings.catch_warnings():
        warnings.simplefilter("ignore", DeprecationWarning)
        sampled_df = df_dataset.groupby("Label", group_keys=False).apply(lambda x: x.sample(frac=frac, random_state=42))
    sampled_df["Label"] = sampled_df["Label"].map({"Benign": 0, "DDos": 1, "Dos": 2, "Bot": 3, "Bruteforce": 4})

    scaler = MinMaxScaler()
    data = scaler.fit_transform(sampled_df.iloc[:, :-1])
    target = sampled_df.iloc[:, -1].values

    # Loop over different SOM sizes
    for som_shape in som_sizes:
        print(f"Evaluating for som_shape: {som_shape}")
        # Split dataset with K-Fold and parallelism
        parallel_results = Parallel(n_jobs=-1)(delayed(parallel_train_and_evaluate)(train_idx, test_idx, som_shape, data, target, sigma, learning_rate) for train_idx, test_idx in kf.split(data))
        
        reports, training_times, training_mem_usages, evaluating_times, eval_mem_usages, total_mem_usages = zip(*parallel_results)
        
        # Aggregate metrics from reports
        class_metrics = {}
        for report in reports:
            for key, metrics in report.items():
                if key.isdigit() or key in ['macro avg', 'weighted avg']:
                    if key not in class_metrics:
                        class_metrics[key] = {m: [] for m in metrics.keys() if m != 'support'}
                    for metric, value in metrics.items():
                        if metric != 'support':
                            class_metrics[key][metric].append(value)

        # Calculate averages and prepare formatted output
        averages = {key: {metric: np.mean(values) for metric, values in metrics.items()} for key, metrics in class_metrics.items()}

        # Calculate average training and evaluation times and memory usage
        avg_training_time = np.mean(training_times)
        avg_training_mem_usage = np.mean(training_mem_usages)
        avg_evaluating_time = np.mean(evaluating_times)
        avg_eval_mem_usage = np.mean(eval_mem_usages)
        avg_total_mem_usage = np.mean(total_mem_usages)

        results.append((frac, som_shape, averages, avg_training_time, avg_training_mem_usage, avg_evaluating_time, avg_eval_mem_usage, avg_total_mem_usage, reports, training_times, training_mem_usages, evaluating_times, eval_mem_usages, total_mem_usages))

# Display results
print("\nAverage Metrics Across All Folds:")
for result in results:
    frac, shape, metrics, avg_training_time, avg_training_mem_usage, avg_evaluating_time, avg_eval_mem_usage, avg_total_mem_usage, all_reports, all_training_times, all_training_mem_usages, all_evaluating_times, all_eval_mem_usages, all_total_mem_usages = result
    print("****************************")
    print(f"\nSampling Fraction: {frac}")
    print(f"SOM Shape: {shape}".upper())
    for class_id, class_metrics in metrics.items():
        print(f"\nClass {class_id}:")
        for metric, value in class_metrics.items():
            print(f"{metric}: {value:.4f}")

    # Display average training and evaluation times and memory usage
    minutes_train, seconds_train = divmod(avg_training_time, 60)
    minutes_eval, seconds_eval = divmod(avg_evaluating_time, 60)
    print(f"Average Training Time: {int(minutes_train)} minutes and {seconds_train:.2f} seconds")
    print(f"Average Training Memory Usage: {format_memory_usage(avg_training_mem_usage)}")
    print(f"Average Evaluating Time: {int(minutes_eval)} minutes and {seconds_eval:.2f} seconds")
    print(f"Average Evaluating Memory Usage: {format_memory_usage(avg_eval_mem_usage)}")
    print(f"Average Total Memory Usage: {format_memory_usage(avg_total_mem_usage)}")
    print("---------------------------------------")
    display_report_and_times(all_reports, all_training_times, all_training_mem_usages, all_evaluating_times, all_eval_mem_usages, all_total_mem_usages)
# Out:
# Evaluating for sampling fraction: 0.01
# Evaluating for som_shape: (10, 10)
# Evaluating for som_shape: (20, 20)
# Evaluating for som_shape: (30, 30)
# Evaluating for sampling fraction: 0.03
# Evaluating for som_shape: (10, 10)
# Evaluating for som_shape: (20, 20)
# Evaluating for som_shape: (30, 30)
#
# Average Metrics Across All Folds:
# ****************************
#
# Sampling Fraction: 0.01
# SOM SHAPE: (10, 10)
#
# Class 0:
# precision: 0.9648
# recall: 0.9834
# f1-score: 0.9739
#
# Class 1:
# precision: 0.9695
# recall: 0.9616
# f1-score: 0.9654
#
# Class 2:
# precision: 0.9720
# recall: 0.8920
# f1-score: 0.9298
#
# Class 3:
# precision: 0.8957
# recall: 0.5858
# f1-score: 0.6899
#
# Class 4:
# precision: 0.6678
# recall: 0.8557
# f1-score: 0.7492
#
# Class macro avg:
# precision: 0.8940
# recall: 0.8557
# f1-score: 0.8616
#
# Class weighted avg:
# precision: 0.9557
# recall: 0.9538
# f1-score: 0.9519
# Average Training Time: 0 minutes and 7.52 seconds
# Average Training Memory Usage: 0.79 MB
# Average Evaluating Time: 0 minutes and 3.61 seconds
# Average Evaluating Memory Usage: 1.78 MB
# Average Total Memory Usage: 2.57 MB
# ---------------------------------------
#
# All Reports and Times for this SOM Shape:
#
# Report for Fold 1:
#
# Label 0:
#   Precision: 0.9575
#   Recall: 0.9924
#   F1-score: 0.9746
#   Support: 9873.0000
#
# Label 1:
#   Precision: 0.9884
#   Recall: 0.9292
#   F1-score: 0.9579
#   Support: 1187.0000
#
# Label 2:
#   Precision: 0.9924
#   Recall: 0.9050
#   F1-score: 0.9467
#   Support: 1010.0000
#
# Label 3:
#   Precision: 0.9695
#   Recall: 0.5153
#   F1-score: 0.6729
#   Support: 555.0000
#
# Label 4:
#   Precision: 0.7320
#   Recall: 0.8601
#   F1-score: 0.7909
#   Support: 343.0000
#
# Accuracy: 0.9559
#
# Label macro avg:
#   Precision: 0.9279
#   Recall: 0.8404
#   F1-score: 0.8686
#   Support: 12968.0000
#
# Label weighted avg:
#   Precision: 0.9576
#   Recall: 0.9559
#   F1-score: 0.9532
#   Support: 12968.0000
#
# Training Time: 7.2142 seconds
# Training Memory Usage: 0.79 MB
# Evaluating Time: 3.6534 seconds
# Evaluating Memory Usage: 1.78 MB
# Total Memory Usage: 2.57 MB
#
# Report for Fold 2:
#
# Label 0:
#   Precision: 0.9597
#   Recall: 0.9840
#   F1-score: 0.9717
#   Support: 9964.0000
#
# Label 1:
#   Precision: 0.9731
#   Recall: 0.9628
#   F1-score: 0.9679
#   Support: 1129.0000
#
# Label 2:
#   Precision: 0.9941
#   Recall: 0.8350
#   F1-score: 0.9076
#   Support: 1012.0000
#
# Label 3:
#   Precision: 0.8258
#   Recall: 0.5176
#   F1-score: 0.6364
#   Support: 568.0000
#
# Label 4:
#   Precision: 0.5911
#   Recall: 0.8576
#   F1-score: 0.6999
#   Support: 295.0000
#
# Accuracy: 0.9473
#
# Label macro avg:
#   Precision: 0.8688
#   Recall: 0.8314
#   F1-score: 0.8367
#   Support: 12968.0000
#
# Label weighted avg:
#   Precision: 0.9493
#   Recall: 0.9473
#   F1-score: 0.9455
#   Support: 12968.0000
#
# Training Time: 7.6921 seconds
# Training Memory Usage: 0.79 MB
# Evaluating Time: 3.5896 seconds
# Evaluating Memory Usage: 1.78 MB
# Total Memory Usage: 2.58 MB
#
# Report for Fold 3:
#
# Label 0:
#   Precision: 0.9586
#   Recall: 0.9852
#   F1-score: 0.9717
#   Support: 9920.0000
#
# Label 1:
#   Precision: 0.9594
#   Recall: 0.9717
#   F1-score: 0.9655
#   Support: 1167.0000
#
# Label 2:
#   Precision: 0.9589
#   Recall: 0.9038
#   F1-score: 0.9305
#   Support: 1008.0000
#
# Label 3:
#   Precision: 0.9739
#   Recall: 0.4539
#   F1-score: 0.6192
#   Support: 575.0000
#
# Label 4:
#   Precision: 0.6997
#   Recall: 0.8758
#   F1-score: 0.7779
#   Support: 298.0000
#
# Accuracy: 0.9516
#
# Label macro avg:
#   Precision: 0.9101
#   Recall: 0.8381
#   F1-score: 0.8530
#   Support: 12968.0000
#
# Label weighted avg:
#   Precision: 0.9534
#   Recall: 0.9516
#   F1-score: 0.9479
#   Support: 12968.0000
#
# Training Time: 7.5365 seconds
# Training Memory Usage: 0.79 MB
# Evaluating Time: 3.6748 seconds
# Evaluating Memory Usage: 1.78 MB
# Total Memory Usage: 2.57 MB
#
# Report for Fold 4:
#
# Label 0:
#   Precision: 0.9609
#   Recall: 0.9800
#   F1-score: 0.9703
#   Support: 9894.0000
#
# Label 1:
#   Precision: 0.9660
#   Recall: 0.9819
#   F1-score: 0.9739
#   Support: 1159.0000
#
# Label 2:
#   Precision: 0.9621
#   Recall: 0.9122
#   F1-score: 0.9365
#   Support: 1002.0000
#
# Label 3:
#   Precision: 0.8933
#   Recall: 0.5140
#   F1-score: 0.6526
#   Support: 570.0000
#
# Label 4:
#   Precision: 0.6627
#   Recall: 0.8134
#   F1-score: 0.7304
#   Support: 343.0000
#
# Accuracy: 0.9500
#
# Label macro avg:
#   Precision: 0.8890
#   Recall: 0.8403
#   F1-score: 0.8527
#   Support: 12968.0000
#
# Label weighted avg:
#   Precision: 0.9506
#   Recall: 0.9500
#   F1-score: 0.9477
#   Support: 12968.0000
#
# Training Time: 7.4163 seconds
# Training Memory Usage: 0.79 MB
# Evaluating Time: 3.5482 seconds
# Evaluating Memory Usage: 1.78 MB
# Total Memory Usage: 2.58 MB
#
# Report for Fold 5:
#
# Label 0:
#   Precision: 0.9872
#   Recall: 0.9752
#   F1-score: 0.9812
#   Support: 9959.0000
#
# Label 1:
#   Precision: 0.9608
#   Recall: 0.9625
#   F1-score: 0.9616
#   Support: 1120.0000
#
# Label 2:
#   Precision: 0.9526
#   Recall: 0.9043
#   F1-score: 0.9278
#   Support: 1045.0000
#
# Label 3:
#   Precision: 0.8162
#   Recall: 0.9279
#   F1-score: 0.8685
#   Support: 555.0000
#
# Label 4:
#   Precision: 0.6536
#   Recall: 0.8715
#   F1-score: 0.7470
#   Support: 288.0000
#
# Accuracy: 0.9641
#
# Label macro avg:
#   Precision: 0.8741
#   Recall: 0.9283
#   F1-score: 0.8972
#   Support: 12967.0000
#
# Label weighted avg:
#   Precision: 0.9674
#   Recall: 0.9641
#   F1-score: 0.9652
#   Support: 12967.0000
#
# Training Time: 7.7173 seconds
# Training Memory Usage: 0.79 MB
# Evaluating Time: 3.5630 seconds
# Evaluating Memory Usage: 1.78 MB
# Total Memory Usage: 2.58 MB
# ****************************
#
# Sampling Fraction: 0.01
# SOM SHAPE: (20, 20)
#
# Class 0:
# precision: 0.9950
# recall: 0.9894
# f1-score: 0.9922
#
# Class 1:
# precision: 0.9783
# recall: 0.9946
# f1-score: 0.9864
#
# Class 2:
# precision: 0.9894
# recall: 0.9342
# f1-score: 0.9610
#
# Class 3:
# precision: 0.8926
# recall: 0.9462
# f1-score: 0.9181
#
# Class 4:
# precision: 0.8422
# recall: 0.9987
# f1-score: 0.9138
#
# Class macro avg:
# precision: 0.9395
# recall: 0.9726
# f1-score: 0.9543
#
# Class weighted avg:
# precision: 0.9850
# recall: 0.9839
# f1-score: 0.9841
# Average Training Time: 0 minutes and 15.62 seconds
# Average Training Memory Usage: 0.87 MB
# Average Evaluating Time: 0 minutes and 7.71 seconds
# Average Evaluating Memory Usage: 2.14 MB
# Average Total Memory Usage: 3.01 MB
# ---------------------------------------
#
# All Reports and Times for this SOM Shape:
#
# Report for Fold 1:
#
# Label 0:
#   Precision: 0.9962
#   Recall: 0.9870
#   F1-score: 0.9916
#   Support: 9873.0000
#
# Label 1:
#   Precision: 0.9761
#   Recall: 0.9958
#   F1-score: 0.9858
#   Support: 1187.0000
#
# Label 2:
#   Precision: 0.9875
#   Recall: 0.9386
#   F1-score: 0.9624
#   Support: 1010.0000
#
# Label 3:
#   Precision: 0.8651
#   Recall: 0.9477
#   F1-score: 0.9046
#   Support: 555.0000
#
# Label 4:
#   Precision: 0.8428
#   Recall: 1.0000
#   F1-score: 0.9147
#   Support: 343.0000
#
# Accuracy: 0.9827
#
# Label macro avg:
#   Precision: 0.9335
#   Recall: 0.9738
#   F1-score: 0.9518
#   Support: 12968.0000
#
# Label weighted avg:
#   Precision: 0.9840
#   Recall: 0.9827
#   F1-score: 0.9830
#   Support: 12968.0000
#
# Training Time: 15.8509 seconds
# Training Memory Usage: 0.87 MB
# Evaluating Time: 7.7364 seconds
# Evaluating Memory Usage: 2.14 MB
# Total Memory Usage: 3.01 MB
#
# Report for Fold 2:
#
# Label 0:
#   Precision: 0.9952
#   Recall: 0.9891
#   F1-score: 0.9921
#   Support: 9964.0000
#
# Label 1:
#   Precision: 0.9807
#   Recall: 0.9911
#   F1-score: 0.9859
#   Support: 1129.0000
#
# Label 2:
#   Precision: 0.9907
#   Recall: 0.9457
#   F1-score: 0.9676
#   Support: 1012.0000
#
# Label 3:
#   Precision: 0.8705
#   Recall: 0.9349
#   F1-score: 0.9015
#   Support: 568.0000
#
# Label 4:
#   Precision: 0.8477
#   Recall: 1.0000
#   F1-score: 0.9176
#   Support: 295.0000
#
# Accuracy: 0.9837
#
# Label macro avg:
#   Precision: 0.9369
#   Recall: 0.9721
#   F1-score: 0.9529
#   Support: 12968.0000
#
# Label weighted avg:
#   Precision: 0.9847
#   Recall: 0.9837
#   F1-score: 0.9840
#   Support: 12968.0000
#
# Training Time: 15.9848 seconds
# Training Memory Usage: 0.87 MB
# Evaluating Time: 7.7906 seconds
# Evaluating Memory Usage: 2.13 MB
# Total Memory Usage: 3.01 MB
#
# Report for Fold 3:
#
# Label 0:
#   Precision: 0.9933
#   Recall: 0.9886
#   F1-score: 0.9910
#   Support: 9920.0000
#
# Label 1:
#   Precision: 0.9773
#   Recall: 0.9974
#   F1-score: 0.9873
#   Support: 1167.0000
#
# Label 2:
#   Precision: 0.9957
#   Recall: 0.9177
#   F1-score: 0.9551
#   Support: 1008.0000
#
# Label 3:
#   Precision: 0.8690
#   Recall: 0.9461
#   F1-score: 0.9059
#   Support: 575.0000
#
# Label 4:
#   Precision: 0.8539
#   Recall: 1.0000
#   F1-score: 0.9212
#   Support: 298.0000
#
# Accuracy: 0.9823
#
# Label macro avg:
#   Precision: 0.9378
#   Recall: 0.9700
#   F1-score: 0.9521
#   Support: 12968.0000
#
# Label weighted avg:
#   Precision: 0.9833
#   Recall: 0.9823
#   F1-score: 0.9825
#   Support: 12968.0000
#
# Training Time: 14.9995 seconds
# Training Memory Usage: 0.87 MB
# Evaluating Time: 7.5167 seconds
# Evaluating Memory Usage: 2.14 MB
# Total Memory Usage: 3.01 MB
#
# Report for Fold 4:
#
# Label 0:
#   Precision: 0.9942
#   Recall: 0.9946
#   F1-score: 0.9944
#   Support: 9894.0000
#
# Label 1:
#   Precision: 0.9838
#   Recall: 0.9965
#   F1-score: 0.9901
#   Support: 1159.0000
#
# Label 2:
#   Precision: 0.9883
#   Recall: 0.9291
#   F1-score: 0.9578
#   Support: 1002.0000
#
# Label 3:
#   Precision: 0.9872
#   Recall: 0.9509
#   F1-score: 0.9687
#   Support: 570.0000
#
# Label 4:
#   Precision: 0.8444
#   Recall: 0.9971
#   F1-score: 0.9144
#   Support: 343.0000
#
# Accuracy: 0.9879
#
# Label macro avg:
#   Precision: 0.9596
#   Recall: 0.9737
#   F1-score: 0.9651
#   Support: 12968.0000
#
# Label weighted avg:
#   Precision: 0.9886
#   Recall: 0.9879
#   F1-score: 0.9880
#   Support: 12968.0000
#
# Training Time: 15.8125 seconds
# Training Memory Usage: 0.87 MB
# Evaluating Time: 7.8259 seconds
# Evaluating Memory Usage: 2.13 MB
# Total Memory Usage: 3.01 MB
#
# Report for Fold 5:
#
# Label 0:
#   Precision: 0.9963
#   Recall: 0.9877
#   F1-score: 0.9920
#   Support: 9959.0000
#
# Label 1:
#   Precision: 0.9737
#   Recall: 0.9920
#   F1-score: 0.9828
#   Support: 1120.0000
#
# Label 2:
#   Precision: 0.9850
#   Recall: 0.9397
#   F1-score: 0.9618
#   Support: 1045.0000
#
# Label 3:
#   Precision: 0.8713
#   Recall: 0.9514
#   F1-score: 0.9096
#   Support: 555.0000
#
# Label 4:
#   Precision: 0.8223
#   Recall: 0.9965
#   F1-score: 0.9011
#   Support: 288.0000
#
# Accuracy: 0.9829
#
# Label macro avg:
#   Precision: 0.9297
#   Recall: 0.9735
#   F1-score: 0.9494
#   Support: 12967.0000
#
# Label weighted avg:
#   Precision: 0.9842
#   Recall: 0.9829
#   F1-score: 0.9832
#   Support: 12967.0000
#
# Training Time: 15.4361 seconds
# Training Memory Usage: 0.87 MB
# Evaluating Time: 7.6813 seconds
# Evaluating Memory Usage: 2.13 MB
# Total Memory Usage: 3.01 MB
# ****************************
#
# Sampling Fraction: 0.01
# SOM SHAPE: (30, 30)
#
# Class 0:
# precision: 0.9955
# recall: 0.9977
# f1-score: 0.9966
#
# Class 1:
# precision: 0.9910
# recall: 0.9916
# f1-score: 0.9913
#
# Class 2:
# precision: 0.9941
# recall: 0.9513
# f1-score: 0.9722
#
# Class 3:
# precision: 0.9948
# recall: 0.9501
# f1-score: 0.9719
#
# Class 4:
# precision: 0.8635
# recall: 0.9908
# f1-score: 0.9227
#
# Class macro avg:
# precision: 0.9678
# recall: 0.9763
# f1-score: 0.9709
#
# Class weighted avg:
# precision: 0.9918
# recall: 0.9913
# f1-score: 0.9914
# Average Training Time: 0 minutes and 29.17 seconds
# Average Training Memory Usage: 1.38 MB
# Average Evaluating Time: 0 minutes and 13.86 seconds
# Average Evaluating Memory Usage: 2.71 MB
# Average Total Memory Usage: 4.08 MB
# ---------------------------------------
#
# All Reports and Times for this SOM Shape:
#
# Report for Fold 1:
#
# Label 0:
#   Precision: 0.9961
#   Recall: 0.9972
#   F1-score: 0.9966
#   Support: 9873.0000
#
# Label 1:
#   Precision: 0.9818
#   Recall: 0.9975
#   F1-score: 0.9896
#   Support: 1187.0000
#
# Label 2:
#   Precision: 0.9958
#   Recall: 0.9426
#   F1-score: 0.9685
#   Support: 1010.0000
#
# Label 3:
#   Precision: 0.9926
#   Recall: 0.9604
#   F1-score: 0.9762
#   Support: 555.0000
#
# Label 4:
#   Precision: 0.8805
#   Recall: 0.9883
#   F1-score: 0.9313
#   Support: 343.0000
#
# Accuracy: 0.9911
#
# Label macro avg:
#   Precision: 0.9693
#   Recall: 0.9772
#   F1-score: 0.9724
#   Support: 12968.0000
#
# Label weighted avg:
#   Precision: 0.9915
#   Recall: 0.9911
#   F1-score: 0.9912
#   Support: 12968.0000
#
# Training Time: 29.6487 seconds
# Training Memory Usage: 1.38 MB
# Evaluating Time: 13.9440 seconds
# Evaluating Memory Usage: 2.70 MB
# Total Memory Usage: 4.08 MB
#
# Report for Fold 2:
#
# Label 0:
#   Precision: 0.9938
#   Recall: 0.9989
#   F1-score: 0.9963
#   Support: 9964.0000
#
# Label 1:
#   Precision: 0.9929
#   Recall: 0.9841
#   F1-score: 0.9884
#   Support: 1129.0000
#
# Label 2:
#   Precision: 0.9979
#   Recall: 0.9516
#   F1-score: 0.9742
#   Support: 1012.0000
#
# Label 3:
#   Precision: 0.9981
#   Recall: 0.9384
#   F1-score: 0.9673
#   Support: 568.0000
#
# Label 4:
#   Precision: 0.8806
#   Recall: 1.0000
#   F1-score: 0.9365
#   Support: 295.0000
#
# Accuracy: 0.9913
#
# Label macro avg:
#   Precision: 0.9727
#   Recall: 0.9746
#   F1-score: 0.9726
#   Support: 12968.0000
#
# Label weighted avg:
#   Precision: 0.9917
#   Recall: 0.9913
#   F1-score: 0.9913
#   Support: 12968.0000
#
# Training Time: 29.3761 seconds
# Training Memory Usage: 1.38 MB
# Evaluating Time: 14.1740 seconds
# Evaluating Memory Usage: 2.71 MB
# Total Memory Usage: 4.09 MB
#
# Report for Fold 3:
#
# Label 0:
#   Precision: 0.9952
#   Recall: 0.9988
#   F1-score: 0.9970
#   Support: 9920.0000
#
# Label 1:
#   Precision: 0.9983
#   Recall: 0.9949
#   F1-score: 0.9966
#   Support: 1167.0000
#
# Label 2:
#   Precision: 0.9958
#   Recall: 0.9514
#   F1-score: 0.9731
#   Support: 1008.0000
#
# Label 3:
#   Precision: 1.0000
#   Recall: 0.9478
#   F1-score: 0.9732
#   Support: 575.0000
#
# Label 4:
#   Precision: 0.8739
#   Recall: 1.0000
#   F1-score: 0.9327
#   Support: 298.0000
#
# Accuracy: 0.9925
#
# Label macro avg:
#   Precision: 0.9726
#   Recall: 0.9786
#   F1-score: 0.9745
#   Support: 12968.0000
#
# Label weighted avg:
#   Precision: 0.9929
#   Recall: 0.9925
#   F1-score: 0.9926
#   Support: 12968.0000
#
# Training Time: 28.4092 seconds
# Training Memory Usage: 1.38 MB
# Evaluating Time: 14.2690 seconds
# Evaluating Memory Usage: 2.71 MB
# Total Memory Usage: 4.09 MB
#
# Report for Fold 4:
#
# Label 0:
#   Precision: 0.9961
#   Recall: 0.9973
#   F1-score: 0.9967
#   Support: 9894.0000
#
# Label 1:
#   Precision: 0.9948
#   Recall: 0.9914
#   F1-score: 0.9931
#   Support: 1159.0000
#
# Label 2:
#   Precision: 0.9897
#   Recall: 0.9581
#   F1-score: 0.9736
#   Support: 1002.0000
#
# Label 3:
#   Precision: 0.9945
#   Recall: 0.9526
#   F1-score: 0.9731
#   Support: 570.0000
#
# Label 4:
#   Precision: 0.8593
#   Recall: 0.9796
#   F1-score: 0.9155
#   Support: 343.0000
#
# Accuracy: 0.9913
#
# Label macro avg:
#   Precision: 0.9669
#   Recall: 0.9758
#   F1-score: 0.9704
#   Support: 12968.0000
#
# Label weighted avg:
#   Precision: 0.9918
#   Recall: 0.9913
#   F1-score: 0.9914
#   Support: 12968.0000
#
# Training Time: 29.0757 seconds
# Training Memory Usage: 1.38 MB
# Evaluating Time: 13.3687 seconds
# Evaluating Memory Usage: 2.71 MB
# Total Memory Usage: 4.09 MB
#
# Report for Fold 5:
#
# Label 0:
#   Precision: 0.9963
#   Recall: 0.9964
#   F1-score: 0.9963
#   Support: 9959.0000
#
# Label 1:
#   Precision: 0.9875
#   Recall: 0.9902
#   F1-score: 0.9889
#   Support: 1120.0000
#
# Label 2:
#   Precision: 0.9910
#   Recall: 0.9531
#   F1-score: 0.9717
#   Support: 1045.0000
#
# Label 3:
#   Precision: 0.9888
#   Recall: 0.9514
#   F1-score: 0.9697
#   Support: 555.0000
#
# Label 4:
#   Precision: 0.8232
#   Recall: 0.9861
#   F1-score: 0.8973
#   Support: 288.0000
#
# Accuracy: 0.9902
#
# Label macro avg:
#   Precision: 0.9574
#   Recall: 0.9754
#   F1-score: 0.9648
#   Support: 12967.0000
#
# Label weighted avg:
#   Precision: 0.9909
#   Recall: 0.9902
#   F1-score: 0.9904
#   Support: 12967.0000
#
# Training Time: 29.3298 seconds
# Training Memory Usage: 1.38 MB
# Evaluating Time: 13.5394 seconds
# Evaluating Memory Usage: 2.70 MB
# Total Memory Usage: 4.08 MB
# ****************************
#
# Sampling Fraction: 0.03
# SOM SHAPE: (10, 10)
#
# Class 0:
# precision: 0.9755
# recall: 0.9779
# f1-score: 0.9766
#
# Class 1:
# precision: 0.9716
# recall: 0.9456
# f1-score: 0.9580
#
# Class 2:
# precision: 0.9849
# recall: 0.8659
# f1-score: 0.9211
#
# Class 3:
# precision: 0.7794
# recall: 0.7643
# f1-score: 0.7428
#
# Class 4:
# precision: 0.6235
# recall: 0.8519
# f1-score: 0.7198
#
# Class macro avg:
# precision: 0.8670
# recall: 0.8811
# f1-score: 0.8637
#
# Class weighted avg:
# precision: 0.9588
# recall: 0.9538
# f1-score: 0.9542
# Average Training Time: 0 minutes and 22.76 seconds
# Average Training Memory Usage: 2.38 MB
# Average Evaluating Time: 0 minutes and 11.20 seconds
# Average Evaluating Memory Usage: 4.98 MB
# Average Total Memory Usage: 7.36 MB
# ---------------------------------------
#
# All Reports and Times for this SOM Shape:
#
# Report for Fold 1:
#
# Label 0:
#   Precision: 0.9873
#   Recall: 0.9700
#   F1-score: 0.9786
#   Support: 29665.0000
#
# Label 1:
#   Precision: 0.9744
#   Recall: 0.8751
#   F1-score: 0.9221
#   Support: 3524.0000
#
# Label 2:
#   Precision: 0.9905
#   Recall: 0.8956
#   F1-score: 0.9406
#   Support: 3035.0000
#
# Label 3:
#   Precision: 0.6271
#   Recall: 0.9475
#   F1-score: 0.7547
#   Support: 1713.0000
#
# Label 4:
#   Precision: 0.6690
#   Recall: 0.8718
#   F1-score: 0.7571
#   Support: 967.0000
#
# Accuracy: 0.9522
#
# Label macro avg:
#   Precision: 0.8497
#   Recall: 0.9120
#   F1-score: 0.8706
#   Support: 38904.0000
#
# Label weighted avg:
#   Precision: 0.9626
#   Recall: 0.9522
#   F1-score: 0.9551
#   Support: 38904.0000
#
# Training Time: 22.5251 seconds
# Training Memory Usage: 2.38 MB
# Evaluating Time: 10.8172 seconds
# Evaluating Memory Usage: 4.98 MB
# Total Memory Usage: 7.36 MB
#
# Report for Fold 2:
#
# Label 0:
#   Precision: 0.9558
#   Recall: 0.9860
#   F1-score: 0.9707
#   Support: 29761.0000
#
# Label 1:
#   Precision: 0.9730
#   Recall: 0.9491
#   F1-score: 0.9609
#   Support: 3458.0000
#
# Label 2:
#   Precision: 0.9956
#   Recall: 0.8165
#   F1-score: 0.8972
#   Support: 3019.0000
#
# Label 3:
#   Precision: 0.8536
#   Recall: 0.5071
#   F1-score: 0.6362
#   Support: 1690.0000
#
# Label 4:
#   Precision: 0.5987
#   Recall: 0.8268
#   F1-score: 0.6945
#   Support: 976.0000
#
# Accuracy: 0.9448
#
# Label macro avg:
#   Precision: 0.8753
#   Recall: 0.8171
#   F1-score: 0.8319
#   Support: 38904.0000
#
# Label weighted avg:
#   Precision: 0.9470
#   Recall: 0.9448
#   F1-score: 0.9426
#   Support: 38904.0000
#
# Training Time: 23.1581 seconds
# Training Memory Usage: 2.38 MB
# Evaluating Time: 12.1381 seconds
# Evaluating Memory Usage: 4.99 MB
# Total Memory Usage: 7.37 MB
#
# Report for Fold 3:
#
# Label 0:
#   Precision: 0.9881
#   Recall: 0.9767
#   F1-score: 0.9824
#   Support: 29780.0000
#
# Label 1:
#   Precision: 0.9750
#   Recall: 0.9622
#   F1-score: 0.9686
#   Support: 3492.0000
#
# Label 2:
#   Precision: 0.9749
#   Recall: 0.9103
#   F1-score: 0.9415
#   Support: 3067.0000
#
# Label 3:
#   Precision: 0.7998
#   Recall: 0.9428
#   F1-score: 0.8654
#   Support: 1661.0000
#
# Label 4:
#   Precision: 0.6464
#   Recall: 0.8583
#   F1-score: 0.7374
#   Support: 903.0000
#
# Accuracy: 0.9660
#
# Label macro avg:
#   Precision: 0.8768
#   Recall: 0.9301
#   F1-score: 0.8991
#   Support: 38903.0000
#
# Label weighted avg:
#   Precision: 0.9699
#   Recall: 0.9660
#   F1-score: 0.9672
#   Support: 38903.0000
#
# Training Time: 22.4565 seconds
# Training Memory Usage: 2.38 MB
# Evaluating Time: 10.6326 seconds
# Evaluating Memory Usage: 4.98 MB
# Total Memory Usage: 7.36 MB
#
# Report for Fold 4:
#
# Label 0:
#   Precision: 0.9857
#   Recall: 0.9723
#   F1-score: 0.9790
#   Support: 29775.0000
#
# Label 1:
#   Precision: 0.9677
#   Recall: 0.9605
#   F1-score: 0.9641
#   Support: 3494.0000
#
# Label 2:
#   Precision: 0.9748
#   Recall: 0.8605
#   F1-score: 0.9141
#   Support: 3060.0000
#
# Label 3:
#   Precision: 0.7455
#   Recall: 0.9304
#   F1-score: 0.8277
#   Support: 1681.0000
#
# Label 4:
#   Precision: 0.6055
#   Recall: 0.8578
#   F1-score: 0.7099
#   Support: 893.0000
#
# Accuracy: 0.9580
#
# Label macro avg:
#   Precision: 0.8558
#   Recall: 0.9163
#   F1-score: 0.8790
#   Support: 38903.0000
#
# Label weighted avg:
#   Precision: 0.9641
#   Recall: 0.9580
#   F1-score: 0.9598
#   Support: 38903.0000
#
# Training Time: 22.3767 seconds
# Training Memory Usage: 2.38 MB
# Evaluating Time: 10.9652 seconds
# Evaluating Memory Usage: 4.99 MB
# Total Memory Usage: 7.36 MB
#
# Report for Fold 5:
#
# Label 0:
#   Precision: 0.9606
#   Recall: 0.9845
#   F1-score: 0.9724
#   Support: 29850.0000
#
# Label 1:
#   Precision: 0.9676
#   Recall: 0.9810
#   F1-score: 0.9743
#   Support: 3318.0000
#
# Label 2:
#   Precision: 0.9889
#   Recall: 0.8466
#   F1-score: 0.9122
#   Support: 3050.0000
#
# Label 3:
#   Precision: 0.8710
#   Recall: 0.4936
#   F1-score: 0.6301
#   Support: 1724.0000
#
# Label 4:
#   Precision: 0.5979
#   Recall: 0.8450
#   F1-score: 0.7003
#   Support: 961.0000
#
# Accuracy: 0.9482
#
# Label macro avg:
#   Precision: 0.8772
#   Recall: 0.8301
#   F1-score: 0.8379
#   Support: 38903.0000
#
# Label weighted avg:
#   Precision: 0.9505
#   Recall: 0.9482
#   F1-score: 0.9460
#   Support: 38903.0000
#
# Training Time: 23.2756 seconds
# Training Memory Usage: 2.38 MB
# Evaluating Time: 11.4263 seconds
# Evaluating Memory Usage: 4.97 MB
# Total Memory Usage: 7.35 MB
# ****************************
#
# Sampling Fraction: 0.03
# SOM SHAPE: (20, 20)
#
# Class 0:
# precision: 0.9953
# recall: 0.9904
# f1-score: 0.9928
#
# Class 1:
# precision: 0.9820
# recall: 0.9902
# f1-score: 0.9860
#
# Class 2:
# precision: 0.9920
# recall: 0.9419
# f1-score: 0.9663
#
# Class 3:
# precision: 0.8872
# recall: 0.9362
# f1-score: 0.9106
#
# Class 4:
# precision: 0.8414
# recall: 0.9998
# f1-score: 0.9137
#
# Class macro avg:
# precision: 0.9396
# recall: 0.9717
# f1-score: 0.9539
#
# Class weighted avg:
# precision: 0.9855
# recall: 0.9844
# f1-score: 0.9847
# Average Training Time: 0 minutes and 46.82 seconds
# Average Training Memory Usage: 2.38 MB
# Average Evaluating Time: 0 minutes and 23.63 seconds
# Average Evaluating Memory Usage: 5.35 MB
# Average Total Memory Usage: 7.73 MB
# ---------------------------------------
#
# All Reports and Times for this SOM Shape:
#
# Report for Fold 1:
#
# Label 0:
#   Precision: 0.9951
#   Recall: 0.9881
#   F1-score: 0.9916
#   Support: 29665.0000
#
# Label 1:
#   Precision: 0.9814
#   Recall: 0.9906
#   F1-score: 0.9860
#   Support: 3524.0000
#
# Label 2:
#   Precision: 0.9927
#   Recall: 0.9440
#   F1-score: 0.9677
#   Support: 3035.0000
#
# Label 3:
#   Precision: 0.8526
#   Recall: 0.9317
#   F1-score: 0.8904
#   Support: 1713.0000
#
# Label 4:
#   Precision: 0.8542
#   Recall: 1.0000
#   F1-score: 0.9214
#   Support: 967.0000
#
# Accuracy: 0.9827
#
# Label macro avg:
#   Precision: 0.9352
#   Recall: 0.9709
#   F1-score: 0.9514
#   Support: 38904.0000
#
# Label weighted avg:
#   Precision: 0.9839
#   Recall: 0.9827
#   F1-score: 0.9830
#   Support: 38904.0000
#
# Training Time: 48.9727 seconds
# Training Memory Usage: 2.38 MB
# Evaluating Time: 24.8419 seconds
# Evaluating Memory Usage: 5.35 MB
# Total Memory Usage: 7.73 MB
#
# Report for Fold 2:
#
# Label 0:
#   Precision: 0.9951
#   Recall: 0.9897
#   F1-score: 0.9924
#   Support: 29761.0000
#
# Label 1:
#   Precision: 0.9867
#   Recall: 0.9896
#   F1-score: 0.9882
#   Support: 3458.0000
#
# Label 2:
#   Precision: 0.9906
#   Recall: 0.9384
#   F1-score: 0.9638
#   Support: 3019.0000
#
# Label 3:
#   Precision: 0.8725
#   Recall: 0.9391
#   F1-score: 0.9045
#   Support: 1690.0000
#
# Label 4:
#   Precision: 0.8436
#   Recall: 1.0000
#   F1-score: 0.9151
#   Support: 976.0000
#
# Accuracy: 0.9838
#
# Label macro avg:
#   Precision: 0.9377
#   Recall: 0.9713
#   F1-score: 0.9528
#   Support: 38904.0000
#
# Label weighted avg:
#   Precision: 0.9849
#   Recall: 0.9838
#   F1-score: 0.9840
#   Support: 38904.0000
#
# Training Time: 45.9996 seconds
# Training Memory Usage: 2.38 MB
# Evaluating Time: 23.6138 seconds
# Evaluating Memory Usage: 5.33 MB
# Total Memory Usage: 7.71 MB
#
# Report for Fold 3:
#
# Label 0:
#   Precision: 0.9956
#   Recall: 0.9890
#   F1-score: 0.9923
#   Support: 29780.0000
#
# Label 1:
#   Precision: 0.9770
#   Recall: 0.9968
#   F1-score: 0.9868
#   Support: 3492.0000
#
# Label 2:
#   Precision: 0.9910
#   Recall: 0.9354
#   F1-score: 0.9624
#   Support: 3067.0000
#
# Label 3:
#   Precision: 0.8828
#   Recall: 0.9428
#   F1-score: 0.9118
#   Support: 1661.0000
#
# Label 4:
#   Precision: 0.8275
#   Recall: 0.9989
#   F1-score: 0.9052
#   Support: 903.0000
#
# Accuracy: 0.9837
#
# Label macro avg:
#   Precision: 0.9348
#   Recall: 0.9726
#   F1-score: 0.9517
#   Support: 38903.0000
#
# Label weighted avg:
#   Precision: 0.9849
#   Recall: 0.9837
#   F1-score: 0.9840
#   Support: 38903.0000
#
# Training Time: 47.5125 seconds
# Training Memory Usage: 2.38 MB
# Evaluating Time: 23.9910 seconds
# Evaluating Memory Usage: 5.35 MB
# Total Memory Usage: 7.73 MB
#
# Report for Fold 4:
#
# Label 0:
#   Precision: 0.9948
#   Recall: 0.9893
#   F1-score: 0.9921
#   Support: 29775.0000
#
# Label 1:
#   Precision: 0.9817
#   Recall: 0.9823
#   F1-score: 0.9820
#   Support: 3494.0000
#
# Label 2:
#   Precision: 0.9901
#   Recall: 0.9444
#   F1-score: 0.9667
#   Support: 3060.0000
#
# Label 3:
#   Precision: 0.8567
#   Recall: 0.9244
#   F1-score: 0.8893
#   Support: 1681.0000
#
# Label 4:
#   Precision: 0.8385
#   Recall: 1.0000
#   F1-score: 0.9122
#   Support: 893.0000
#
# Accuracy: 0.9826
#
# Label macro avg:
#   Precision: 0.9324
#   Recall: 0.9681
#   F1-score: 0.9484
#   Support: 38903.0000
#
# Label weighted avg:
#   Precision: 0.9837
#   Recall: 0.9826
#   F1-score: 0.9829
#   Support: 38903.0000
#
# Training Time: 47.0675 seconds
# Training Memory Usage: 2.38 MB
# Evaluating Time: 22.9977 seconds
# Evaluating Memory Usage: 5.36 MB
# Total Memory Usage: 7.74 MB
#
# Report for Fold 5:
#
# Label 0:
#   Precision: 0.9961
#   Recall: 0.9958
#   F1-score: 0.9959
#   Support: 29850.0000
#
# Label 1:
#   Precision: 0.9830
#   Recall: 0.9916
#   F1-score: 0.9872
#   Support: 3318.0000
#
# Label 2:
#   Precision: 0.9959
#   Recall: 0.9472
#   F1-score: 0.9709
#   Support: 3050.0000
#
# Label 3:
#   Precision: 0.9713
#   Recall: 0.9432
#   F1-score: 0.9570
#   Support: 1724.0000
#
# Label 4:
#   Precision: 0.8430
#   Recall: 1.0000
#   F1-score: 0.9148
#   Support: 961.0000
#
# Accuracy: 0.9894
#
# Label macro avg:
#   Precision: 0.9578
#   Recall: 0.9755
#   F1-score: 0.9652
#   Support: 38903.0000
#
# Label weighted avg:
#   Precision: 0.9901
#   Recall: 0.9894
#   F1-score: 0.9895
#   Support: 38903.0000
#
# Training Time: 44.5581 seconds
# Training Memory Usage: 2.38 MB
# Evaluating Time: 22.6987 seconds
# Evaluating Memory Usage: 5.35 MB
# Total Memory Usage: 7.73 MB
# ****************************
#
# Sampling Fraction: 0.03
# SOM SHAPE: (30, 30)
#
# Class 0:
# precision: 0.9958
# recall: 0.9972
# f1-score: 0.9965
#
# Class 1:
# precision: 0.9885
# recall: 0.9915
# f1-score: 0.9899
#
# Class 2:
# precision: 0.9903
# recall: 0.9537
# f1-score: 0.9716
#
# Class 3:
# precision: 0.9949
# recall: 0.9476
# f1-score: 0.9707
#
# Class 4:
# precision: 0.8643
# recall: 0.9933
# f1-score: 0.9241
#
# Class macro avg:
# precision: 0.9668
# recall: 0.9767
# f1-score: 0.9706
#
# Class weighted avg:
# precision: 0.9915
# recall: 0.9910
# f1-score: 0.9911
# Average Training Time: 1 minutes and 27.08 seconds
# Average Training Memory Usage: 2.38 MB
# Average Evaluating Time: 0 minutes and 42.17 seconds
# Average Evaluating Memory Usage: 5.93 MB
# Average Total Memory Usage: 8.31 MB
# ---------------------------------------
#
# All Reports and Times for this SOM Shape:
#
# Report for Fold 1:
#
# Label 0:
#   Precision: 0.9949
#   Recall: 0.9987
#   F1-score: 0.9968
#   Support: 29665.0000
#
# Label 1:
#   Precision: 0.9951
#   Recall: 0.9850
#   F1-score: 0.9900
#   Support: 3524.0000
#
# Label 2:
#   Precision: 0.9938
#   Recall: 0.9489
#   F1-score: 0.9708
#   Support: 3035.0000
#
# Label 3:
#   Precision: 0.9920
#   Recall: 0.9463
#   F1-score: 0.9686
#   Support: 1713.0000
#
# Label 4:
#   Precision: 0.8743
#   Recall: 1.0000
#   F1-score: 0.9329
#   Support: 967.0000
#
# Accuracy: 0.9913
#
# Label macro avg:
#   Precision: 0.9700
#   Recall: 0.9758
#   F1-score: 0.9718
#   Support: 38904.0000
#
# Label weighted avg:
#   Precision: 0.9917
#   Recall: 0.9913
#   F1-score: 0.9913
#   Support: 38904.0000
#
# Training Time: 92.5206 seconds
# Training Memory Usage: 2.38 MB
# Evaluating Time: 44.1278 seconds
# Evaluating Memory Usage: 5.95 MB
# Total Memory Usage: 8.33 MB
#
# Report for Fold 2:
#
# Label 0:
#   Precision: 0.9963
#   Recall: 0.9964
#   F1-score: 0.9963
#   Support: 29761.0000
#
# Label 1:
#   Precision: 0.9790
#   Recall: 0.9983
#   F1-score: 0.9885
#   Support: 3458.0000
#
# Label 2:
#   Precision: 0.9901
#   Recall: 0.9569
#   F1-score: 0.9732
#   Support: 3019.0000
#
# Label 3:
#   Precision: 0.9975
#   Recall: 0.9462
#   F1-score: 0.9712
#   Support: 1690.0000
#
# Label 4:
#   Precision: 0.8803
#   Recall: 0.9867
#   F1-score: 0.9304
#   Support: 976.0000
#
# Accuracy: 0.9911
#
# Label macro avg:
#   Precision: 0.9686
#   Recall: 0.9769
#   F1-score: 0.9719
#   Support: 38904.0000
#
# Label weighted avg:
#   Precision: 0.9914
#   Recall: 0.9911
#   F1-score: 0.9911
#   Support: 38904.0000
#
# Training Time: 83.1546 seconds
# Training Memory Usage: 2.38 MB
# Evaluating Time: 41.5511 seconds
# Evaluating Memory Usage: 5.92 MB
# Total Memory Usage: 8.30 MB
#
# Report for Fold 3:
#
# Label 0:
#   Precision: 0.9972
#   Recall: 0.9962
#   F1-score: 0.9967
#   Support: 29780.0000
#
# Label 1:
#   Precision: 0.9823
#   Recall: 0.9986
#   F1-score: 0.9903
#   Support: 3492.0000
#
# Label 2:
#   Precision: 0.9959
#   Recall: 0.9508
#   F1-score: 0.9728
#   Support: 3067.0000
#
# Label 3:
#   Precision: 0.9969
#   Recall: 0.9579
#   F1-score: 0.9770
#   Support: 1661.0000
#
# Label 4:
#   Precision: 0.8360
#   Recall: 0.9989
#   F1-score: 0.9102
#   Support: 903.0000
#
# Accuracy: 0.9912
#
# Label macro avg:
#   Precision: 0.9616
#   Recall: 0.9805
#   F1-score: 0.9694
#   Support: 38903.0000
#
# Label weighted avg:
#   Precision: 0.9920
#   Recall: 0.9912
#   F1-score: 0.9914
#   Support: 38903.0000
#
# Training Time: 84.2477 seconds
# Training Memory Usage: 2.38 MB
# Evaluating Time: 41.7402 seconds
# Evaluating Memory Usage: 5.92 MB
# Total Memory Usage: 8.30 MB
#
# Report for Fold 4:
#
# Label 0:
#   Precision: 0.9956
#   Recall: 0.9978
#   F1-score: 0.9967
#   Support: 29775.0000
#
# Label 1:
#   Precision: 0.9954
#   Recall: 0.9894
#   F1-score: 0.9924
#   Support: 3494.0000
#
# Label 2:
#   Precision: 0.9781
#   Recall: 0.9614
#   F1-score: 0.9697
#   Support: 3060.0000
#
# Label 3:
#   Precision: 0.9950
#   Recall: 0.9429
#   F1-score: 0.9682
#   Support: 1681.0000
#
# Label 4:
#   Precision: 0.8866
#   Recall: 0.9810
#   F1-score: 0.9314
#   Support: 893.0000
#
# Accuracy: 0.9914
#
# Label macro avg:
#   Precision: 0.9701
#   Recall: 0.9745
#   F1-score: 0.9717
#   Support: 38903.0000
#
# Label weighted avg:
#   Precision: 0.9917
#   Recall: 0.9914
#   F1-score: 0.9914
#   Support: 38903.0000
#
# Training Time: 90.4316 seconds
# Training Memory Usage: 2.38 MB
# Evaluating Time: 42.5142 seconds
# Evaluating Memory Usage: 5.94 MB
# Total Memory Usage: 8.32 MB
#
# Report for Fold 5:
#
# Label 0:
#   Precision: 0.9950
#   Recall: 0.9968
#   F1-score: 0.9959
#   Support: 29850.0000
#
# Label 1:
#   Precision: 0.9906
#   Recall: 0.9861
#   F1-score: 0.9884
#   Support: 3318.0000
#
# Label 2:
#   Precision: 0.9935
#   Recall: 0.9505
#   F1-score: 0.9715
#   Support: 3050.0000
#
# Label 3:
#   Precision: 0.9933
#   Recall: 0.9449
#   F1-score: 0.9685
#   Support: 1724.0000
#
# Label 4:
#   Precision: 0.8445
#   Recall: 1.0000
#   F1-score: 0.9157
#   Support: 961.0000
#
# Accuracy: 0.9901
#
# Label macro avg:
#   Precision: 0.9634
#   Recall: 0.9757
#   F1-score: 0.9680
#   Support: 38903.0000
#
# Label weighted avg:
#   Precision: 0.9907
#   Recall: 0.9901
#   F1-score: 0.9902
#   Support: 38903.0000
#
# Training Time: 85.0541 seconds
# Training Memory Usage: 2.38 MB
# Evaluating Time: 40.9058 seconds
# Evaluating Memory Usage: 5.92 MB
# Total Memory Usage: 8.30 MB
