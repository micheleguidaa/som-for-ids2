# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from minisom import MiniSom
import numpy as np
import time
from joblib import Parallel, delayed
import warnings

warnings.filterwarnings('ignore')

# Function to process a single file
def process_file(file):
    print(f"Processing file: {file}")  # Debug statement
    df = pd.read_csv(DATA_PATH + file)
    df['Label'] = df['Label'].apply(lambda x: 0 if x == 'Benign' else 1)
    
    target = df.iloc[:, -1].values
    data = df.iloc[:, :-1]
    
    # Print distribution of target labels
    label_distribution = df['Label'].value_counts()
    print(f"Label distribution for {file}:")
    print(label_distribution)
    
    scaler = StandardScaler()
    data = scaler.fit_transform(data)
    
    X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.2)
    
    return X_train, X_test, y_train, y_test

# Function to classify using SOM
def classify(som, data, X_train, y_train):
    print("Starting classification...")  # Debug statement
    winmap = som.labels_map(X_train, y_train)
    default_class = np.sum(list(winmap.values())).most_common()[0][0]
    result = []
    for d in data:
        win_position = som.winner(d)
        if win_position in winmap:
            result.append(winmap[win_position].most_common()[0][0])
        else:
            result.append(default_class)
    return result

# Function to train SOM and generate classification report
def train_som(X_train, X_test, y_train, y_test, file):
    print(f"Training SOM for {file} with data shape: {X_train.shape}")  # Debug statement
    n_neurons = 20
    m_neurons = 20
    input_len = X_train.shape[1]
    sigma = 1.5
    learning_rate = 1.2
    iterations = 10000
    
    som = MiniSom(x=n_neurons, y=m_neurons, input_len=input_len, sigma=sigma, learning_rate=learning_rate)
    
    # Classification before training
    print(f"Classifying {file} before training...")  # Debug statement
    y_pred_before = classify(som, X_test, X_train, y_train)
    report_before = classification_report(y_test, y_pred_before, digits=4)
    topographic_error_before = som.topographic_error(X_test)
    quantization_error_before = som.quantization_error(X_test)
    
    # Training SOM
    print(f"Training SOM for {file}...")  # Debug statement
    start_time = time.time()
    som.train(X_train, iterations, verbose=True)
    train_time = time.time() - start_time
    
    # Classification after training
    print(f"Classifying {file} after training...")  # Debug statement
    y_pred_after = classify(som, X_test, X_train, y_train)
    report_after = classification_report(y_test, y_pred_after, digits=4)
    topographic_error_after = som.topographic_error(X_test)
    quantization_error_after = som.quantization_error(X_test)
    
    return {
        "report_before": report_before,
        "topographic_error_before": topographic_error_before,
        "quantization_error_before": quantization_error_before,
        "report_after": report_after,
        "topographic_error_after": topographic_error_after,
        "quantization_error_after": quantization_error_after,
        "train_time": train_time
    }

# Paths and files
DATA_PATH = "/users/mik2002/som/dataset-processed CIC-IDS-2018/"
FILES = [
    "processed_bot_dataset.csv",
    "processed_bruteforce_dataset.csv",
    "processed_Ddos_dataset.csv",
    "processed_dos_dataset.csv",
    "processed_infiltration_dataset.csv",
]

# Process each file in parallel
print("Starting file processing...")  # Debug statement
results = Parallel(n_jobs=len(FILES))(delayed(process_file)(file) for file in FILES)

# Train SOM for each dataset and get metrics
metrics = []

for i, (X_train, X_test, y_train, y_test) in enumerate(results):
    metric = train_som(X_train, X_test, y_train, y_test, FILES[i])
    metrics.append(metric)

# Display metrics
for i, file in enumerate(FILES):
    print(f"Metrics for {file}:")
    print("Before Training:")
    print(metrics[i]["report_before"])
    print(f"Topographic Error: {metrics[i]['topographic_error_before']:.4f}")
    print(f"Quantization Error: {metrics[i]['quantization_error_before']:.4f}")
    print("\nAfter Training:")
    print(metrics[i]["report_after"])
    print(f"Topographic Error: {metrics[i]['topographic_error_after']:.4f}")
    print(f"Quantization Error: {metrics[i]['quantization_error_after']:.4f}")
    print(f"Training Time: {metrics[i]['train_time']:.2f} seconds")
    print("-" * 50)
# Out:
# Starting file processing...
# Processing file: processed_Ddos_dataset.csv
# Processing file: processed_bruteforce_dataset.csv
# Processing file: processed_bot_dataset.csv
# Processing file: processed_dos_dataset.csv
# Processing file: processed_infiltration_dataset.csv
# Label distribution for processed_bruteforce_dataset.csv:
# Label
# 0    664002
# 1    156668
# Name: count, dtype: int64
# Label distribution for processed_infiltration_dataset.csv:
# Label
# 0    772775
# 1    161060
# Name: count, dtype: int64
# Label distribution for processed_bot_dataset.csv:
# Label
# 0    758248
# 1    282310
# Name: count, dtype: int64
# Label distribution for processed_dos_dataset.csv:
# Label
# 0    1436245
# 1     507715
# Name: count, dtype: int64
# Label distribution for processed_Ddos_dataset.csv:
# Label
# 0    7335789
# 1     576191
# Name: count, dtype: int64
# Training SOM for processed_bot_dataset.csv with data shape: (832446, 65)
# Classifying processed_bot_dataset.csv before training...
# Starting classification...
# Training SOM for processed_bot_dataset.csv...
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.5330845970113028
# Classifying processed_bot_dataset.csv after training...
# Starting classification...
# Training SOM for processed_bruteforce_dataset.csv with data shape: (656536, 65)
# Classifying processed_bruteforce_dataset.csv before training...
# Starting classification...
# Training SOM for processed_bruteforce_dataset.csv...
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.5172893937904907
# Classifying processed_bruteforce_dataset.csv after training...
# Starting classification...
# Training SOM for processed_Ddos_dataset.csv with data shape: (6329584, 65)
# Classifying processed_Ddos_dataset.csv before training...
# Starting classification...
# Training SOM for processed_Ddos_dataset.csv...
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.6581477894665606
# Classifying processed_Ddos_dataset.csv after training...
# Starting classification...
# Training SOM for processed_dos_dataset.csv with data shape: (1555168, 65)
# Classifying processed_dos_dataset.csv before training...
# Starting classification...
# Training SOM for processed_dos_dataset.csv...
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.6133448247066513
# Classifying processed_dos_dataset.csv after training...
# Starting classification...
# Training SOM for processed_infiltration_dataset.csv with data shape: (747068, 65)
# Classifying processed_infiltration_dataset.csv before training...
# Starting classification...
# Training SOM for processed_infiltration_dataset.csv...
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 0.5631081630753283
# Classifying processed_infiltration_dataset.csv after training...
# Starting classification...
# Metrics for processed_bot_dataset.csv:
# Before Training:
#               precision    recall  f1-score   support
#
#            0     0.9980    0.9009    0.9470    151694
#            1     0.7888    0.9953    0.8801     56418
#
#     accuracy                         0.9265    208112
#    macro avg     0.8934    0.9481    0.9135    208112
# weighted avg     0.9413    0.9265    0.9288    208112
#
# Topographic Error: 0.9990
# Quantization Error: 5.8018
#
# After Training:
#               precision    recall  f1-score   support
#
#            0     0.9994    0.9893    0.9943    151694
#            1     0.9721    0.9984    0.9851     56418
#
#     accuracy                         0.9918    208112
#    macro avg     0.9857    0.9939    0.9897    208112
# weighted avg     0.9920    0.9918    0.9918    208112
#
# Topographic Error: 0.0384
# Quantization Error: 0.5327
# Training Time: 12.03 seconds
# --------------------------------------------------
# Metrics for processed_bruteforce_dataset.csv:
# Before Training:
#               precision    recall  f1-score   support
#
#            0     0.9655    0.9983    0.9816    132668
#            1     0.9918    0.8496    0.9152     31466
#
#     accuracy                         0.9698    164134
#    macro avg     0.9787    0.9239    0.9484    164134
# weighted avg     0.9705    0.9698    0.9689    164134
#
# Topographic Error: 0.9956
# Quantization Error: 5.2477
#
# After Training:
#               precision    recall  f1-score   support
#
#            0     1.0000    0.9988    0.9994    132668
#            1     0.9950    0.9999    0.9975     31466
#
#     accuracy                         0.9990    164134
#    macro avg     0.9975    0.9994    0.9984    164134
# weighted avg     0.9990    0.9990    0.9990    164134
#
# Topographic Error: 0.0368
# Quantization Error: 0.5028
# Training Time: 10.21 seconds
# --------------------------------------------------
# Metrics for processed_Ddos_dataset.csv:
# Before Training:
#               precision    recall  f1-score   support
#
#            0     0.9494    0.9892    0.9689   1467251
#            1     0.7048    0.3280    0.4476    115145
#
#     accuracy                         0.9411   1582396
#    macro avg     0.8271    0.6586    0.7083   1582396
# weighted avg     0.9316    0.9411    0.9310   1582396
#
# Topographic Error: 0.9940
# Quantization Error: 5.8426
#
# After Training:
#               precision    recall  f1-score   support
#
#            0     0.9991    0.9976    0.9984   1467251
#            1     0.9704    0.9889    0.9796    115145
#
#     accuracy                         0.9970   1582396
#    macro avg     0.9848    0.9933    0.9890   1582396
# weighted avg     0.9970    0.9970    0.9970   1582396
#
# Topographic Error: 0.0745
# Quantization Error: 0.6536
# Training Time: 71.80 seconds
# --------------------------------------------------
# Metrics for processed_dos_dataset.csv:
# Before Training:
#               precision    recall  f1-score   support
#
#            0     0.9877    0.9248    0.9552    287710
#            1     0.8188    0.9674    0.8869    101082
#
#     accuracy                         0.9359    388792
#    macro avg     0.9033    0.9461    0.9211    388792
# weighted avg     0.9438    0.9359    0.9375    388792
#
# Topographic Error: 0.9975
# Quantization Error: 5.6570
#
# After Training:
#               precision    recall  f1-score   support
#
#            0     0.9984    0.9971    0.9978    287710
#            1     0.9918    0.9956    0.9937    101082
#
#     accuracy                         0.9967    388792
#    macro avg     0.9951    0.9963    0.9957    388792
# weighted avg     0.9967    0.9967    0.9967    388792
#
# Topographic Error: 0.0385
# Quantization Error: 0.6162
# Training Time: 19.52 seconds
# --------------------------------------------------
# Metrics for processed_infiltration_dataset.csv:
# Before Training:
#               precision    recall  f1-score   support
#
#            0     0.8267    0.9994    0.9048    154334
#            1     0.4764    0.0028    0.0056     32433
#
#     accuracy                         0.8263    186767
#    macro avg     0.6515    0.5011    0.4552    186767
# weighted avg     0.7658    0.8263    0.7487    186767
#
# Topographic Error: 0.9994
# Quantization Error: 5.7008
#
# After Training:
#               precision    recall  f1-score   support
#
#            0     0.8263    1.0000    0.9049    154334
#            1     0.2500    0.0000    0.0001     32433
#
#     accuracy                         0.8263    186767
#    macro avg     0.5382    0.5000    0.4525    186767
# weighted avg     0.7263    0.8263    0.7478    186767
#
# Topographic Error: 0.0792
# Quantization Error: 0.5524
# Training Time: 10.93 seconds
# --------------------------------------------------
