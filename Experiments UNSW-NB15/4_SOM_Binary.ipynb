# %%
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report
from minisom import MiniSom
import numpy as np
import time
import matplotlib.pyplot as plt
from joblib import Parallel, delayed
import warnings
import tracemalloc
from collections import Counter

# %%
# Funzione per convertire l'uso della memoria in unità appropriate
def format_memory_usage(mem_usage):
    if mem_usage >= 1024 ** 3:
        return f"{mem_usage / (1024 ** 3):.2f} GB"
    else:
        return f"{mem_usage / (1024 ** 2):.2f} MB"

# Funzione per classificare i dati utilizzando il SOM
def classify2(som, data, training_data, training_labels):
    winmap = som.labels_map(training_data, training_labels)
    default_class = Counter(training_labels).most_common(1)[0][0]
    result = []
    for sample in data:
        winner = som.winner(sample)
        if winner in winmap:
            result.append(winmap[winner].most_common(1)[0][0])
        else:
            result.append(default_class)
    return result

# Funzione per monitorare l'uso della memoria durante una funzione
def monitor_memory_usage(func, *args, **kwargs):
    tracemalloc.start()
    result = func(*args, **kwargs)
    current, peak = tracemalloc.get_traced_memory()
    tracemalloc.stop()
    return result, peak

# Funzione per il training e l'evaluation con monitoraggio della memoria
def train_and_evaluate(train_idx, test_idx, X, y, som_shape, sigma, learning_rate):
    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    som = MiniSom(som_shape[0], som_shape[1], X_train.shape[1], sigma=sigma, learning_rate=learning_rate)

    start_train = time.time()
    _, training_mem_usage = monitor_memory_usage(som.train_random, X_train, X_train.shape[0])
    end_train = time.time()

    start_eval = time.time()
    y_pred, eval_mem_usage = monitor_memory_usage(classify2, som, X_test, X_train, y_train)
    end_eval = time.time()

    report = classification_report(y_test, y_pred, digits=4, output_dict=True, zero_division=0)

    training_time = end_train - start_train
    evaluating_time = end_eval - start_eval
    total_mem_usage = training_mem_usage + eval_mem_usage

    return report, training_time, training_mem_usage, evaluating_time, eval_mem_usage, total_mem_usage

# %%
# Inizializzazione del dataset e dei parametri
DATA_PATH = "/users/mik2002/som/dataset-processed UNSW-NB15/"
DATA_FILE = "dataset-processed-UNSW-NB15.csv"

# Carichiamo il dataset combinato e processato
df_dataset = pd.read_csv(DATA_PATH + DATA_FILE)

# Drop the 'attack_cat' column se ancora presente (può essere già stato rimosso nel dataset processato)
if 'attack_cat' in df_dataset.columns:
    df_dataset = df_dataset.drop(columns=['attack_cat'])

# Display label distribution
print("Distribution:")
display(df_dataset["label"].value_counts())
# Out:
# Distribution:
# label
# 1    164673
# 0     93000
# Name: count, dtype: int64

# %%
# Parametri per il SOM
som_sizes = [(10, 10), (20, 20), (30, 30), (40, 40)]
learning_rate = 1.2
sigma = 1.5
sampling_fractions = [0.1, 0.3, 0.5, 0.7, 1]  # Diversi frazioni di campionamento

# %%
results = []

# Funzione wrapper per il parallelismo
def parallel_train_and_evaluate(train_idx, test_idx, som_shape, data, target, sigma, learning_rate):
    report, training_time, training_mem_usage, evaluating_time, eval_mem_usage, total_mem_usage = train_and_evaluate(train_idx, test_idx, data, target, som_shape, sigma, learning_rate)
    return report, training_time, training_mem_usage, evaluating_time, eval_mem_usage, total_mem_usage

# Inizializzazione del KFold
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# Loop su diverse frazioni di campionamento
for frac in sampling_fractions:
    print(f"Evaluating for sampling fraction: {frac}")
    
    # Esegui campionamento casuale stratificato mantenendo le proporzioni delle classi
    with warnings.catch_warnings():
        warnings.simplefilter("ignore", DeprecationWarning)
        sampled_df = df_dataset.groupby("label", group_keys=False).apply(lambda x: x.sample(frac=frac, random_state=42))

    scaler = MinMaxScaler()
    data = scaler.fit_transform(sampled_df.iloc[:, :-1])
    target = sampled_df.iloc[:, -1].values

    # Loop su diverse dimensioni del SOM
    for som_shape in som_sizes:
        print(f"Evaluating for som_shape: {som_shape}")
        # Split del dataset con K-Fold e parallelismo
        parallel_results = Parallel(n_jobs=-1)(delayed(parallel_train_and_evaluate)(train_idx, test_idx, som_shape, data, target, sigma, learning_rate) for train_idx, test_idx in kf.split(data))
        
        reports, training_times, training_mem_usages, evaluating_times, eval_mem_usages, total_mem_usages = zip(*parallel_results)
        
        # Aggrega metriche dai report
        class_metrics = {}
        accuracies = []
        for report in reports:
            accuracies.append(report['accuracy'])
            for key, metrics in report.items():
                if key.isdigit() or key in ['macro avg', 'weighted avg']:
                    if key not in class_metrics:
                        class_metrics[key] = {m: [] for m in metrics.keys() if m != 'support'}
                    for metric, value in metrics.items():
                        if metric != 'support':
                            class_metrics[key][metric].append(value)

        # Calcola medie e prepara output formattato
        averages = {key: {metric: np.mean(values) for metric, values in metrics.items()} for key, metrics in class_metrics.items()}
        averages['accuracy'] = np.mean(accuracies)

        # Calcola i tempi medi di training e valutazione e l'uso della memoria
        avg_training_time = np.mean(training_times)
        avg_training_mem_usage = np.mean(training_mem_usages)
        avg_evaluating_time = np.mean(evaluating_times)
        avg_eval_mem_usage = np.mean(eval_mem_usages)
        avg_total_mem_usage = np.mean(total_mem_usages)

        results.append((frac, som_shape, averages, avg_training_time, avg_training_mem_usage, avg_evaluating_time, avg_eval_mem_usage, avg_total_mem_usage))

        # Mostra i risultati per ogni frazione di campionamento e dimensione del SOM
        print("\nAverage Metrics Across All Folds:")
        print("****************************")
        print(f"\nSampling Fraction: {frac}")
        print(f"SOM Shape: {som_shape}".upper())
        for class_id, class_metrics in averages.items():
            if isinstance(class_metrics, dict):
                print(f"\nClass {class_id}:")
                for metric, value in class_metrics.items():
                    print(f"{metric}: {value:.4f}")
            else:
                print(f"\n{class_id}: {class_metrics:.4f}")

        # Mostra i tempi medi di training e valutazione e l'uso della memoria
        minutes_train, seconds_train = divmod(avg_training_time, 60)
        minutes_eval, seconds_eval = divmod(avg_evaluating_time, 60)
        print(f"Average Training Time: {int(minutes_train)} minutes and {seconds_train:.2f} seconds")
        print(f"Average Training Memory Usage: {format_memory_usage(avg_training_mem_usage)}")
        print(f"Average Evaluating Time: {int(minutes_eval)} minutes and {seconds_eval:.2f} seconds")
        print(f"Average Evaluating Memory Usage: {format_memory_usage(avg_eval_mem_usage)}")
        print(f"Average Total Memory Usage: {format_memory_usage(avg_total_mem_usage)}")
        print("---------------------------------------")

# Funzione per creare i grafici
def plot_metrics(results):
    fractions = [res[0] for res in results]
    shapes = [res[1] for res in results]
    metrics = ["precision", "recall", "f1-score", "accuracy", "training_time", "training_memory", "evaluating_time", "evaluating_memory", "total_time", "total_memory"]
    
    metric_values = {metric: [] for metric in metrics}
    
    for result in results:
        frac, shape, averages, avg_training_time, avg_training_mem_usage, avg_evaluating_time, avg_eval_mem_usage, avg_total_mem_usage = result
        metric_values["precision"].append(averages["weighted avg"]["precision"])
        metric_values["recall"].append(averages["weighted avg"]["recall"])
        metric_values["f1-score"].append(averages["weighted avg"]["f1-score"])
        metric_values["accuracy"].append(averages["accuracy"])
        metric_values["training_time"].append(avg_training_time)
        metric_values["training_memory"].append(avg_training_mem_usage / (1024 ** 2))  # Convert to MB
        metric_values["evaluating_time"].append(avg_evaluating_time)
        metric_values["evaluating_memory"].append(avg_eval_mem_usage / (1024 ** 2))  # Convert to MB
        metric_values["total_time"].append(avg_training_time + avg_evaluating_time)
        metric_values["total_memory"].append(avg_total_mem_usage / (1024 ** 2))  # Convert to MB
    
    fig, axes = plt.subplots(nrows=4, ncols=3, figsize=(15, 15))
    axes = axes.flatten()
    
    y_labels = {
        "precision": "Precision",
        "recall": "Recall",
        "f1-score": "F1-Score",
        "accuracy": "Accuracy",
        "training_time": "Time (s)",
        "training_memory": "Memory (MB)",
        "evaluating_time": "Time (s)",
        "evaluating_memory": "Memory (MB)",
        "total_time": "Time (s)",
        "total_memory": "Memory (MB)"
    }
    
    for i, metric in enumerate(metrics):
        axes[i].plot(fractions, metric_values[metric], marker='o', linestyle='-', label=metric)
        axes[i].set_title(metric.replace("_", " ").capitalize())
        axes[i].set_xlabel("Sampling fraction")
        axes[i].set_ylabel(y_labels[metric])
        axes[i].legend()
    
    plt.tight_layout()
    plt.show()

# Mostra i grafici delle metriche
plot_metrics(results)
# Out:
# Evaluating for sampling fraction: 0.1
# Evaluating for som_shape: (10, 10)
#
# Average Metrics Across All Folds:
# ****************************
#
# Sampling Fraction: 0.1
# SOM SHAPE: (10, 10)
#
# Class 0:
# precision: 0.9919
# recall: 0.7109
# f1-score: 0.8282
#
# Class 1:
# precision: 0.8593
# recall: 0.9967
# f1-score: 0.9229
#
# Class macro avg:
# precision: 0.9256
# recall: 0.8538
# f1-score: 0.8755
#
# Class weighted avg:
# precision: 0.9071
# recall: 0.8936
# f1-score: 0.8887
#
# accuracy: 0.8936
# Average Training Time: 0 minutes and 2.85 seconds
# Average Training Memory Usage: 0.32 MB
# Average Evaluating Time: 0 minutes and 1.33 seconds
# Average Evaluating Memory Usage: 0.77 MB
# Average Total Memory Usage: 1.09 MB
# ---------------------------------------
# Evaluating for som_shape: (20, 20)
#
# Average Metrics Across All Folds:
# ****************************
#
# Sampling Fraction: 0.1
# SOM SHAPE: (20, 20)
#
# Class 0:
# precision: 0.9705
# recall: 0.7269
# f1-score: 0.8311
#
# Class 1:
# precision: 0.8649
# recall: 0.9875
# f1-score: 0.9222
#
# Class macro avg:
# precision: 0.9177
# recall: 0.8572
# f1-score: 0.8766
#
# Class weighted avg:
# precision: 0.9031
# recall: 0.8934
# f1-score: 0.8893
#
# accuracy: 0.8934
# Average Training Time: 0 minutes and 5.67 seconds
# Average Training Memory Usage: 0.55 MB
# Average Evaluating Time: 0 minutes and 2.82 seconds
# Average Evaluating Memory Usage: 1.08 MB
# Average Total Memory Usage: 1.63 MB
# ---------------------------------------
# Evaluating for som_shape: (30, 30)
#
# Average Metrics Across All Folds:
# ****************************
#
# Sampling Fraction: 0.1
# SOM SHAPE: (30, 30)
#
# Class 0:
# precision: 0.9325
# recall: 0.7621
# f1-score: 0.8386
#
# Class 1:
# precision: 0.8782
# recall: 0.9687
# f1-score: 0.9212
#
# Class macro avg:
# precision: 0.9053
# recall: 0.8654
# f1-score: 0.8799
#
# Class weighted avg:
# precision: 0.8979
# recall: 0.8941
# f1-score: 0.8914
#
# accuracy: 0.8941
# Average Training Time: 0 minutes and 10.14 seconds
# Average Training Memory Usage: 0.95 MB
# Average Evaluating Time: 0 minutes and 4.81 seconds
# Average Evaluating Memory Usage: 1.55 MB
# Average Total Memory Usage: 2.50 MB
# ---------------------------------------
# Evaluating for som_shape: (40, 40)
#
# Average Metrics Across All Folds:
# ****************************
#
# Sampling Fraction: 0.1
# SOM SHAPE: (40, 40)
#
# Class 0:
# precision: 0.9340
# recall: 0.7567
# f1-score: 0.8360
#
# Class 1:
# precision: 0.8759
# recall: 0.9698
# f1-score: 0.9205
#
# Class macro avg:
# precision: 0.9050
# recall: 0.8633
# f1-score: 0.8782
#
# Class weighted avg:
# precision: 0.8969
# recall: 0.8929
# f1-score: 0.8900
#
# accuracy: 0.8929
# Average Training Time: 0 minutes and 33.01 seconds
# Average Training Memory Usage: 1.50 MB
# Average Evaluating Time: 0 minutes and 8.12 seconds
# Average Evaluating Memory Usage: 2.15 MB
# Average Total Memory Usage: 3.65 MB
# ---------------------------------------
# Evaluating for sampling fraction: 0.3
# Evaluating for som_shape: (10, 10)
#
# Average Metrics Across All Folds:
# ****************************
#
# Sampling Fraction: 0.3
# SOM SHAPE: (10, 10)
#
# Class 0:
# precision: 0.9934
# recall: 0.7076
# f1-score: 0.8265
#
# Class 1:
# precision: 0.8579
# recall: 0.9973
# f1-score: 0.9224
#
# Class macro avg:
# precision: 0.9257
# recall: 0.8525
# f1-score: 0.8744
#
# Class weighted avg:
# precision: 0.9068
# recall: 0.8927
# f1-score: 0.8878
#
# accuracy: 0.8927
# Average Training Time: 0 minutes and 8.45 seconds
# Average Training Memory Usage: 0.95 MB
# Average Evaluating Time: 0 minutes and 4.04 seconds
# Average Evaluating Memory Usage: 2.05 MB
# Average Total Memory Usage: 3.00 MB
# ---------------------------------------
# Evaluating for som_shape: (20, 20)
#
# Average Metrics Across All Folds:
# ****************************
#
# Sampling Fraction: 0.3
# SOM SHAPE: (20, 20)
#
# Class 0:
# precision: 0.9915
# recall: 0.7134
# f1-score: 0.8297
#
# Class 1:
# precision: 0.8602
# recall: 0.9965
# f1-score: 0.9234
#
# Class macro avg:
# precision: 0.9259
# recall: 0.8550
# f1-score: 0.8765
#
# Class weighted avg:
# precision: 0.9077
# recall: 0.8943
# f1-score: 0.8896
#
# accuracy: 0.8943
# Average Training Time: 0 minutes and 17.35 seconds
# Average Training Memory Usage: 0.95 MB
# Average Evaluating Time: 0 minutes and 8.34 seconds
# Average Evaluating Memory Usage: 2.36 MB
# Average Total Memory Usage: 3.30 MB
# ---------------------------------------
# Evaluating for som_shape: (30, 30)
#
# Average Metrics Across All Folds:
# ****************************
#
# Sampling Fraction: 0.3
# SOM SHAPE: (30, 30)
#
# Class 0:
# precision: 0.9713
# recall: 0.7313
# f1-score: 0.8343
#
# Class 1:
# precision: 0.8668
# recall: 0.9878
# f1-score: 0.9233
#
# Class macro avg:
# precision: 0.9190
# recall: 0.8595
# f1-score: 0.8788
#
# Class weighted avg:
# precision: 0.9046
# recall: 0.8952
# f1-score: 0.8912
#
# accuracy: 0.8952
# Average Training Time: 0 minutes and 30.77 seconds
# Average Training Memory Usage: 1.26 MB
# Average Evaluating Time: 0 minutes and 15.45 seconds
# Average Evaluating Memory Usage: 2.85 MB
# Average Total Memory Usage: 4.11 MB
# ---------------------------------------
# Evaluating for som_shape: (40, 40)
#
# Average Metrics Across All Folds:
# ****************************
#
# Sampling Fraction: 0.3
# SOM SHAPE: (40, 40)
#
# Class 0:
# precision: 0.9475
# recall: 0.7502
# f1-score: 0.8373
#
# Class 1:
# precision: 0.8738
# recall: 0.9763
# f1-score: 0.9222
#
# Class macro avg:
# precision: 0.9106
# recall: 0.8633
# f1-score: 0.8798
#
# Class weighted avg:
# precision: 0.9003
# recall: 0.8948
# f1-score: 0.8916
#
# accuracy: 0.8948
# Average Training Time: 0 minutes and 50.08 seconds
# Average Training Memory Usage: 1.82 MB
# Average Evaluating Time: 0 minutes and 23.43 seconds
# Average Evaluating Memory Usage: 3.50 MB
# Average Total Memory Usage: 5.31 MB
# ---------------------------------------
# Evaluating for sampling fraction: 0.5
# Evaluating for som_shape: (10, 10)
#
# Average Metrics Across All Folds:
# ****************************
#
# Sampling Fraction: 0.5
# SOM SHAPE: (10, 10)
#
# Class 0:
# precision: 0.9959
# recall: 0.7061
# f1-score: 0.8263
#
# Class 1:
# precision: 0.8575
# recall: 0.9984
# f1-score: 0.9226
#
# Class macro avg:
# precision: 0.9267
# recall: 0.8522
# f1-score: 0.8745
#
# Class weighted avg:
# precision: 0.9075
# recall: 0.8929
# f1-score: 0.8878
#
# accuracy: 0.8929
# Average Training Time: 0 minutes and 14.34 seconds
# Average Training Memory Usage: 1.57 MB
# Average Evaluating Time: 0 minutes and 6.89 seconds
# Average Evaluating Memory Usage: 3.33 MB
# Average Total Memory Usage: 4.90 MB
# ---------------------------------------
# Evaluating for som_shape: (20, 20)
#
# Average Metrics Across All Folds:
# ****************************
#
# Sampling Fraction: 0.5
# SOM SHAPE: (20, 20)
#
# Class 0:
# precision: 0.9968
# recall: 0.7093
# f1-score: 0.8288
#
# Class 1:
# precision: 0.8588
# recall: 0.9987
# f1-score: 0.9235
#
# Class macro avg:
# precision: 0.9278
# recall: 0.8540
# f1-score: 0.8762
#
# Class weighted avg:
# precision: 0.9086
# recall: 0.8943
# f1-score: 0.8893
#
# accuracy: 0.8943
# Average Training Time: 0 minutes and 28.67 seconds
# Average Training Memory Usage: 1.57 MB
# Average Evaluating Time: 0 minutes and 14.43 seconds
# Average Evaluating Memory Usage: 3.64 MB
# Average Total Memory Usage: 5.21 MB
# ---------------------------------------
# Evaluating for som_shape: (30, 30)
#
# Average Metrics Across All Folds:
# ****************************
#
# Sampling Fraction: 0.5
# SOM SHAPE: (30, 30)
#
# Class 0:
# precision: 0.9774
# recall: 0.7260
# f1-score: 0.8331
#
# Class 1:
# precision: 0.8649
# recall: 0.9905
# f1-score: 0.9235
#
# Class macro avg:
# precision: 0.9212
# recall: 0.8583
# f1-score: 0.8783
#
# Class weighted avg:
# precision: 0.9055
# recall: 0.8951
# f1-score: 0.8909
#
# accuracy: 0.8951
# Average Training Time: 0 minutes and 53.73 seconds
# Average Training Memory Usage: 1.57 MB
# Average Evaluating Time: 0 minutes and 25.95 seconds
# Average Evaluating Memory Usage: 4.13 MB
# Average Total Memory Usage: 5.70 MB
# ---------------------------------------
# Evaluating for som_shape: (40, 40)
#
# Average Metrics Across All Folds:
# ****************************
#
# Sampling Fraction: 0.5
# SOM SHAPE: (40, 40)
#
# Class 0:
# precision: 0.9533
# recall: 0.7476
# f1-score: 0.8380
#
# Class 1:
# precision: 0.8730
# recall: 0.9793
# f1-score: 0.9231
#
# Class macro avg:
# precision: 0.9131
# recall: 0.8635
# f1-score: 0.8805
#
# Class weighted avg:
# precision: 0.9019
# recall: 0.8957
# f1-score: 0.8924
#
# accuracy: 0.8957
# Average Training Time: 1 minutes and 26.95 seconds
# Average Training Memory Usage: 2.12 MB
# Average Evaluating Time: 0 minutes and 42.62 seconds
# Average Evaluating Memory Usage: 4.78 MB
# Average Total Memory Usage: 6.90 MB
# ---------------------------------------
# Evaluating for sampling fraction: 0.7
# Evaluating for som_shape: (10, 10)
#
# Average Metrics Across All Folds:
# ****************************
#
# Sampling Fraction: 0.7
# SOM SHAPE: (10, 10)
#
# Class 0:
# precision: 0.9963
# recall: 0.7058
# f1-score: 0.8263
#
# Class 1:
# precision: 0.8573
# recall: 0.9985
# f1-score: 0.9226
#
# Class macro avg:
# precision: 0.9268
# recall: 0.8522
# f1-score: 0.8744
#
# Class weighted avg:
# precision: 0.9075
# recall: 0.8929
# f1-score: 0.8878
#
# accuracy: 0.8929
# Average Training Time: 0 minutes and 20.08 seconds
# Average Training Memory Usage: 2.20 MB
# Average Evaluating Time: 0 minutes and 9.45 seconds
# Average Evaluating Memory Usage: 4.61 MB
# Average Total Memory Usage: 6.81 MB
# ---------------------------------------
# Evaluating for som_shape: (20, 20)
#
# Average Metrics Across All Folds:
# ****************************
#
# Sampling Fraction: 0.7
# SOM SHAPE: (20, 20)
#
# Class 0:
# precision: 0.9928
# recall: 0.7117
# f1-score: 0.8291
#
# Class 1:
# precision: 0.8596
# recall: 0.9971
# f1-score: 0.9233
#
# Class macro avg:
# precision: 0.9262
# recall: 0.8544
# f1-score: 0.8762
#
# Class weighted avg:
# precision: 0.9077
# recall: 0.8941
# f1-score: 0.8893
#
# accuracy: 0.8941
# Average Training Time: 0 minutes and 39.37 seconds
# Average Training Memory Usage: 2.20 MB
# Average Evaluating Time: 0 minutes and 20.08 seconds
# Average Evaluating Memory Usage: 4.91 MB
# Average Total Memory Usage: 7.11 MB
# ---------------------------------------
# Evaluating for som_shape: (30, 30)
#
# Average Metrics Across All Folds:
# ****************************
#
# Sampling Fraction: 0.7
# SOM SHAPE: (30, 30)
#
# Class 0:
# precision: 0.9847
# recall: 0.7220
# f1-score: 0.8331
#
# Class 1:
# precision: 0.8636
# recall: 0.9937
# f1-score: 0.9240
#
# Class macro avg:
# precision: 0.9241
# recall: 0.8578
# f1-score: 0.8786
#
# Class weighted avg:
# precision: 0.9073
# recall: 0.8956
# f1-score: 0.8912
#
# accuracy: 0.8956
# Average Training Time: 1 minutes and 14.55 seconds
# Average Training Memory Usage: 2.20 MB
# Average Evaluating Time: 0 minutes and 36.56 seconds
# Average Evaluating Memory Usage: 5.37 MB
# Average Total Memory Usage: 7.57 MB
# ---------------------------------------
# Evaluating for som_shape: (40, 40)
#
# Average Metrics Across All Folds:
# ****************************
#
# Sampling Fraction: 0.7
# SOM SHAPE: (40, 40)
#
# Class 0:
# precision: 0.9600
# recall: 0.7442
# f1-score: 0.8384
#
# Class 1:
# precision: 0.8718
# recall: 0.9825
# f1-score: 0.9238
#
# Class macro avg:
# precision: 0.9159
# recall: 0.8633
# f1-score: 0.8811
#
# Class weighted avg:
# precision: 0.9036
# recall: 0.8965
# f1-score: 0.8930
#
# accuracy: 0.8965
# Average Training Time: 1 minutes and 57.10 seconds
# Average Training Memory Usage: 2.43 MB
# Average Evaluating Time: 0 minutes and 57.57 seconds
# Average Evaluating Memory Usage: 5.99 MB
# Average Total Memory Usage: 8.43 MB
# ---------------------------------------
# Evaluating for sampling fraction: 1
# Evaluating for som_shape: (10, 10)
#
# Average Metrics Across All Folds:
# ****************************
#
# Sampling Fraction: 1
# SOM SHAPE: (10, 10)
#
# Class 0:
# precision: 0.9960
# recall: 0.7057
# f1-score: 0.8261
#
# Class 1:
# precision: 0.8573
# recall: 0.9984
# f1-score: 0.9225
#
# Class macro avg:
# precision: 0.9266
# recall: 0.8520
# f1-score: 0.8743
#
# Class weighted avg:
# precision: 0.9073
# recall: 0.8928
# f1-score: 0.8877
#
# accuracy: 0.8928
# Average Training Time: 0 minutes and 29.15 seconds
# Average Training Memory Usage: 3.15 MB
# Average Evaluating Time: 0 minutes and 13.74 seconds
# Average Evaluating Memory Usage: 6.52 MB
# Average Total Memory Usage: 9.66 MB
# ---------------------------------------
# Evaluating for som_shape: (20, 20)
#
# Average Metrics Across All Folds:
# ****************************
#
# Sampling Fraction: 1
# SOM SHAPE: (20, 20)
#
# Class 0:
# precision: 0.9973
# recall: 0.7078
# f1-score: 0.8280
#
# Class 1:
# precision: 0.8582
# recall: 0.9989
# f1-score: 0.9232
#
# Class macro avg:
# precision: 0.9278
# recall: 0.8534
# f1-score: 0.8756
#
# Class weighted avg:
# precision: 0.9084
# recall: 0.8939
# f1-score: 0.8889
#
# accuracy: 0.8939
# Average Training Time: 0 minutes and 56.78 seconds
# Average Training Memory Usage: 3.15 MB
# Average Evaluating Time: 0 minutes and 28.08 seconds
# Average Evaluating Memory Usage: 6.81 MB
# Average Total Memory Usage: 9.96 MB
# ---------------------------------------
# Evaluating for som_shape: (30, 30)
#
# Average Metrics Across All Folds:
# ****************************
#
# Sampling Fraction: 1
# SOM SHAPE: (30, 30)
#
# Class 0:
# precision: 0.9821
# recall: 0.7237
# f1-score: 0.8333
#
# Class 1:
# precision: 0.8642
# recall: 0.9925
# f1-score: 0.9239
#
# Class macro avg:
# precision: 0.9231
# recall: 0.8581
# f1-score: 0.8786
#
# Class weighted avg:
# precision: 0.9067
# recall: 0.8955
# f1-score: 0.8912
#
# accuracy: 0.8955
# Average Training Time: 1 minutes and 45.31 seconds
# Average Training Memory Usage: 3.15 MB
# Average Evaluating Time: 0 minutes and 50.78 seconds
# Average Evaluating Memory Usage: 7.28 MB
# Average Total Memory Usage: 10.43 MB
# ---------------------------------------
# Evaluating for som_shape: (40, 40)
#
# Average Metrics Across All Folds:
# ****************************
#
# Sampling Fraction: 1
# SOM SHAPE: (40, 40)
#
# Class 0:
# precision: 0.9624
# recall: 0.7444
# f1-score: 0.8395
#
# Class 1:
# precision: 0.8720
# recall: 0.9836
# f1-score: 0.9244
#
# Class macro avg:
# precision: 0.9172
# recall: 0.8640
# f1-score: 0.8819
#
# Class weighted avg:
# precision: 0.9047
# recall: 0.8972
# f1-score: 0.8938
#
# accuracy: 0.8972
# Average Training Time: 2 minutes and 54.54 seconds
# Average Training Memory Usage: 3.15 MB
# Average Evaluating Time: 1 minutes and 23.93 seconds
# Average Evaluating Memory Usage: 7.97 MB
# Average Total Memory Usage: 11.12 MB
# ---------------------------------------
