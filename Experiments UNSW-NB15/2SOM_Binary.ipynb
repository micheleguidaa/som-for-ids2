# %%
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report
from minisom import MiniSom
import numpy as np
import time
import matplotlib.pyplot as plt
from joblib import Parallel, delayed
import warnings
import tracemalloc
from collections import Counter

# %%
# Funzione per convertire l'uso della memoria in unità appropriate
def format_memory_usage(mem_usage):
    if mem_usage >= 1024 ** 3:
        return f"{mem_usage / (1024 ** 3):.2f} GB"
    else:
        return f"{mem_usage / (1024 ** 2):.2f} MB"

# Funzione per classificare i dati utilizzando il SOM
def classify2(som, data, training_data, training_labels):
    winmap = som.labels_map(training_data, training_labels)
    default_class = Counter(training_labels).most_common(1)[0][0]
    result = []
    for sample in data:
        winner = som.winner(sample)
        if winner in winmap:
            result.append(winmap[winner].most_common(1)[0][0])
        else:
            result.append(default_class)
    return result

# Funzione per monitorare l'uso della memoria durante una funzione
def monitor_memory_usage(func, *args, **kwargs):
    tracemalloc.start()
    result = func(*args, **kwargs)
    current, peak = tracemalloc.get_traced_memory()
    tracemalloc.stop()
    return result, peak

# %%
# Funzione per il training e l'evaluation con monitoraggio della memoria
def train_and_evaluate(train_idx, test_idx, X, y, som_shape, sigma, learning_rate):
    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    som = MiniSom(som_shape[0], som_shape[1], X_train.shape[1], sigma=sigma, learning_rate=learning_rate)

    start_train = time.time()
    _, training_mem_usage = monitor_memory_usage(som.train_random, X_train, X_train.shape[0])
    end_train = time.time()

    start_eval = time.time()
    y_pred, eval_mem_usage = monitor_memory_usage(classify2, som, X_test, X_train, y_train)
    end_eval = time.time()

    report = classification_report(y_test, y_pred, digits=4, output_dict=True, zero_division=0)

    training_time = end_train - start_train
    evaluating_time = end_eval - start_eval
    total_mem_usage = training_mem_usage + eval_mem_usage

    return report, training_time, training_mem_usage, evaluating_time, eval_mem_usage, total_mem_usage

# %%
# Inizializzazione del dataset e dei parametri
DATA_PATH = "/users/mik2002/som/dataset-processed UNSW-NB15/"
DATA_FILE = "dataset-processed-UNSW-NB15.csv"

# Carichiamo il dataset combinato e processato
df_dataset = pd.read_csv(DATA_PATH + DATA_FILE)

# Drop the 'attack_cat' column se ancora presente (può essere già stato rimosso nel dataset processato)
if 'attack_cat' in df_dataset.columns:
    df_dataset = df_dataset.drop(columns=['attack_cat'])

# Display label distribution
print("Distribution:")
display(df_dataset["label"].value_counts())
# Out:
# Distribution:
# label
# 1    164673
# 0     93000
# Name: count, dtype: int64

# %%
# Parametri le SOM
som_sizes = [(10, 10),(20, 20),(30, 30),(40,40)]
learning_rate = 1.2
sigma = 1.5
sampling_fractions = [0.1, 0.3, 0.5, 0.7, 1]  # Diversi frazioni di campionamento

# %%
results = []

# Funzione wrapper per il parallelismo
def parallel_train_and_evaluate(train_idx, test_idx, som_shape, data, target, sigma, learning_rate):
    report, training_time, training_mem_usage, evaluating_time, eval_mem_usage, total_mem_usage = train_and_evaluate(train_idx, test_idx, data, target, som_shape, sigma, learning_rate)
    return report, training_time, training_mem_usage, evaluating_time, eval_mem_usage, total_mem_usage

def display_report_and_times(all_reports, all_training_times, all_training_mem_usages, all_evaluating_times, all_eval_mem_usages, all_total_mem_usages):
    print("\nAll Reports and Times for this SOM Shape:")
    
    for i, (report, train_time, train_mem_usage, eval_time, eval_mem_usage, total_mem_usage) in enumerate(zip(all_reports, all_training_times, all_training_mem_usages, all_evaluating_times, all_eval_mem_usages, all_total_mem_usages)):
        print(f"\nReport for Fold {i+1}:")
        for label, metrics in report.items():
            if isinstance(metrics, dict):
                print(f"\nLabel {label}:")
                for metric_name, metric_value in metrics.items():
                    print(f"  {metric_name.capitalize()}: {metric_value:.4f}")
            else:
                print(f"\n{label.capitalize()}: {metrics:.4f}")
        print(f"\nTraining Time: {train_time:.4f} seconds")
        print(f"Training Memory Usage: {format_memory_usage(train_mem_usage)}")
        print(f"Evaluating Time: {eval_time:.4f} seconds")
        print(f"Evaluating Memory Usage: {format_memory_usage(eval_mem_usage)}")
        print(f"Total Memory Usage: {format_memory_usage(total_mem_usage)}")

# Inizializzazione del KFold
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# Loop su diverse frazioni di campionamento
for frac in sampling_fractions:
    print(f"Evaluating for sampling fraction: {frac}")
    
    # Esegui campionamento casuale stratificato mantenendo le proporzioni delle classi
    with warnings.catch_warnings():
        warnings.simplefilter("ignore", DeprecationWarning)
        sampled_df = df_dataset.groupby("label", group_keys=False).apply(lambda x: x.sample(frac=frac, random_state=42))

    scaler = MinMaxScaler()
    data = scaler.fit_transform(sampled_df.iloc[:, :-1])
    target = sampled_df.iloc[:, -1].values

    # Loop su diverse dimensioni del SOM
    for som_shape in som_sizes:
        print(f"Evaluating for som_shape: {som_shape}")
        # Split del dataset con K-Fold e parallelismo
        parallel_results = Parallel(n_jobs=-1)(delayed(parallel_train_and_evaluate)(train_idx, test_idx, som_shape, data, target, sigma, learning_rate) for train_idx, test_idx in kf.split(data))
        
        reports, training_times, training_mem_usages, evaluating_times, eval_mem_usages, total_mem_usages = zip(*parallel_results)
        
        # Aggrega metriche dai report
        class_metrics = {}
        for report in reports:
            for key, metrics in report.items():
                if key.isdigit() or key in ['macro avg', 'weighted avg']:
                    if key not in class_metrics:
                        class_metrics[key] = {m: [] for m in metrics.keys() if m != 'support'}
                    for metric, value in metrics.items():
                        if metric != 'support':
                            class_metrics[key][metric].append(value)

        # Calcola medie e prepara output formattato
        averages = {key: {metric: np.mean(values) for metric, values in metrics.items()} for key, metrics in class_metrics.items()}

        # Calcola i tempi medi di training e valutazione e l'uso della memoria
        avg_training_time = np.mean(training_times)
        avg_training_mem_usage = np.mean(training_mem_usages)
        avg_evaluating_time = np.mean(evaluating_times)
        avg_eval_mem_usage = np.mean(eval_mem_usages)
        avg_total_mem_usage = np.mean(total_mem_usages)

        results.append((frac, som_shape, averages, avg_training_time, avg_training_mem_usage, avg_evaluating_time, avg_eval_mem_usage, avg_total_mem_usage, reports, training_times, training_mem_usages, evaluating_times, eval_mem_usages, total_mem_usages))

# Mostra i risultati
print("\nAverage Metrics Across All Folds:")
for result in results:
    frac, shape, metrics, avg_training_time, avg_training_mem_usage, avg_evaluating_time, avg_eval_mem_usage, avg_total_mem_usage, all_reports, all_training_times, all_training_mem_usages, all_evaluating_times, all_eval_mem_usages, all_total_mem_usages = result
    print("****************************")
    print(f"\nSampling Fraction: {frac}")
    print(f"SOM Shape: {shape}".upper())
    for class_id, class_metrics in metrics.items():
        print(f"\nClass {class_id}:")
        for metric, value in class_metrics.items():
            print(f"{metric}: {value:.4f}")

    # Mostra i tempi medi di training e valutazione e l'uso della memoria
    minutes_train, seconds_train = divmod(avg_training_time, 60)
    minutes_eval, seconds_eval = divmod(avg_evaluating_time, 60)
    print(f"Average Training Time: {int(minutes_train)} minutes and {seconds_train:.2f} seconds")
    print(f"Average Training Memory Usage: {format_memory_usage(avg_training_mem_usage)}")
    print(f"Average Evaluating Time: {int(minutes_eval)} minutes and {seconds_eval:.2f} seconds")
    print(f"Average Evaluating Memory Usage: {format_memory_usage(avg_eval_mem_usage)}")
    print(f"Average Total Memory Usage: {format_memory_usage(avg_total_mem_usage)}")
    print("---------------------------------------")
    display_report_and_times(all_reports, all_training_times, all_training_mem_usages, all_evaluating_times, all_eval_mem_usages, all_total_mem_usages)
# Out:
# Evaluating for sampling fraction: 0.1
# Evaluating for som_shape: (10, 10)
# Evaluating for som_shape: (20, 20)
# Evaluating for som_shape: (30, 30)
# Evaluating for sampling fraction: 0.3
# Evaluating for som_shape: (10, 10)
# Evaluating for som_shape: (20, 20)
# Evaluating for som_shape: (30, 30)
# Evaluating for sampling fraction: 0.5
# Evaluating for som_shape: (10, 10)
# Evaluating for som_shape: (20, 20)
# Evaluating for som_shape: (30, 30)
# Evaluating for sampling fraction: 0.7
# Evaluating for som_shape: (10, 10)
# Evaluating for som_shape: (20, 20)
# Evaluating for som_shape: (30, 30)
# Evaluating for sampling fraction: 0.9
# Evaluating for som_shape: (10, 10)
# Evaluating for som_shape: (20, 20)
# Evaluating for som_shape: (30, 30)
#
# Average Metrics Across All Folds:
# ****************************
#
# Sampling Fraction: 0.1
# SOM SHAPE: (10, 10)
#
# Class 0:
# precision: 0.9917
# recall: 0.7101
# f1-score: 0.8276
#
# Class 1:
# precision: 0.8589
# recall: 0.9966
# f1-score: 0.9227
#
# Class macro avg:
# precision: 0.9253
# recall: 0.8534
# f1-score: 0.8751
#
# Class weighted avg:
# precision: 0.9068
# recall: 0.8932
# f1-score: 0.8884
# Average Training Time: 0 minutes and 2.88 seconds
# Average Training Memory Usage: 0.31 MB
# Average Evaluating Time: 0 minutes and 1.39 seconds
# Average Evaluating Memory Usage: 0.77 MB
# Average Total Memory Usage: 1.09 MB
# ---------------------------------------
#
# All Reports and Times for this SOM Shape:
#
# Report for Fold 1:
#
# Label 0:
#   Precision: 0.9948
#   Recall: 0.7135
#   F1-score: 0.8310
#   Support: 1881.0000
#
# Label 1:
#   Precision: 0.8583
#   Recall: 0.9979
#   F1-score: 0.9229
#   Support: 3273.0000
#
# Accuracy: 0.8941
#
# Label macro avg:
#   Precision: 0.9266
#   Recall: 0.8557
#   F1-score: 0.8769
#   Support: 5154.0000
#
# Label weighted avg:
#   Precision: 0.9081
#   Recall: 0.8941
#   F1-score: 0.8893
#   Support: 5154.0000
#
# Training Time: 2.7403 seconds
# Training Memory Usage: 0.31 MB
# Evaluating Time: 1.3234 seconds
# Evaluating Memory Usage: 0.77 MB
# Total Memory Usage: 1.09 MB
#
# Report for Fold 2:
#
# Label 0:
#   Precision: 0.9940
#   Recall: 0.7151
#   F1-score: 0.8318
#   Support: 1846.0000
#
# Label 1:
#   Precision: 0.8625
#   Recall: 0.9976
#   F1-score: 0.9251
#   Support: 3308.0000
#
# Accuracy: 0.8964
#
# Label macro avg:
#   Precision: 0.9282
#   Recall: 0.8563
#   F1-score: 0.8785
#   Support: 5154.0000
#
# Label weighted avg:
#   Precision: 0.9096
#   Recall: 0.8964
#   F1-score: 0.8917
#   Support: 5154.0000
#
# Training Time: 2.8373 seconds
# Training Memory Usage: 0.31 MB
# Evaluating Time: 1.3296 seconds
# Evaluating Memory Usage: 0.77 MB
# Total Memory Usage: 1.09 MB
#
# Report for Fold 3:
#
# Label 0:
#   Precision: 0.9948
#   Recall: 0.7177
#   F1-score: 0.8339
#   Support: 1860.0000
#
# Label 1:
#   Precision: 0.8622
#   Recall: 0.9979
#   F1-score: 0.9251
#   Support: 3293.0000
#
# Accuracy: 0.8968
#
# Label macro avg:
#   Precision: 0.9285
#   Recall: 0.8578
#   F1-score: 0.8795
#   Support: 5153.0000
#
# Label weighted avg:
#   Precision: 0.9101
#   Recall: 0.8968
#   F1-score: 0.8922
#   Support: 5153.0000
#
# Training Time: 3.1312 seconds
# Training Memory Usage: 0.31 MB
# Evaluating Time: 1.6136 seconds
# Evaluating Memory Usage: 0.77 MB
# Total Memory Usage: 1.09 MB
#
# Report for Fold 4:
#
# Label 0:
#   Precision: 0.9782
#   Recall: 0.7098
#   F1-score: 0.8227
#   Support: 1899.0000
#
# Label 1:
#   Precision: 0.8540
#   Recall: 0.9908
#   F1-score: 0.9173
#   Support: 3254.0000
#
# Accuracy: 0.8873
#
# Label macro avg:
#   Precision: 0.9161
#   Recall: 0.8503
#   F1-score: 0.8700
#   Support: 5153.0000
#
# Label weighted avg:
#   Precision: 0.8998
#   Recall: 0.8873
#   F1-score: 0.8825
#   Support: 5153.0000
#
# Training Time: 2.7974 seconds
# Training Memory Usage: 0.31 MB
# Evaluating Time: 1.3404 seconds
# Evaluating Memory Usage: 0.77 MB
# Total Memory Usage: 1.09 MB
#
# Report for Fold 5:
#
# Label 0:
#   Precision: 0.9968
#   Recall: 0.6946
#   F1-score: 0.8187
#   Support: 1814.0000
#
# Label 1:
#   Precision: 0.8575
#   Recall: 0.9988
#   F1-score: 0.9228
#   Support: 3339.0000
#
# Accuracy: 0.8917
#
# Label macro avg:
#   Precision: 0.9272
#   Recall: 0.8467
#   F1-score: 0.8708
#   Support: 5153.0000
#
# Label weighted avg:
#   Precision: 0.9066
#   Recall: 0.8917
#   F1-score: 0.8862
#   Support: 5153.0000
#
# Training Time: 2.8982 seconds
# Training Memory Usage: 0.31 MB
# Evaluating Time: 1.3678 seconds
# Evaluating Memory Usage: 0.77 MB
# Total Memory Usage: 1.09 MB
# ****************************
#
# Sampling Fraction: 0.1
# SOM SHAPE: (20, 20)
#
# Class 0:
# precision: 0.9731
# recall: 0.7246
# f1-score: 0.8306
#
# Class 1:
# precision: 0.8641
# recall: 0.9887
# f1-score: 0.9222
#
# Class macro avg:
# precision: 0.9186
# recall: 0.8567
# f1-score: 0.8764
#
# Class weighted avg:
# precision: 0.9035
# recall: 0.8934
# f1-score: 0.8892
# Average Training Time: 0 minutes and 5.71 seconds
# Average Training Memory Usage: 0.54 MB
# Average Evaluating Time: 0 minutes and 2.85 seconds
# Average Evaluating Memory Usage: 1.08 MB
# Average Total Memory Usage: 1.62 MB
# ---------------------------------------
#
# All Reports and Times for this SOM Shape:
#
# Report for Fold 1:
#
# Label 0:
#   Precision: 0.9786
#   Recall: 0.7294
#   F1-score: 0.8358
#   Support: 1881.0000
#
# Label 1:
#   Precision: 0.8643
#   Recall: 0.9908
#   F1-score: 0.9233
#   Support: 3273.0000
#
# Accuracy: 0.8954
#
# Label macro avg:
#   Precision: 0.9215
#   Recall: 0.8601
#   F1-score: 0.8795
#   Support: 5154.0000
#
# Label weighted avg:
#   Precision: 0.9060
#   Recall: 0.8954
#   F1-score: 0.8914
#   Support: 5154.0000
#
# Training Time: 5.2233 seconds
# Training Memory Usage: 0.54 MB
# Evaluating Time: 2.7660 seconds
# Evaluating Memory Usage: 1.08 MB
# Total Memory Usage: 1.62 MB
#
# Report for Fold 2:
#
# Label 0:
#   Precision: 0.9630
#   Recall: 0.7324
#   F1-score: 0.8320
#   Support: 1846.0000
#
# Label 1:
#   Precision: 0.8683
#   Recall: 0.9843
#   F1-score: 0.9226
#   Support: 3308.0000
#
# Accuracy: 0.8941
#
# Label macro avg:
#   Precision: 0.9156
#   Recall: 0.8583
#   F1-score: 0.8773
#   Support: 5154.0000
#
# Label weighted avg:
#   Precision: 0.9022
#   Recall: 0.8941
#   F1-score: 0.8902
#   Support: 5154.0000
#
# Training Time: 5.8997 seconds
# Training Memory Usage: 0.54 MB
# Evaluating Time: 2.7868 seconds
# Evaluating Memory Usage: 1.08 MB
# Total Memory Usage: 1.62 MB
#
# Report for Fold 3:
#
# Label 0:
#   Precision: 0.9715
#   Recall: 0.7333
#   F1-score: 0.8358
#   Support: 1860.0000
#
# Label 1:
#   Precision: 0.8677
#   Recall: 0.9879
#   F1-score: 0.9239
#   Support: 3293.0000
#
# Accuracy: 0.8960
#
# Label macro avg:
#   Precision: 0.9196
#   Recall: 0.8606
#   F1-score: 0.8798
#   Support: 5153.0000
#
# Label weighted avg:
#   Precision: 0.9052
#   Recall: 0.8960
#   F1-score: 0.8921
#   Support: 5153.0000
#
# Training Time: 5.9186 seconds
# Training Memory Usage: 0.54 MB
# Evaluating Time: 2.9992 seconds
# Evaluating Memory Usage: 1.08 MB
# Total Memory Usage: 1.62 MB
#
# Report for Fold 4:
#
# Label 0:
#   Precision: 0.9906
#   Recall: 0.7183
#   F1-score: 0.8327
#   Support: 1899.0000
#
# Label 1:
#   Precision: 0.8583
#   Recall: 0.9960
#   F1-score: 0.9220
#   Support: 3254.0000
#
# Accuracy: 0.8937
#
# Label macro avg:
#   Precision: 0.9244
#   Recall: 0.8571
#   F1-score: 0.8774
#   Support: 5153.0000
#
# Label weighted avg:
#   Precision: 0.9071
#   Recall: 0.8937
#   F1-score: 0.8891
#   Support: 5153.0000
#
# Training Time: 6.2036 seconds
# Training Memory Usage: 0.54 MB
# Evaluating Time: 2.9741 seconds
# Evaluating Memory Usage: 1.08 MB
# Total Memory Usage: 1.62 MB
#
# Report for Fold 5:
#
# Label 0:
#   Precision: 0.9619
#   Recall: 0.7095
#   F1-score: 0.8166
#   Support: 1814.0000
#
# Label 1:
#   Precision: 0.8619
#   Recall: 0.9847
#   F1-score: 0.9192
#   Support: 3339.0000
#
# Accuracy: 0.8878
#
# Label macro avg:
#   Precision: 0.9119
#   Recall: 0.8471
#   F1-score: 0.8679
#   Support: 5153.0000
#
# Label weighted avg:
#   Precision: 0.8971
#   Recall: 0.8878
#   F1-score: 0.8831
#   Support: 5153.0000
#
# Training Time: 5.2929 seconds
# Training Memory Usage: 0.54 MB
# Evaluating Time: 2.7149 seconds
# Evaluating Memory Usage: 1.08 MB
# Total Memory Usage: 1.62 MB
# ****************************
#
# Sampling Fraction: 0.1
# SOM SHAPE: (30, 30)
#
# Class 0:
# precision: 0.9290
# recall: 0.7595
# f1-score: 0.8355
#
# Class 1:
# precision: 0.8770
# recall: 0.9672
# f1-score: 0.9198
#
# Class macro avg:
# precision: 0.9030
# recall: 0.8633
# f1-score: 0.8777
#
# Class weighted avg:
# precision: 0.8958
# recall: 0.8922
# f1-score: 0.8894
# Average Training Time: 0 minutes and 10.17 seconds
# Average Training Memory Usage: 0.95 MB
# Average Evaluating Time: 0 minutes and 4.85 seconds
# Average Evaluating Memory Usage: 1.55 MB
# Average Total Memory Usage: 2.50 MB
# ---------------------------------------
#
# All Reports and Times for this SOM Shape:
#
# Report for Fold 1:
#
# Label 0:
#   Precision: 0.9328
#   Recall: 0.7597
#   F1-score: 0.8374
#   Support: 1881.0000
#
# Label 1:
#   Precision: 0.8752
#   Recall: 0.9685
#   F1-score: 0.9195
#   Support: 3273.0000
#
# Accuracy: 0.8923
#
# Label macro avg:
#   Precision: 0.9040
#   Recall: 0.8641
#   F1-score: 0.8784
#   Support: 5154.0000
#
# Label weighted avg:
#   Precision: 0.8962
#   Recall: 0.8923
#   F1-score: 0.8895
#   Support: 5154.0000
#
# Training Time: 9.7825 seconds
# Training Memory Usage: 0.95 MB
# Evaluating Time: 4.9856 seconds
# Evaluating Memory Usage: 1.55 MB
# Total Memory Usage: 2.50 MB
#
# Report for Fold 2:
#
# Label 0:
#   Precision: 0.9192
#   Recall: 0.7703
#   F1-score: 0.8382
#   Support: 1846.0000
#
# Label 1:
#   Precision: 0.8825
#   Recall: 0.9622
#   F1-score: 0.9206
#   Support: 3308.0000
#
# Accuracy: 0.8935
#
# Label macro avg:
#   Precision: 0.9008
#   Recall: 0.8663
#   F1-score: 0.8794
#   Support: 5154.0000
#
# Label weighted avg:
#   Precision: 0.8956
#   Recall: 0.8935
#   F1-score: 0.8911
#   Support: 5154.0000
#
# Training Time: 10.2880 seconds
# Training Memory Usage: 0.95 MB
# Evaluating Time: 4.5616 seconds
# Evaluating Memory Usage: 1.55 MB
# Total Memory Usage: 2.50 MB
#
# Report for Fold 3:
#
# Label 0:
#   Precision: 0.9162
#   Recall: 0.7823
#   F1-score: 0.8440
#   Support: 1860.0000
#
# Label 1:
#   Precision: 0.8864
#   Recall: 0.9596
#   F1-score: 0.9216
#   Support: 3293.0000
#
# Accuracy: 0.8956
#
# Label macro avg:
#   Precision: 0.9013
#   Recall: 0.8709
#   F1-score: 0.8828
#   Support: 5153.0000
#
# Label weighted avg:
#   Precision: 0.8972
#   Recall: 0.8956
#   F1-score: 0.8935
#   Support: 5153.0000
#
# Training Time: 10.5466 seconds
# Training Memory Usage: 0.95 MB
# Evaluating Time: 5.0823 seconds
# Evaluating Memory Usage: 1.57 MB
# Total Memory Usage: 2.52 MB
#
# Report for Fold 4:
#
# Label 0:
#   Precision: 0.9572
#   Recall: 0.7536
#   F1-score: 0.8433
#   Support: 1899.0000
#
# Label 1:
#   Precision: 0.8721
#   Recall: 0.9803
#   F1-score: 0.9230
#   Support: 3254.0000
#
# Accuracy: 0.8968
#
# Label macro avg:
#   Precision: 0.9146
#   Recall: 0.8669
#   F1-score: 0.8831
#   Support: 5153.0000
#
# Label weighted avg:
#   Precision: 0.9034
#   Recall: 0.8968
#   F1-score: 0.8936
#   Support: 5153.0000
#
# Training Time: 9.8371 seconds
# Training Memory Usage: 0.95 MB
# Evaluating Time: 4.5892 seconds
# Evaluating Memory Usage: 1.55 MB
# Total Memory Usage: 2.50 MB
#
# Report for Fold 5:
#
# Label 0:
#   Precision: 0.9196
#   Recall: 0.7315
#   F1-score: 0.8149
#   Support: 1814.0000
#
# Label 1:
#   Precision: 0.8687
#   Recall: 0.9653
#   F1-score: 0.9145
#   Support: 3339.0000
#
# Accuracy: 0.8830
#
# Label macro avg:
#   Precision: 0.8942
#   Recall: 0.8484
#   F1-score: 0.8647
#   Support: 5153.0000
#
# Label weighted avg:
#   Precision: 0.8866
#   Recall: 0.8830
#   F1-score: 0.8794
#   Support: 5153.0000
#
# Training Time: 10.4183 seconds
# Training Memory Usage: 0.95 MB
# Evaluating Time: 5.0289 seconds
# Evaluating Memory Usage: 1.54 MB
# Total Memory Usage: 2.49 MB
# ****************************
#
# Sampling Fraction: 0.3
# SOM SHAPE: (10, 10)
#
# Class 0:
# precision: 0.9957
# recall: 0.7071
# f1-score: 0.8269
#
# Class 1:
# precision: 0.8578
# recall: 0.9983
# f1-score: 0.9227
#
# Class macro avg:
# precision: 0.9268
# recall: 0.8527
# f1-score: 0.8748
#
# Class weighted avg:
# precision: 0.9076
# recall: 0.8932
# f1-score: 0.8881
# Average Training Time: 0 minutes and 8.51 seconds
# Average Training Memory Usage: 0.95 MB
# Average Evaluating Time: 0 minutes and 4.04 seconds
# Average Evaluating Memory Usage: 2.05 MB
# Average Total Memory Usage: 3.00 MB
# ---------------------------------------
#
# All Reports and Times for this SOM Shape:
#
# Report for Fold 1:
#
# Label 0:
#   Precision: 0.9946
#   Recall: 0.7028
#   F1-score: 0.8236
#   Support: 5495.0000
#
# Label 1:
#   Precision: 0.8590
#   Recall: 0.9979
#   F1-score: 0.9232
#   Support: 9966.0000
#
# Accuracy: 0.8930
#
# Label macro avg:
#   Precision: 0.9268
#   Recall: 0.8504
#   F1-score: 0.8734
#   Support: 15461.0000
#
# Label weighted avg:
#   Precision: 0.9072
#   Recall: 0.8930
#   F1-score: 0.8878
#   Support: 15461.0000
#
# Training Time: 8.5766 seconds
# Training Memory Usage: 0.95 MB
# Evaluating Time: 4.0414 seconds
# Evaluating Memory Usage: 2.05 MB
# Total Memory Usage: 3.00 MB
#
# Report for Fold 2:
#
# Label 0:
#   Precision: 0.9942
#   Recall: 0.7176
#   F1-score: 0.8336
#   Support: 5496.0000
#
# Label 1:
#   Precision: 0.8650
#   Recall: 0.9977
#   F1-score: 0.9266
#   Support: 9965.0000
#
# Accuracy: 0.8981
#
# Label macro avg:
#   Precision: 0.9296
#   Recall: 0.8577
#   F1-score: 0.8801
#   Support: 15461.0000
#
# Label weighted avg:
#   Precision: 0.9109
#   Recall: 0.8981
#   F1-score: 0.8935
#   Support: 15461.0000
#
# Training Time: 8.5833 seconds
# Training Memory Usage: 0.95 MB
# Evaluating Time: 4.1274 seconds
# Evaluating Memory Usage: 2.05 MB
# Total Memory Usage: 3.00 MB
#
# Report for Fold 3:
#
# Label 0:
#   Precision: 0.9947
#   Recall: 0.7078
#   F1-score: 0.8271
#   Support: 5619.0000
#
# Label 1:
#   Precision: 0.8567
#   Recall: 0.9979
#   F1-score: 0.9219
#   Support: 9841.0000
#
# Accuracy: 0.8924
#
# Label macro avg:
#   Precision: 0.9257
#   Recall: 0.8528
#   F1-score: 0.8745
#   Support: 15460.0000
#
# Label weighted avg:
#   Precision: 0.9069
#   Recall: 0.8924
#   F1-score: 0.8875
#   Support: 15460.0000
#
# Training Time: 8.3295 seconds
# Training Memory Usage: 0.95 MB
# Evaluating Time: 3.9705 seconds
# Evaluating Memory Usage: 2.06 MB
# Total Memory Usage: 3.00 MB
#
# Report for Fold 4:
#
# Label 0:
#   Precision: 0.9985
#   Recall: 0.7111
#   F1-score: 0.8306
#   Support: 5559.0000
#
# Label 1:
#   Precision: 0.8604
#   Recall: 0.9994
#   F1-score: 0.9247
#   Support: 9901.0000
#
# Accuracy: 0.8957
#
# Label macro avg:
#   Precision: 0.9294
#   Recall: 0.8552
#   F1-score: 0.8777
#   Support: 15460.0000
#
# Label weighted avg:
#   Precision: 0.9100
#   Recall: 0.8957
#   F1-score: 0.8909
#   Support: 15460.0000
#
# Training Time: 8.3761 seconds
# Training Memory Usage: 0.95 MB
# Evaluating Time: 3.9291 seconds
# Evaluating Memory Usage: 2.05 MB
# Total Memory Usage: 3.00 MB
#
# Report for Fold 5:
#
# Label 0:
#   Precision: 0.9965
#   Recall: 0.6962
#   F1-score: 0.8197
#   Support: 5731.0000
#
# Label 1:
#   Precision: 0.8480
#   Recall: 0.9986
#   F1-score: 0.9172
#   Support: 9729.0000
#
# Accuracy: 0.8865
#
# Label macro avg:
#   Precision: 0.9223
#   Recall: 0.8474
#   F1-score: 0.8684
#   Support: 15460.0000
#
# Label weighted avg:
#   Precision: 0.9031
#   Recall: 0.8865
#   F1-score: 0.8810
#   Support: 15460.0000
#
# Training Time: 8.6981 seconds
# Training Memory Usage: 0.95 MB
# Evaluating Time: 4.1315 seconds
# Evaluating Memory Usage: 2.05 MB
# Total Memory Usage: 2.99 MB
# ****************************
#
# Sampling Fraction: 0.3
# SOM SHAPE: (20, 20)
#
# Class 0:
# precision: 0.9975
# recall: 0.7092
# f1-score: 0.8289
#
# Class 1:
# precision: 0.8587
# recall: 0.9990
# f1-score: 0.9236
#
# Class macro avg:
# precision: 0.9281
# recall: 0.8541
# f1-score: 0.8763
#
# Class weighted avg:
# precision: 0.9089
# recall: 0.8943
# f1-score: 0.8894
# Average Training Time: 0 minutes and 17.39 seconds
# Average Training Memory Usage: 0.95 MB
# Average Evaluating Time: 0 minutes and 8.57 seconds
# Average Evaluating Memory Usage: 2.36 MB
# Average Total Memory Usage: 3.30 MB
# ---------------------------------------
#
# All Reports and Times for this SOM Shape:
#
# Report for Fold 1:
#
# Label 0:
#   Precision: 0.9972
#   Recall: 0.7068
#   F1-score: 0.8273
#   Support: 5495.0000
#
# Label 1:
#   Precision: 0.8607
#   Recall: 0.9989
#   F1-score: 0.9247
#   Support: 9966.0000
#
# Accuracy: 0.8951
#
# Label macro avg:
#   Precision: 0.9289
#   Recall: 0.8529
#   F1-score: 0.8760
#   Support: 15461.0000
#
# Label weighted avg:
#   Precision: 0.9092
#   Recall: 0.8951
#   F1-score: 0.8901
#   Support: 15461.0000
#
# Training Time: 17.8712 seconds
# Training Memory Usage: 0.95 MB
# Evaluating Time: 8.6629 seconds
# Evaluating Memory Usage: 2.36 MB
# Total Memory Usage: 3.30 MB
#
# Report for Fold 2:
#
# Label 0:
#   Precision: 0.9970
#   Recall: 0.7209
#   F1-score: 0.8367
#   Support: 5496.0000
#
# Label 1:
#   Precision: 0.8665
#   Recall: 0.9988
#   F1-score: 0.9279
#   Support: 9965.0000
#
# Accuracy: 0.9000
#
# Label macro avg:
#   Precision: 0.9317
#   Recall: 0.8598
#   F1-score: 0.8823
#   Support: 15461.0000
#
# Label weighted avg:
#   Precision: 0.9129
#   Recall: 0.9000
#   F1-score: 0.8955
#   Support: 15461.0000
#
# Training Time: 16.8863 seconds
# Training Memory Usage: 0.95 MB
# Evaluating Time: 8.3953 seconds
# Evaluating Memory Usage: 2.36 MB
# Total Memory Usage: 3.31 MB
#
# Report for Fold 3:
#
# Label 0:
#   Precision: 0.9972
#   Recall: 0.7090
#   F1-score: 0.8288
#   Support: 5619.0000
#
# Label 1:
#   Precision: 0.8574
#   Recall: 0.9989
#   F1-score: 0.9227
#   Support: 9841.0000
#
# Accuracy: 0.8935
#
# Label macro avg:
#   Precision: 0.9273
#   Recall: 0.8540
#   F1-score: 0.8758
#   Support: 15460.0000
#
# Label weighted avg:
#   Precision: 0.9082
#   Recall: 0.8935
#   F1-score: 0.8886
#   Support: 15460.0000
#
# Training Time: 17.3939 seconds
# Training Memory Usage: 0.95 MB
# Evaluating Time: 8.6680 seconds
# Evaluating Memory Usage: 2.36 MB
# Total Memory Usage: 3.30 MB
#
# Report for Fold 4:
#
# Label 0:
#   Precision: 0.9995
#   Recall: 0.7129
#   F1-score: 0.8322
#   Support: 5559.0000
#
# Label 1:
#   Precision: 0.8612
#   Recall: 0.9998
#   F1-score: 0.9253
#   Support: 9901.0000
#
# Accuracy: 0.8966
#
# Label macro avg:
#   Precision: 0.9303
#   Recall: 0.8563
#   F1-score: 0.8788
#   Support: 15460.0000
#
# Label weighted avg:
#   Precision: 0.9109
#   Recall: 0.8966
#   F1-score: 0.8918
#   Support: 15460.0000
#
# Training Time: 17.4393 seconds
# Training Memory Usage: 0.95 MB
# Evaluating Time: 8.4864 seconds
# Evaluating Memory Usage: 2.36 MB
# Total Memory Usage: 3.31 MB
#
# Report for Fold 5:
#
# Label 0:
#   Precision: 0.9965
#   Recall: 0.6962
#   F1-score: 0.8197
#   Support: 5731.0000
#
# Label 1:
#   Precision: 0.8480
#   Recall: 0.9986
#   F1-score: 0.9172
#   Support: 9729.0000
#
# Accuracy: 0.8865
#
# Label macro avg:
#   Precision: 0.9223
#   Recall: 0.8474
#   F1-score: 0.8684
#   Support: 15460.0000
#
# Label weighted avg:
#   Precision: 0.9031
#   Recall: 0.8865
#   F1-score: 0.8810
#   Support: 15460.0000
#
# Training Time: 17.3832 seconds
# Training Memory Usage: 0.95 MB
# Evaluating Time: 8.6274 seconds
# Evaluating Memory Usage: 2.36 MB
# Total Memory Usage: 3.31 MB
# ****************************
#
# Sampling Fraction: 0.3
# SOM SHAPE: (30, 30)
#
# Class 0:
# precision: 0.9689
# recall: 0.7318
# f1-score: 0.8338
#
# Class 1:
# precision: 0.8669
# recall: 0.9867
# f1-score: 0.9229
#
# Class macro avg:
# precision: 0.9179
# recall: 0.8592
# f1-score: 0.8783
#
# Class weighted avg:
# precision: 0.9037
# recall: 0.8947
# f1-score: 0.8907
# Average Training Time: 0 minutes and 30.18 seconds
# Average Training Memory Usage: 1.26 MB
# Average Evaluating Time: 0 minutes and 15.19 seconds
# Average Evaluating Memory Usage: 2.85 MB
# Average Total Memory Usage: 4.11 MB
# ---------------------------------------
#
# All Reports and Times for this SOM Shape:
#
# Report for Fold 1:
#
# Label 0:
#   Precision: 0.9739
#   Recall: 0.7261
#   F1-score: 0.8319
#   Support: 5495.0000
#
# Label 1:
#   Precision: 0.8676
#   Recall: 0.9893
#   F1-score: 0.9244
#   Support: 9966.0000
#
# Accuracy: 0.8957
#
# Label macro avg:
#   Precision: 0.9207
#   Recall: 0.8577
#   F1-score: 0.8782
#   Support: 15461.0000
#
# Label weighted avg:
#   Precision: 0.9054
#   Recall: 0.8957
#   F1-score: 0.8916
#   Support: 15461.0000
#
# Training Time: 29.7995 seconds
# Training Memory Usage: 1.26 MB
# Evaluating Time: 15.2251 seconds
# Evaluating Memory Usage: 2.85 MB
# Total Memory Usage: 4.11 MB
#
# Report for Fold 2:
#
# Label 0:
#   Precision: 0.9719
#   Recall: 0.7431
#   F1-score: 0.8422
#   Support: 5496.0000
#
# Label 1:
#   Precision: 0.8746
#   Recall: 0.9882
#   F1-score: 0.9279
#   Support: 9965.0000
#
# Accuracy: 0.9010
#
# Label macro avg:
#   Precision: 0.9233
#   Recall: 0.8656
#   F1-score: 0.8851
#   Support: 15461.0000
#
# Label weighted avg:
#   Precision: 0.9092
#   Recall: 0.9010
#   F1-score: 0.8975
#   Support: 15461.0000
#
# Training Time: 30.6695 seconds
# Training Memory Usage: 1.26 MB
# Evaluating Time: 15.6246 seconds
# Evaluating Memory Usage: 2.85 MB
# Total Memory Usage: 4.11 MB
#
# Report for Fold 3:
#
# Label 0:
#   Precision: 0.9626
#   Recall: 0.7368
#   F1-score: 0.8347
#   Support: 5619.0000
#
# Label 1:
#   Precision: 0.8675
#   Recall: 0.9836
#   F1-score: 0.9219
#   Support: 9841.0000
#
# Accuracy: 0.8939
#
# Label macro avg:
#   Precision: 0.9150
#   Recall: 0.8602
#   F1-score: 0.8783
#   Support: 15460.0000
#
# Label weighted avg:
#   Precision: 0.9020
#   Recall: 0.8939
#   F1-score: 0.8902
#   Support: 15460.0000
#
# Training Time: 30.2956 seconds
# Training Memory Usage: 1.26 MB
# Evaluating Time: 15.9229 seconds
# Evaluating Memory Usage: 2.85 MB
# Total Memory Usage: 4.11 MB
#
# Report for Fold 4:
#
# Label 0:
#   Precision: 0.9666
#   Recall: 0.7347
#   F1-score: 0.8348
#   Support: 5559.0000
#
# Label 1:
#   Precision: 0.8687
#   Recall: 0.9858
#   F1-score: 0.9235
#   Support: 9901.0000
#
# Accuracy: 0.8955
#
# Label macro avg:
#   Precision: 0.9177
#   Recall: 0.8602
#   F1-score: 0.8792
#   Support: 15460.0000
#
# Label weighted avg:
#   Precision: 0.9039
#   Recall: 0.8955
#   F1-score: 0.8916
#   Support: 15460.0000
#
# Training Time: 31.5412 seconds
# Training Memory Usage: 1.26 MB
# Evaluating Time: 14.6425 seconds
# Evaluating Memory Usage: 2.85 MB
# Total Memory Usage: 4.11 MB
#
# Report for Fold 5:
#
# Label 0:
#   Precision: 0.9694
#   Recall: 0.7182
#   F1-score: 0.8251
#   Support: 5731.0000
#
# Label 1:
#   Precision: 0.8560
#   Recall: 0.9866
#   F1-score: 0.9167
#   Support: 9729.0000
#
# Accuracy: 0.8871
#
# Label macro avg:
#   Precision: 0.9127
#   Recall: 0.8524
#   F1-score: 0.8709
#   Support: 15460.0000
#
# Label weighted avg:
#   Precision: 0.8980
#   Recall: 0.8871
#   F1-score: 0.8827
#   Support: 15460.0000
#
# Training Time: 28.6051 seconds
# Training Memory Usage: 1.26 MB
# Evaluating Time: 14.5563 seconds
# Evaluating Memory Usage: 2.85 MB
# Total Memory Usage: 4.11 MB
# ****************************
#
# Sampling Fraction: 0.5
# SOM SHAPE: (10, 10)
#
# Class 0:
# precision: 0.9952
# recall: 0.7066
# f1-score: 0.8264
#
# Class 1:
# precision: 0.8576
# recall: 0.9981
# f1-score: 0.9225
#
# Class macro avg:
# precision: 0.9264
# recall: 0.8523
# f1-score: 0.8745
#
# Class weighted avg:
# precision: 0.9073
# recall: 0.8929
# f1-score: 0.8878
# Average Training Time: 0 minutes and 14.36 seconds
# Average Training Memory Usage: 1.58 MB
# Average Evaluating Time: 0 minutes and 6.74 seconds
# Average Evaluating Memory Usage: 3.33 MB
# Average Total Memory Usage: 4.90 MB
# ---------------------------------------
#
# All Reports and Times for this SOM Shape:
#
# Report for Fold 1:
#
# Label 0:
#   Precision: 0.9966
#   Recall: 0.7150
#   F1-score: 0.8326
#   Support: 9413.0000
#
# Label 1:
#   Precision: 0.8589
#   Recall: 0.9986
#   F1-score: 0.9235
#   Support: 16355.0000
#
# Accuracy: 0.8950
#
# Label macro avg:
#   Precision: 0.9277
#   Recall: 0.8568
#   F1-score: 0.8781
#   Support: 25768.0000
#
# Label weighted avg:
#   Precision: 0.9092
#   Recall: 0.8950
#   F1-score: 0.8903
#   Support: 25768.0000
#
# Training Time: 14.3553 seconds
# Training Memory Usage: 1.58 MB
# Evaluating Time: 6.6856 seconds
# Evaluating Memory Usage: 3.33 MB
# Total Memory Usage: 4.91 MB
#
# Report for Fold 2:
#
# Label 0:
#   Precision: 0.9959
#   Recall: 0.7043
#   F1-score: 0.8251
#   Support: 9203.0000
#
# Label 1:
#   Precision: 0.8587
#   Recall: 0.9984
#   F1-score: 0.9233
#   Support: 16564.0000
#
# Accuracy: 0.8934
#
# Label macro avg:
#   Precision: 0.9273
#   Recall: 0.8514
#   F1-score: 0.8742
#   Support: 25767.0000
#
# Label weighted avg:
#   Precision: 0.9077
#   Recall: 0.8934
#   F1-score: 0.8882
#   Support: 25767.0000
#
# Training Time: 15.0017 seconds
# Training Memory Usage: 1.58 MB
# Evaluating Time: 6.9995 seconds
# Evaluating Memory Usage: 3.33 MB
# Total Memory Usage: 4.90 MB
#
# Report for Fold 3:
#
# Label 0:
#   Precision: 0.9974
#   Recall: 0.7033
#   F1-score: 0.8249
#   Support: 9373.0000
#
# Label 1:
#   Precision: 0.8548
#   Recall: 0.9990
#   F1-score: 0.9213
#   Support: 16394.0000
#
# Accuracy: 0.8914
#
# Label macro avg:
#   Precision: 0.9261
#   Recall: 0.8511
#   F1-score: 0.8731
#   Support: 25767.0000
#
# Label weighted avg:
#   Precision: 0.9067
#   Recall: 0.8914
#   F1-score: 0.8862
#   Support: 25767.0000
#
# Training Time: 14.1550 seconds
# Training Memory Usage: 1.58 MB
# Evaluating Time: 6.6348 seconds
# Evaluating Memory Usage: 3.33 MB
# Total Memory Usage: 4.90 MB
#
# Report for Fold 4:
#
# Label 0:
#   Precision: 0.9968
#   Recall: 0.7054
#   F1-score: 0.8262
#   Support: 9146.0000
#
# Label 1:
#   Precision: 0.8604
#   Recall: 0.9987
#   F1-score: 0.9244
#   Support: 16621.0000
#
# Accuracy: 0.8946
#
# Label macro avg:
#   Precision: 0.9286
#   Recall: 0.8521
#   F1-score: 0.8753
#   Support: 25767.0000
#
# Label weighted avg:
#   Precision: 0.9088
#   Recall: 0.8946
#   F1-score: 0.8895
#   Support: 25767.0000
#
# Training Time: 14.2986 seconds
# Training Memory Usage: 1.58 MB
# Evaluating Time: 6.7132 seconds
# Evaluating Memory Usage: 3.33 MB
# Total Memory Usage: 4.90 MB
#
# Report for Fold 5:
#
# Label 0:
#   Precision: 0.9892
#   Recall: 0.7050
#   F1-score: 0.8232
#   Support: 9365.0000
#
# Label 1:
#   Precision: 0.8553
#   Recall: 0.9956
#   F1-score: 0.9201
#   Support: 16402.0000
#
# Accuracy: 0.8900
#
# Label macro avg:
#   Precision: 0.9222
#   Recall: 0.8503
#   F1-score: 0.8717
#   Support: 25767.0000
#
# Label weighted avg:
#   Precision: 0.9040
#   Recall: 0.8900
#   F1-score: 0.8849
#   Support: 25767.0000
#
# Training Time: 14.0086 seconds
# Training Memory Usage: 1.58 MB
# Evaluating Time: 6.6575 seconds
# Evaluating Memory Usage: 3.33 MB
# Total Memory Usage: 4.90 MB
# ****************************
#
# Sampling Fraction: 0.5
# SOM SHAPE: (20, 20)
#
# Class 0:
# precision: 0.9923
# recall: 0.7116
# f1-score: 0.8288
#
# Class 1:
# precision: 0.8596
# recall: 0.9969
# f1-score: 0.9231
#
# Class macro avg:
# precision: 0.9259
# recall: 0.8542
# f1-score: 0.8760
#
# Class weighted avg:
# precision: 0.9075
# recall: 0.8939
# f1-score: 0.8891
# Average Training Time: 0 minutes and 28.49 seconds
# Average Training Memory Usage: 1.58 MB
# Average Evaluating Time: 0 minutes and 14.16 seconds
# Average Evaluating Memory Usage: 3.64 MB
# Average Total Memory Usage: 5.21 MB
# ---------------------------------------
#
# All Reports and Times for this SOM Shape:
#
# Report for Fold 1:
#
# Label 0:
#   Precision: 0.9924
#   Recall: 0.7173
#   F1-score: 0.8327
#   Support: 9413.0000
#
# Label 1:
#   Precision: 0.8597
#   Recall: 0.9968
#   F1-score: 0.9232
#   Support: 16355.0000
#
# Accuracy: 0.8947
#
# Label macro avg:
#   Precision: 0.9260
#   Recall: 0.8571
#   F1-score: 0.8779
#   Support: 25768.0000
#
# Label weighted avg:
#   Precision: 0.9081
#   Recall: 0.8947
#   F1-score: 0.8901
#   Support: 25768.0000
#
# Training Time: 29.8303 seconds
# Training Memory Usage: 1.58 MB
# Evaluating Time: 14.7751 seconds
# Evaluating Memory Usage: 3.64 MB
# Total Memory Usage: 5.22 MB
#
# Report for Fold 2:
#
# Label 0:
#   Precision: 0.9912
#   Recall: 0.7115
#   F1-score: 0.8284
#   Support: 9203.0000
#
# Label 1:
#   Precision: 0.8614
#   Recall: 0.9965
#   F1-score: 0.9241
#   Support: 16564.0000
#
# Accuracy: 0.8947
#
# Label macro avg:
#   Precision: 0.9263
#   Recall: 0.8540
#   F1-score: 0.8762
#   Support: 25767.0000
#
# Label weighted avg:
#   Precision: 0.9078
#   Recall: 0.8947
#   F1-score: 0.8899
#   Support: 25767.0000
#
# Training Time: 29.0012 seconds
# Training Memory Usage: 1.58 MB
# Evaluating Time: 14.0550 seconds
# Evaluating Memory Usage: 3.63 MB
# Total Memory Usage: 5.21 MB
#
# Report for Fold 3:
#
# Label 0:
#   Precision: 0.9928
#   Recall: 0.7108
#   F1-score: 0.8285
#   Support: 9373.0000
#
# Label 1:
#   Precision: 0.8577
#   Recall: 0.9971
#   F1-score: 0.9222
#   Support: 16394.0000
#
# Accuracy: 0.8929
#
# Label macro avg:
#   Precision: 0.9253
#   Recall: 0.8539
#   F1-score: 0.8753
#   Support: 25767.0000
#
# Label weighted avg:
#   Precision: 0.9069
#   Recall: 0.8929
#   F1-score: 0.8881
#   Support: 25767.0000
#
# Training Time: 27.9132 seconds
# Training Memory Usage: 1.58 MB
# Evaluating Time: 13.9506 seconds
# Evaluating Memory Usage: 3.64 MB
# Total Memory Usage: 5.21 MB
#
# Report for Fold 4:
#
# Label 0:
#   Precision: 0.9891
#   Recall: 0.7117
#   F1-score: 0.8277
#   Support: 9146.0000
#
# Label 1:
#   Precision: 0.8626
#   Recall: 0.9957
#   F1-score: 0.9243
#   Support: 16621.0000
#
# Accuracy: 0.8949
#
# Label macro avg:
#   Precision: 0.9258
#   Recall: 0.8537
#   F1-score: 0.8760
#   Support: 25767.0000
#
# Label weighted avg:
#   Precision: 0.9075
#   Recall: 0.8949
#   F1-score: 0.8901
#   Support: 25767.0000
#
# Training Time: 27.7260 seconds
# Training Memory Usage: 1.58 MB
# Evaluating Time: 13.8020 seconds
# Evaluating Memory Usage: 3.64 MB
# Total Memory Usage: 5.21 MB
#
# Report for Fold 5:
#
# Label 0:
#   Precision: 0.9961
#   Recall: 0.7067
#   F1-score: 0.8268
#   Support: 9365.0000
#
# Label 1:
#   Precision: 0.8564
#   Recall: 0.9984
#   F1-score: 0.9219
#   Support: 16402.0000
#
# Accuracy: 0.8924
#
# Label macro avg:
#   Precision: 0.9262
#   Recall: 0.8525
#   F1-score: 0.8744
#   Support: 25767.0000
#
# Label weighted avg:
#   Precision: 0.9071
#   Recall: 0.8924
#   F1-score: 0.8874
#   Support: 25767.0000
#
# Training Time: 27.9961 seconds
# Training Memory Usage: 1.58 MB
# Evaluating Time: 14.2170 seconds
# Evaluating Memory Usage: 3.63 MB
# Total Memory Usage: 5.21 MB
# ****************************
#
# Sampling Fraction: 0.5
# SOM SHAPE: (30, 30)
#
# Class 0:
# precision: 0.9736
# recall: 0.7288
# f1-score: 0.8336
#
# Class 1:
# precision: 0.8659
# recall: 0.9888
# f1-score: 0.9233
#
# Class macro avg:
# precision: 0.9197
# recall: 0.8588
# f1-score: 0.8784
#
# Class weighted avg:
# precision: 0.9048
# recall: 0.8950
# f1-score: 0.8909
# Average Training Time: 0 minutes and 53.71 seconds
# Average Training Memory Usage: 1.57 MB
# Average Evaluating Time: 0 minutes and 26.68 seconds
# Average Evaluating Memory Usage: 4.12 MB
# Average Total Memory Usage: 5.70 MB
# ---------------------------------------
#
# All Reports and Times for this SOM Shape:
#
# Report for Fold 1:
#
# Label 0:
#   Precision: 0.9722
#   Recall: 0.7344
#   F1-score: 0.8367
#   Support: 9413.0000
#
# Label 1:
#   Precision: 0.8660
#   Recall: 0.9879
#   F1-score: 0.9229
#   Support: 16355.0000
#
# Accuracy: 0.8953
#
# Label macro avg:
#   Precision: 0.9191
#   Recall: 0.8612
#   F1-score: 0.8798
#   Support: 25768.0000
#
# Label weighted avg:
#   Precision: 0.9048
#   Recall: 0.8953
#   F1-score: 0.8914
#   Support: 25768.0000
#
# Training Time: 52.9308 seconds
# Training Memory Usage: 1.57 MB
# Evaluating Time: 26.6258 seconds
# Evaluating Memory Usage: 4.13 MB
# Total Memory Usage: 5.70 MB
#
# Report for Fold 2:
#
# Label 0:
#   Precision: 0.9719
#   Recall: 0.7326
#   F1-score: 0.8354
#   Support: 9203.0000
#
# Label 1:
#   Precision: 0.8693
#   Recall: 0.9882
#   F1-score: 0.9250
#   Support: 16564.0000
#
# Accuracy: 0.8969
#
# Label macro avg:
#   Precision: 0.9206
#   Recall: 0.8604
#   F1-score: 0.8802
#   Support: 25767.0000
#
# Label weighted avg:
#   Precision: 0.9059
#   Recall: 0.8969
#   F1-score: 0.8930
#   Support: 25767.0000
#
# Training Time: 53.8559 seconds
# Training Memory Usage: 1.57 MB
# Evaluating Time: 27.1097 seconds
# Evaluating Memory Usage: 4.13 MB
# Total Memory Usage: 5.70 MB
#
# Report for Fold 3:
#
# Label 0:
#   Precision: 0.9733
#   Recall: 0.7268
#   F1-score: 0.8322
#   Support: 9373.0000
#
# Label 1:
#   Precision: 0.8635
#   Recall: 0.9886
#   F1-score: 0.9218
#   Support: 16394.0000
#
# Accuracy: 0.8934
#
# Label macro avg:
#   Precision: 0.9184
#   Recall: 0.8577
#   F1-score: 0.8770
#   Support: 25767.0000
#
# Label weighted avg:
#   Precision: 0.9035
#   Recall: 0.8934
#   F1-score: 0.8892
#   Support: 25767.0000
#
# Training Time: 52.3400 seconds
# Training Memory Usage: 1.57 MB
# Evaluating Time: 25.2114 seconds
# Evaluating Memory Usage: 4.12 MB
# Total Memory Usage: 5.69 MB
#
# Report for Fold 4:
#
# Label 0:
#   Precision: 0.9741
#   Recall: 0.7250
#   F1-score: 0.8313
#   Support: 9146.0000
#
# Label 1:
#   Precision: 0.8674
#   Recall: 0.9894
#   F1-score: 0.9244
#   Support: 16621.0000
#
# Accuracy: 0.8956
#
# Label macro avg:
#   Precision: 0.9207
#   Recall: 0.8572
#   F1-score: 0.8778
#   Support: 25767.0000
#
# Label weighted avg:
#   Precision: 0.9053
#   Recall: 0.8956
#   F1-score: 0.8913
#   Support: 25767.0000
#
# Training Time: 55.2777 seconds
# Training Memory Usage: 1.57 MB
# Evaluating Time: 27.4983 seconds
# Evaluating Memory Usage: 4.13 MB
# Total Memory Usage: 5.70 MB
#
# Report for Fold 5:
#
# Label 0:
#   Precision: 0.9764
#   Recall: 0.7254
#   F1-score: 0.8324
#   Support: 9365.0000
#
# Label 1:
#   Precision: 0.8633
#   Recall: 0.9900
#   F1-score: 0.9223
#   Support: 16402.0000
#
# Accuracy: 0.8938
#
# Label macro avg:
#   Precision: 0.9198
#   Recall: 0.8577
#   F1-score: 0.8773
#   Support: 25767.0000
#
# Label weighted avg:
#   Precision: 0.9044
#   Recall: 0.8938
#   F1-score: 0.8896
#   Support: 25767.0000
#
# Training Time: 54.1580 seconds
# Training Memory Usage: 1.57 MB
# Evaluating Time: 26.9408 seconds
# Evaluating Memory Usage: 4.13 MB
# Total Memory Usage: 5.70 MB
# ****************************
#
# Sampling Fraction: 0.7
# SOM SHAPE: (10, 10)
#
# Class 0:
# precision: 0.9963
# recall: 0.7069
# f1-score: 0.8270
#
# Class 1:
# precision: 0.8578
# recall: 0.9985
# f1-score: 0.9228
#
# Class macro avg:
# precision: 0.9270
# recall: 0.8527
# f1-score: 0.8749
#
# Class weighted avg:
# precision: 0.9078
# recall: 0.8933
# f1-score: 0.8882
# Average Training Time: 0 minutes and 20.38 seconds
# Average Training Memory Usage: 2.20 MB
# Average Evaluating Time: 0 minutes and 9.75 seconds
# Average Evaluating Memory Usage: 4.60 MB
# Average Total Memory Usage: 6.80 MB
# ---------------------------------------
#
# All Reports and Times for this SOM Shape:
#
# Report for Fold 1:
#
# Label 0:
#   Precision: 0.9974
#   Recall: 0.7111
#   F1-score: 0.8302
#   Support: 12940.0000
#
# Label 1:
#   Precision: 0.8607
#   Recall: 0.9990
#   F1-score: 0.9247
#   Support: 23135.0000
#
# Accuracy: 0.8957
#
# Label macro avg:
#   Precision: 0.9291
#   Recall: 0.8550
#   F1-score: 0.8775
#   Support: 36075.0000
#
# Label weighted avg:
#   Precision: 0.9098
#   Recall: 0.8957
#   F1-score: 0.8908
#   Support: 36075.0000
#
# Training Time: 19.7947 seconds
# Training Memory Usage: 2.20 MB
# Evaluating Time: 9.3384 seconds
# Evaluating Memory Usage: 4.60 MB
# Total Memory Usage: 6.80 MB
#
# Report for Fold 2:
#
# Label 0:
#   Precision: 0.9960
#   Recall: 0.7120
#   F1-score: 0.8304
#   Support: 13011.0000
#
# Label 1:
#   Precision: 0.8600
#   Recall: 0.9984
#   F1-score: 0.9241
#   Support: 23063.0000
#
# Accuracy: 0.8951
#
# Label macro avg:
#   Precision: 0.9280
#   Recall: 0.8552
#   F1-score: 0.8772
#   Support: 36074.0000
#
# Label weighted avg:
#   Precision: 0.9091
#   Recall: 0.8951
#   F1-score: 0.8903
#   Support: 36074.0000
#
# Training Time: 19.7373 seconds
# Training Memory Usage: 2.20 MB
# Evaluating Time: 9.3493 seconds
# Evaluating Memory Usage: 4.60 MB
# Total Memory Usage: 6.80 MB
#
# Report for Fold 3:
#
# Label 0:
#   Precision: 0.9973
#   Recall: 0.7078
#   F1-score: 0.8279
#   Support: 13078.0000
#
# Label 1:
#   Precision: 0.8574
#   Recall: 0.9989
#   F1-score: 0.9227
#   Support: 22996.0000
#
# Accuracy: 0.8934
#
# Label macro avg:
#   Precision: 0.9273
#   Recall: 0.8533
#   F1-score: 0.8753
#   Support: 36074.0000
#
# Label weighted avg:
#   Precision: 0.9081
#   Recall: 0.8934
#   F1-score: 0.8884
#   Support: 36074.0000
#
# Training Time: 19.3883 seconds
# Training Memory Usage: 2.20 MB
# Evaluating Time: 9.0753 seconds
# Evaluating Memory Usage: 4.59 MB
# Total Memory Usage: 6.79 MB
#
# Report for Fold 4:
#
# Label 0:
#   Precision: 0.9960
#   Recall: 0.6994
#   F1-score: 0.8217
#   Support: 13139.0000
#
# Label 1:
#   Precision: 0.8529
#   Recall: 0.9984
#   F1-score: 0.9199
#   Support: 22935.0000
#
# Accuracy: 0.8895
#
# Label macro avg:
#   Precision: 0.9244
#   Recall: 0.8489
#   F1-score: 0.8708
#   Support: 36074.0000
#
# Label weighted avg:
#   Precision: 0.9050
#   Recall: 0.8895
#   F1-score: 0.8842
#   Support: 36074.0000
#
# Training Time: 20.8677 seconds
# Training Memory Usage: 2.20 MB
# Evaluating Time: 10.0661 seconds
# Evaluating Memory Usage: 4.60 MB
# Total Memory Usage: 6.81 MB
#
# Report for Fold 5:
#
# Label 0:
#   Precision: 0.9946
#   Recall: 0.7043
#   F1-score: 0.8247
#   Support: 12932.0000
#
# Label 1:
#   Precision: 0.8579
#   Recall: 0.9979
#   F1-score: 0.9226
#   Support: 23142.0000
#
# Accuracy: 0.8926
#
# Label macro avg:
#   Precision: 0.9263
#   Recall: 0.8511
#   F1-score: 0.8736
#   Support: 36074.0000
#
# Label weighted avg:
#   Precision: 0.9069
#   Recall: 0.8926
#   F1-score: 0.8875
#   Support: 36074.0000
#
# Training Time: 22.1168 seconds
# Training Memory Usage: 2.20 MB
# Evaluating Time: 10.9023 seconds
# Evaluating Memory Usage: 4.60 MB
# Total Memory Usage: 6.80 MB
# ****************************
#
# Sampling Fraction: 0.7
# SOM SHAPE: (20, 20)
#
# Class 0:
# precision: 0.9930
# recall: 0.7112
# f1-score: 0.8288
#
# Class 1:
# precision: 0.8594
# recall: 0.9972
# f1-score: 0.9232
#
# Class macro avg:
# precision: 0.9262
# recall: 0.8542
# f1-score: 0.8760
#
# Class weighted avg:
# precision: 0.9076
# recall: 0.8940
# f1-score: 0.8891
# Average Training Time: 0 minutes and 40.07 seconds
# Average Training Memory Usage: 2.20 MB
# Average Evaluating Time: 0 minutes and 20.10 seconds
# Average Evaluating Memory Usage: 4.91 MB
# Average Total Memory Usage: 7.12 MB
# ---------------------------------------
#
# All Reports and Times for this SOM Shape:
#
# Report for Fold 1:
#
# Label 0:
#   Precision: 0.9949
#   Recall: 0.7121
#   F1-score: 0.8301
#   Support: 12940.0000
#
# Label 1:
#   Precision: 0.8611
#   Recall: 0.9980
#   F1-score: 0.9245
#   Support: 23135.0000
#
# Accuracy: 0.8954
#
# Label macro avg:
#   Precision: 0.9280
#   Recall: 0.8551
#   F1-score: 0.8773
#   Support: 36075.0000
#
# Label weighted avg:
#   Precision: 0.9091
#   Recall: 0.8954
#   F1-score: 0.8906
#   Support: 36075.0000
#
# Training Time: 39.0874 seconds
# Training Memory Usage: 2.20 MB
# Evaluating Time: 19.4741 seconds
# Evaluating Memory Usage: 4.91 MB
# Total Memory Usage: 7.11 MB
#
# Report for Fold 2:
#
# Label 0:
#   Precision: 0.9943
#   Recall: 0.7147
#   F1-score: 0.8316
#   Support: 13011.0000
#
# Label 1:
#   Precision: 0.8611
#   Recall: 0.9977
#   F1-score: 0.9244
#   Support: 23063.0000
#
# Accuracy: 0.8956
#
# Label macro avg:
#   Precision: 0.9277
#   Recall: 0.8562
#   F1-score: 0.8780
#   Support: 36074.0000
#
# Label weighted avg:
#   Precision: 0.9091
#   Recall: 0.8956
#   F1-score: 0.8909
#   Support: 36074.0000
#
# Training Time: 40.3030 seconds
# Training Memory Usage: 2.20 MB
# Evaluating Time: 19.9626 seconds
# Evaluating Memory Usage: 4.91 MB
# Total Memory Usage: 7.11 MB
#
# Report for Fold 3:
#
# Label 0:
#   Precision: 0.9936
#   Recall: 0.7143
#   F1-score: 0.8311
#   Support: 13078.0000
#
# Label 1:
#   Precision: 0.8599
#   Recall: 0.9974
#   F1-score: 0.9236
#   Support: 22996.0000
#
# Accuracy: 0.8947
#
# Label macro avg:
#   Precision: 0.9268
#   Recall: 0.8558
#   F1-score: 0.8773
#   Support: 36074.0000
#
# Label weighted avg:
#   Precision: 0.9084
#   Recall: 0.8947
#   F1-score: 0.8900
#   Support: 36074.0000
#
# Training Time: 41.1422 seconds
# Training Memory Usage: 2.20 MB
# Evaluating Time: 21.0521 seconds
# Evaluating Memory Usage: 4.92 MB
# Total Memory Usage: 7.12 MB
#
# Report for Fold 4:
#
# Label 0:
#   Precision: 0.9857
#   Recall: 0.7064
#   F1-score: 0.8230
#   Support: 13139.0000
#
# Label 1:
#   Precision: 0.8553
#   Recall: 0.9941
#   F1-score: 0.9195
#   Support: 22935.0000
#
# Accuracy: 0.8893
#
# Label macro avg:
#   Precision: 0.9205
#   Recall: 0.8503
#   F1-score: 0.8713
#   Support: 36074.0000
#
# Label weighted avg:
#   Precision: 0.9028
#   Recall: 0.8893
#   F1-score: 0.8844
#   Support: 36074.0000
#
# Training Time: 41.0326 seconds
# Training Memory Usage: 2.20 MB
# Evaluating Time: 20.3904 seconds
# Evaluating Memory Usage: 4.91 MB
# Total Memory Usage: 7.11 MB
#
# Report for Fold 5:
#
# Label 0:
#   Precision: 0.9966
#   Recall: 0.7085
#   F1-score: 0.8282
#   Support: 12932.0000
#
# Label 1:
#   Precision: 0.8598
#   Recall: 0.9987
#   F1-score: 0.9240
#   Support: 23142.0000
#
# Accuracy: 0.8946
#
# Label macro avg:
#   Precision: 0.9282
#   Recall: 0.8536
#   F1-score: 0.8761
#   Support: 36074.0000
#
# Label weighted avg:
#   Precision: 0.9088
#   Recall: 0.8946
#   F1-score: 0.8897
#   Support: 36074.0000
#
# Training Time: 38.7791 seconds
# Training Memory Usage: 2.20 MB
# Evaluating Time: 19.5958 seconds
# Evaluating Memory Usage: 4.92 MB
# Total Memory Usage: 7.12 MB
# ****************************
#
# Sampling Fraction: 0.7
# SOM SHAPE: (30, 30)
#
# Class 0:
# precision: 0.9794
# recall: 0.7258
# f1-score: 0.8337
#
# Class 1:
# precision: 0.8649
# recall: 0.9913
# f1-score: 0.9238
#
# Class macro avg:
# precision: 0.9221
# recall: 0.8586
# f1-score: 0.8788
#
# Class weighted avg:
# precision: 0.9062
# recall: 0.8955
# f1-score: 0.8913
# Average Training Time: 1 minutes and 12.07 seconds
# Average Training Memory Usage: 2.20 MB
# Average Evaluating Time: 0 minutes and 35.32 seconds
# Average Evaluating Memory Usage: 5.41 MB
# Average Total Memory Usage: 7.61 MB
# ---------------------------------------
#
# All Reports and Times for this SOM Shape:
#
# Report for Fold 1:
#
# Label 0:
#   Precision: 0.9820
#   Recall: 0.7250
#   F1-score: 0.8342
#   Support: 12940.0000
#
# Label 1:
#   Precision: 0.8658
#   Recall: 0.9926
#   F1-score: 0.9249
#   Support: 23135.0000
#
# Accuracy: 0.8966
#
# Label macro avg:
#   Precision: 0.9239
#   Recall: 0.8588
#   F1-score: 0.8795
#   Support: 36075.0000
#
# Label weighted avg:
#   Precision: 0.9075
#   Recall: 0.8966
#   F1-score: 0.8923
#   Support: 36075.0000
#
# Training Time: 75.2860 seconds
# Training Memory Usage: 2.20 MB
# Evaluating Time: 35.9677 seconds
# Evaluating Memory Usage: 5.41 MB
# Total Memory Usage: 7.61 MB
#
# Report for Fold 2:
#
# Label 0:
#   Precision: 0.9787
#   Recall: 0.7287
#   F1-score: 0.8354
#   Support: 13011.0000
#
# Label 1:
#   Precision: 0.8662
#   Recall: 0.9911
#   F1-score: 0.9244
#   Support: 23063.0000
#
# Accuracy: 0.8964
#
# Label macro avg:
#   Precision: 0.9225
#   Recall: 0.8599
#   F1-score: 0.8799
#   Support: 36074.0000
#
# Label weighted avg:
#   Precision: 0.9068
#   Recall: 0.8964
#   F1-score: 0.8923
#   Support: 36074.0000
#
# Training Time: 69.2391 seconds
# Training Memory Usage: 2.20 MB
# Evaluating Time: 33.9266 seconds
# Evaluating Memory Usage: 5.41 MB
# Total Memory Usage: 7.61 MB
#
# Report for Fold 3:
#
# Label 0:
#   Precision: 0.9754
#   Recall: 0.7321
#   F1-score: 0.8364
#   Support: 13078.0000
#
# Label 1:
#   Precision: 0.8666
#   Recall: 0.9895
#   F1-score: 0.9240
#   Support: 22996.0000
#
# Accuracy: 0.8962
#
# Label macro avg:
#   Precision: 0.9210
#   Recall: 0.8608
#   F1-score: 0.8802
#   Support: 36074.0000
#
# Label weighted avg:
#   Precision: 0.9060
#   Recall: 0.8962
#   F1-score: 0.8922
#   Support: 36074.0000
#
# Training Time: 72.7734 seconds
# Training Memory Usage: 2.20 MB
# Evaluating Time: 36.6386 seconds
# Evaluating Memory Usage: 5.41 MB
# Total Memory Usage: 7.61 MB
#
# Report for Fold 4:
#
# Label 0:
#   Precision: 0.9757
#   Recall: 0.7229
#   F1-score: 0.8305
#   Support: 13139.0000
#
# Label 1:
#   Precision: 0.8618
#   Recall: 0.9897
#   F1-score: 0.9213
#   Support: 22935.0000
#
# Accuracy: 0.8925
#
# Label macro avg:
#   Precision: 0.9187
#   Recall: 0.8563
#   F1-score: 0.8759
#   Support: 36074.0000
#
# Label weighted avg:
#   Precision: 0.9032
#   Recall: 0.8925
#   F1-score: 0.8882
#   Support: 36074.0000
#
# Training Time: 74.1116 seconds
# Training Memory Usage: 2.20 MB
# Evaluating Time: 35.9446 seconds
# Evaluating Memory Usage: 5.41 MB
# Total Memory Usage: 7.61 MB
#
# Report for Fold 5:
#
# Label 0:
#   Precision: 0.9851
#   Recall: 0.7203
#   F1-score: 0.8321
#   Support: 12932.0000
#
# Label 1:
#   Precision: 0.8641
#   Recall: 0.9939
#   F1-score: 0.9245
#   Support: 23142.0000
#
# Accuracy: 0.8958
#
# Label macro avg:
#   Precision: 0.9246
#   Recall: 0.8571
#   F1-score: 0.8783
#   Support: 36074.0000
#
# Label weighted avg:
#   Precision: 0.9075
#   Recall: 0.8958
#   F1-score: 0.8914
#   Support: 36074.0000
#
# Training Time: 68.9515 seconds
# Training Memory Usage: 2.20 MB
# Evaluating Time: 34.0977 seconds
# Evaluating Memory Usage: 5.42 MB
# Total Memory Usage: 7.62 MB
# ****************************
#
# Sampling Fraction: 0.9
# SOM SHAPE: (10, 10)
#
# Class 0:
# precision: 0.9962
# recall: 0.7060
# f1-score: 0.8264
#
# Class 1:
# precision: 0.8574
# recall: 0.9985
# f1-score: 0.9226
#
# Class macro avg:
# precision: 0.9268
# recall: 0.8522
# f1-score: 0.8745
#
# Class weighted avg:
# precision: 0.9075
# recall: 0.8929
# f1-score: 0.8879
# Average Training Time: 0 minutes and 26.44 seconds
# Average Training Memory Usage: 2.83 MB
# Average Evaluating Time: 0 minutes and 12.76 seconds
# Average Evaluating Memory Usage: 5.88 MB
# Average Total Memory Usage: 8.71 MB
# ---------------------------------------
#
# All Reports and Times for this SOM Shape:
#
# Report for Fold 1:
#
# Label 0:
#   Precision: 0.9978
#   Recall: 0.7097
#   F1-score: 0.8294
#   Support: 16569.0000
#
# Label 1:
#   Precision: 0.8610
#   Recall: 0.9991
#   F1-score: 0.9249
#   Support: 29813.0000
#
# Accuracy: 0.8957
#
# Label macro avg:
#   Precision: 0.9294
#   Recall: 0.8544
#   F1-score: 0.8772
#   Support: 46382.0000
#
# Label weighted avg:
#   Precision: 0.9098
#   Recall: 0.8957
#   F1-score: 0.8908
#   Support: 46382.0000
#
# Training Time: 29.2482 seconds
# Training Memory Usage: 2.83 MB
# Evaluating Time: 14.0159 seconds
# Evaluating Memory Usage: 5.90 MB
# Total Memory Usage: 8.73 MB
#
# Report for Fold 2:
#
# Label 0:
#   Precision: 0.9973
#   Recall: 0.7072
#   F1-score: 0.8276
#   Support: 16680.0000
#
# Label 1:
#   Precision: 0.8587
#   Recall: 0.9989
#   F1-score: 0.9235
#   Support: 29701.0000
#
# Accuracy: 0.8940
#
# Label macro avg:
#   Precision: 0.9280
#   Recall: 0.8531
#   F1-score: 0.8755
#   Support: 46381.0000
#
# Label weighted avg:
#   Precision: 0.9085
#   Recall: 0.8940
#   F1-score: 0.8890
#   Support: 46381.0000
#
# Training Time: 25.4115 seconds
# Training Memory Usage: 2.83 MB
# Evaluating Time: 12.0348 seconds
# Evaluating Memory Usage: 5.88 MB
# Total Memory Usage: 8.71 MB
#
# Report for Fold 3:
#
# Label 0:
#   Precision: 0.9966
#   Recall: 0.7088
#   F1-score: 0.8284
#   Support: 16827.0000
#
# Label 1:
#   Precision: 0.8576
#   Recall: 0.9986
#   F1-score: 0.9228
#   Support: 29554.0000
#
# Accuracy: 0.8935
#
# Label macro avg:
#   Precision: 0.9271
#   Recall: 0.8537
#   F1-score: 0.8756
#   Support: 46381.0000
#
# Label weighted avg:
#   Precision: 0.9080
#   Recall: 0.8935
#   F1-score: 0.8885
#   Support: 46381.0000
#
# Training Time: 25.8134 seconds
# Training Memory Usage: 2.83 MB
# Evaluating Time: 12.7109 seconds
# Evaluating Memory Usage: 5.88 MB
# Total Memory Usage: 8.71 MB
#
# Report for Fold 4:
#
# Label 0:
#   Precision: 0.9945
#   Recall: 0.7010
#   F1-score: 0.8223
#   Support: 16898.0000
#
# Label 1:
#   Precision: 0.8534
#   Recall: 0.9978
#   F1-score: 0.9200
#   Support: 29483.0000
#
# Accuracy: 0.8896
#
# Label macro avg:
#   Precision: 0.9239
#   Recall: 0.8494
#   F1-score: 0.8711
#   Support: 46381.0000
#
# Label weighted avg:
#   Precision: 0.9048
#   Recall: 0.8896
#   F1-score: 0.8844
#   Support: 46381.0000
#
# Training Time: 25.0521 seconds
# Training Memory Usage: 2.83 MB
# Evaluating Time: 12.3352 seconds
# Evaluating Memory Usage: 5.87 MB
# Total Memory Usage: 8.70 MB
#
# Report for Fold 5:
#
# Label 0:
#   Precision: 0.9947
#   Recall: 0.7035
#   F1-score: 0.8241
#   Support: 16726.0000
#
# Label 1:
#   Precision: 0.8565
#   Recall: 0.9979
#   F1-score: 0.9218
#   Support: 29655.0000
#
# Accuracy: 0.8917
#
# Label macro avg:
#   Precision: 0.9256
#   Recall: 0.8507
#   F1-score: 0.8730
#   Support: 46381.0000
#
# Label weighted avg:
#   Precision: 0.9063
#   Recall: 0.8917
#   F1-score: 0.8866
#   Support: 46381.0000
#
# Training Time: 26.6585 seconds
# Training Memory Usage: 2.83 MB
# Evaluating Time: 12.7130 seconds
# Evaluating Memory Usage: 5.88 MB
# Total Memory Usage: 8.71 MB
# ****************************
#
# Sampling Fraction: 0.9
# SOM SHAPE: (20, 20)
#
# Class 0:
# precision: 0.9977
# recall: 0.7074
# f1-score: 0.8279
#
# Class 1:
# precision: 0.8581
# recall: 0.9991
# f1-score: 0.9232
#
# Class macro avg:
# precision: 0.9279
# recall: 0.8533
# f1-score: 0.8755
#
# Class weighted avg:
# precision: 0.9085
# recall: 0.8938
# f1-score: 0.8888
# Average Training Time: 0 minutes and 51.40 seconds
# Average Training Memory Usage: 2.83 MB
# Average Evaluating Time: 0 minutes and 25.73 seconds
# Average Evaluating Memory Usage: 6.18 MB
# Average Total Memory Usage: 9.01 MB
# ---------------------------------------
#
# All Reports and Times for this SOM Shape:
#
# Report for Fold 1:
#
# Label 0:
#   Precision: 0.9986
#   Recall: 0.7109
#   F1-score: 0.8305
#   Support: 16569.0000
#
# Label 1:
#   Precision: 0.8615
#   Recall: 0.9994
#   F1-score: 0.9254
#   Support: 29813.0000
#
# Accuracy: 0.8964
#
# Label macro avg:
#   Precision: 0.9300
#   Recall: 0.8552
#   F1-score: 0.8779
#   Support: 46382.0000
#
# Label weighted avg:
#   Precision: 0.9105
#   Recall: 0.8964
#   F1-score: 0.8915
#   Support: 46382.0000
#
# Training Time: 49.8364 seconds
# Training Memory Usage: 2.83 MB
# Evaluating Time: 24.4389 seconds
# Evaluating Memory Usage: 6.17 MB
# Total Memory Usage: 9.00 MB
#
# Report for Fold 2:
#
# Label 0:
#   Precision: 0.9988
#   Recall: 0.7092
#   F1-score: 0.8295
#   Support: 16680.0000
#
# Label 1:
#   Precision: 0.8596
#   Recall: 0.9995
#   F1-score: 0.9243
#   Support: 29701.0000
#
# Accuracy: 0.8951
#
# Label macro avg:
#   Precision: 0.9292
#   Recall: 0.8544
#   F1-score: 0.8769
#   Support: 46381.0000
#
# Label weighted avg:
#   Precision: 0.9096
#   Recall: 0.8951
#   F1-score: 0.8902
#   Support: 46381.0000
#
# Training Time: 51.3812 seconds
# Training Memory Usage: 2.83 MB
# Evaluating Time: 24.9381 seconds
# Evaluating Memory Usage: 6.18 MB
# Total Memory Usage: 9.01 MB
#
# Report for Fold 3:
#
# Label 0:
#   Precision: 0.9992
#   Recall: 0.7112
#   F1-score: 0.8310
#   Support: 16827.0000
#
# Label 1:
#   Precision: 0.8588
#   Recall: 0.9997
#   F1-score: 0.9239
#   Support: 29554.0000
#
# Accuracy: 0.8950
#
# Label macro avg:
#   Precision: 0.9290
#   Recall: 0.8555
#   F1-score: 0.8774
#   Support: 46381.0000
#
# Label weighted avg:
#   Precision: 0.9097
#   Recall: 0.8950
#   F1-score: 0.8902
#   Support: 46381.0000
#
# Training Time: 51.2479 seconds
# Training Memory Usage: 2.83 MB
# Evaluating Time: 25.4369 seconds
# Evaluating Memory Usage: 6.17 MB
# Total Memory Usage: 9.00 MB
#
# Report for Fold 4:
#
# Label 0:
#   Precision: 0.9964
#   Recall: 0.7013
#   F1-score: 0.8232
#   Support: 16898.0000
#
# Label 1:
#   Precision: 0.8537
#   Recall: 0.9985
#   F1-score: 0.9204
#   Support: 29483.0000
#
# Accuracy: 0.8903
#
# Label macro avg:
#   Precision: 0.9250
#   Recall: 0.8499
#   F1-score: 0.8718
#   Support: 46381.0000
#
# Label weighted avg:
#   Precision: 0.9057
#   Recall: 0.8903
#   F1-score: 0.8850
#   Support: 46381.0000
#
# Training Time: 49.5357 seconds
# Training Memory Usage: 2.83 MB
# Evaluating Time: 25.4955 seconds
# Evaluating Memory Usage: 6.18 MB
# Total Memory Usage: 9.01 MB
#
# Report for Fold 5:
#
# Label 0:
#   Precision: 0.9955
#   Recall: 0.7045
#   F1-score: 0.8251
#   Support: 16726.0000
#
# Label 1:
#   Precision: 0.8569
#   Recall: 0.9982
#   F1-score: 0.9222
#   Support: 29655.0000
#
# Accuracy: 0.8923
#
# Label macro avg:
#   Precision: 0.9262
#   Recall: 0.8514
#   F1-score: 0.8737
#   Support: 46381.0000
#
# Label weighted avg:
#   Precision: 0.9069
#   Recall: 0.8923
#   F1-score: 0.8872
#   Support: 46381.0000
#
# Training Time: 55.0002 seconds
# Training Memory Usage: 2.83 MB
# Evaluating Time: 28.3500 seconds
# Evaluating Memory Usage: 6.17 MB
# Total Memory Usage: 9.01 MB
# ****************************
#
# Sampling Fraction: 0.9
# SOM SHAPE: (30, 30)
#
# Class 0:
# precision: 0.9801
# recall: 0.7248
# f1-score: 0.8333
#
# Class 1:
# precision: 0.8645
# recall: 0.9917
# f1-score: 0.9237
#
# Class macro avg:
# precision: 0.9223
# recall: 0.8582
# f1-score: 0.8785
#
# Class weighted avg:
# precision: 0.9062
# recall: 0.8953
# f1-score: 0.8911
# Average Training Time: 1 minutes and 33.98 seconds
# Average Training Memory Usage: 2.83 MB
# Average Evaluating Time: 0 minutes and 45.79 seconds
# Average Evaluating Memory Usage: 6.67 MB
# Average Total Memory Usage: 9.50 MB
# ---------------------------------------
#
# All Reports and Times for this SOM Shape:
#
# Report for Fold 1:
#
# Label 0:
#   Precision: 0.9775
#   Recall: 0.7313
#   F1-score: 0.8367
#   Support: 16569.0000
#
# Label 1:
#   Precision: 0.8690
#   Recall: 0.9906
#   F1-score: 0.9258
#   Support: 29813.0000
#
# Accuracy: 0.8980
#
# Label macro avg:
#   Precision: 0.9232
#   Recall: 0.8610
#   F1-score: 0.8813
#   Support: 46382.0000
#
# Label weighted avg:
#   Precision: 0.9078
#   Recall: 0.8980
#   F1-score: 0.8940
#   Support: 46382.0000
#
# Training Time: 94.4621 seconds
# Training Memory Usage: 2.83 MB
# Evaluating Time: 45.7930 seconds
# Evaluating Memory Usage: 6.66 MB
# Total Memory Usage: 9.50 MB
#
# Report for Fold 2:
#
# Label 0:
#   Precision: 0.9793
#   Recall: 0.7274
#   F1-score: 0.8348
#   Support: 16680.0000
#
# Label 1:
#   Precision: 0.8662
#   Recall: 0.9914
#   F1-score: 0.9246
#   Support: 29701.0000
#
# Accuracy: 0.8964
#
# Label macro avg:
#   Precision: 0.9228
#   Recall: 0.8594
#   F1-score: 0.8797
#   Support: 46381.0000
#
# Label weighted avg:
#   Precision: 0.9069
#   Recall: 0.8964
#   F1-score: 0.8923
#   Support: 46381.0000
#
# Training Time: 89.5592 seconds
# Training Memory Usage: 2.83 MB
# Evaluating Time: 44.0069 seconds
# Evaluating Memory Usage: 6.67 MB
# Total Memory Usage: 9.50 MB
#
# Report for Fold 3:
#
# Label 0:
#   Precision: 0.9856
#   Recall: 0.7256
#   F1-score: 0.8358
#   Support: 16827.0000
#
# Label 1:
#   Precision: 0.8642
#   Recall: 0.9940
#   F1-score: 0.9245
#   Support: 29554.0000
#
# Accuracy: 0.8966
#
# Label macro avg:
#   Precision: 0.9249
#   Recall: 0.8598
#   F1-score: 0.8802
#   Support: 46381.0000
#
# Label weighted avg:
#   Precision: 0.9082
#   Recall: 0.8966
#   F1-score: 0.8924
#   Support: 46381.0000
#
# Training Time: 97.1773 seconds
# Training Memory Usage: 2.83 MB
# Evaluating Time: 45.7631 seconds
# Evaluating Memory Usage: 6.67 MB
# Total Memory Usage: 9.50 MB
#
# Report for Fold 4:
#
# Label 0:
#   Precision: 0.9797
#   Recall: 0.7156
#   F1-score: 0.8271
#   Support: 16898.0000
#
# Label 1:
#   Precision: 0.8588
#   Recall: 0.9915
#   F1-score: 0.9204
#   Support: 29483.0000
#
# Accuracy: 0.8910
#
# Label macro avg:
#   Precision: 0.9193
#   Recall: 0.8536
#   F1-score: 0.8738
#   Support: 46381.0000
#
# Label weighted avg:
#   Precision: 0.9029
#   Recall: 0.8910
#   F1-score: 0.8864
#   Support: 46381.0000
#
# Training Time: 90.0620 seconds
# Training Memory Usage: 2.83 MB
# Evaluating Time: 44.4438 seconds
# Evaluating Memory Usage: 6.67 MB
# Total Memory Usage: 9.50 MB
#
# Report for Fold 5:
#
# Label 0:
#   Precision: 0.9783
#   Recall: 0.7239
#   F1-score: 0.8321
#   Support: 16726.0000
#
# Label 1:
#   Precision: 0.8642
#   Recall: 0.9909
#   F1-score: 0.9232
#   Support: 29655.0000
#
# Accuracy: 0.8946
#
# Label macro avg:
#   Precision: 0.9212
#   Recall: 0.8574
#   F1-score: 0.8777
#   Support: 46381.0000
#
# Label weighted avg:
#   Precision: 0.9053
#   Recall: 0.8946
#   F1-score: 0.8904
#   Support: 46381.0000
#
# Training Time: 98.6513 seconds
# Training Memory Usage: 2.83 MB
# Evaluating Time: 48.9257 seconds
# Evaluating Memory Usage: 6.67 MB
# Total Memory Usage: 9.50 MB
