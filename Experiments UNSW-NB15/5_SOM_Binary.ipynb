# %%
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report
from minisom import MiniSom
import numpy as np
import time
import matplotlib.pyplot as plt
from joblib import Parallel, delayed
import warnings
import tracemalloc
from collections import Counter

# %%
# Funzione per convertire l'uso della memoria in unità appropriate
def format_memory_usage(mem_usage):
    if mem_usage >= 1024 ** 3:
        return f"{mem_usage / (1024 ** 3):.2f} GB"
    else:
        return f"{mem_usage / (1024 ** 2):.2f} MB"

# Funzione per classificare i dati utilizzando il SOM
def classify2(som, data, training_data, training_labels):
    winmap = som.labels_map(training_data, training_labels)
    default_class = Counter(training_labels).most_common(1)[0][0]
    result = []
    for sample in data:
        winner = som.winner(sample)
        if winner in winmap:
            result.append(winmap[winner].most_common(1)[0][0])
        else:
            result.append(default_class)
    return result

# Funzione per monitorare l'uso della memoria durante una funzione
def monitor_memory_usage(func, *args, **kwargs):
    tracemalloc.start()
    result = func(*args, **kwargs)
    current, peak = tracemalloc.get_traced_memory()
    tracemalloc.stop()
    return result, peak

# Funzione per il training e l'evaluation con monitoraggio della memoria
def train_and_evaluate(train_idx, test_idx, X, y, som_shape, sigma, learning_rate):
    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    som = MiniSom(som_shape[0], som_shape[1], X_train.shape[1], sigma=sigma, learning_rate=learning_rate)

    start_train = time.time()
    _, training_mem_usage = monitor_memory_usage(som.train_random, X_train, X_train.shape[0])
    end_train = time.time()

    start_eval = time.time()
    y_pred, eval_mem_usage = monitor_memory_usage(classify2, som, X_test, X_train, y_train)
    end_eval = time.time()

    report = classification_report(y_test, y_pred, digits=4, output_dict=True, zero_division=0)

    training_time = end_train - start_train
    evaluating_time = end_eval - start_eval
    total_mem_usage = training_mem_usage + eval_mem_usage

    return report, training_time, training_mem_usage, evaluating_time, eval_mem_usage, total_mem_usage

# %%
# Inizializzazione del dataset e dei parametri
DATA_PATH = "/users/mik2002/som/dataset-processed UNSW-NB15/"
DATA_FILE = "dataset-processed-UNSW-NB15.csv"

# Carichiamo il dataset combinato e processato
df_dataset = pd.read_csv(DATA_PATH + DATA_FILE)

# Drop the 'attack_cat' column se ancora presente (può essere già stato rimosso nel dataset processato)
if 'attack_cat' in df_dataset.columns:
    df_dataset = df_dataset.drop(columns=['attack_cat'])

# Display label distribution
print("Distribution:")
display(df_dataset["label"].value_counts())
# Out:
# Distribution:
# label
# 1    164673
# 0     93000
# Name: count, dtype: int64

# %%
# Parametri per il SOM
som_sizes = [(10, 10), (15, 15), (20, 20), (25, 25), (30,30)]
learning_rate = 1.2
sigma = 1.5
sampling_fractions = [0.1, 0.3, 0.5, 0.7, 1]  # Diversi frazioni di campionamento

# %%
results = []

# Funzione wrapper per il parallelismo
def parallel_train_and_evaluate(train_idx, test_idx, som_shape, data, target, sigma, learning_rate):
    report, training_time, training_mem_usage, evaluating_time, eval_mem_usage, total_mem_usage = train_and_evaluate(train_idx, test_idx, data, target, som_shape, sigma, learning_rate)
    return report, training_time, training_mem_usage, evaluating_time, eval_mem_usage, total_mem_usage

# Inizializzazione del KFold
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# Loop su diverse frazioni di campionamento
for frac in sampling_fractions:
    print(f"Evaluating for sampling fraction: {frac}")
    
    # Esegui campionamento casuale stratificato mantenendo le proporzioni delle classi
    with warnings.catch_warnings():
        warnings.simplefilter("ignore", DeprecationWarning)
        sampled_df = df_dataset.groupby("label", group_keys=False).apply(lambda x: x.sample(frac=frac, random_state=42))

    scaler = MinMaxScaler()
    data = scaler.fit_transform(sampled_df.iloc[:, :-1])
    target = sampled_df.iloc[:, -1].values

    # Loop su diverse dimensioni del SOM
    for som_shape in som_sizes:
        print(f"Evaluating for som_shape: {som_shape}")
        # Split del dataset con K-Fold e parallelismo
        parallel_results = Parallel(n_jobs=-1)(delayed(parallel_train_and_evaluate)(train_idx, test_idx, som_shape, data, target, sigma, learning_rate) for train_idx, test_idx in kf.split(data))
        
        reports, training_times, training_mem_usages, evaluating_times, eval_mem_usages, total_mem_usages = zip(*parallel_results)
        
        # Aggrega metriche dai report
        class_metrics = {}
        accuracies = []
        for report in reports:
            accuracies.append(report['accuracy'])
            for key, metrics in report.items():
                if key.isdigit() or key in ['macro avg', 'weighted avg']:
                    if key not in class_metrics:
                        class_metrics[key] = {m: [] for m in metrics.keys() if m != 'support'}
                    for metric, value in metrics.items():
                        if metric != 'support':
                            class_metrics[key][metric].append(value)

        # Calcola medie e prepara output formattato
        averages = {key: {metric: np.mean(values) for metric, values in metrics.items()} for key, metrics in class_metrics.items()}
        averages['accuracy'] = np.mean(accuracies)

        # Calcola i tempi medi di training e valutazione e l'uso della memoria
        avg_training_time = np.mean(training_times)
        avg_training_mem_usage = np.mean(training_mem_usages)
        avg_evaluating_time = np.mean(evaluating_times)
        avg_eval_mem_usage = np.mean(eval_mem_usages)
        avg_total_mem_usage = np.mean(total_mem_usages)

        results.append((frac, som_shape, averages, avg_training_time, avg_training_mem_usage, avg_evaluating_time, avg_eval_mem_usage, avg_total_mem_usage))

        # Mostra i risultati per ogni frazione di campionamento e dimensione del SOM
        print("\nAverage Metrics Across All Folds:")
        print("****************************")
        print(f"\nSampling Fraction: {frac}")
        print(f"SOM Shape: {som_shape}".upper())
        for class_id, class_metrics in averages.items():
            if isinstance(class_metrics, dict):
                print(f"\nClass {class_id}:")
                for metric, value in class_metrics.items():
                    print(f"{metric}: {value:.4f}")
            else:
                print(f"\n{class_id}: {class_metrics:.4f}")

        # Mostra i tempi medi di training e valutazione e l'uso della memoria
        minutes_train, seconds_train = divmod(avg_training_time, 60)
        minutes_eval, seconds_eval = divmod(avg_evaluating_time, 60)
        print(f"Average Training Time: {int(minutes_train)} minutes and {seconds_train:.2f} seconds")
        print(f"Average Training Memory Usage: {format_memory_usage(avg_training_mem_usage)}")
        print(f"Average Evaluating Time: {int(minutes_eval)} minutes and {seconds_eval:.2f} seconds")
        print(f"Average Evaluating Memory Usage: {format_memory_usage(avg_eval_mem_usage)}")
        print(f"Average Total Memory Usage: {format_memory_usage(avg_total_mem_usage)}")
        print("---------------------------------------")

# Funzione per creare i grafici
def plot_metrics(results):
    metrics = ["precision", "recall", "f1-score", "accuracy", "training_time", "training_memory", "evaluating_time", "evaluating_memory", "total_time", "total_memory"]
    
    for frac in sampling_fractions:
        fig, axes = plt.subplots(nrows=4, ncols=3, figsize=(15, 15))
        axes = axes.flatten()
        metric_values = {metric: [] for metric in metrics}
        shapes = []

        for result in results:
            if result[0] == frac:
                _, shape, averages, avg_training_time, avg_training_mem_usage, avg_evaluating_time, avg_eval_mem_usage, avg_total_mem_usage = result
                shapes.append(shape)
                metric_values["precision"].append(averages["weighted avg"]["precision"])
                metric_values["recall"].append(averages["weighted avg"]["recall"])
                metric_values["f1-score"].append(averages["weighted avg"]["f1-score"])
                metric_values["accuracy"].append(averages["accuracy"])
                metric_values["training_time"].append(avg_training_time)
                metric_values["training_memory"].append(avg_training_mem_usage / (1024 ** 2))  # Convert to MB
                metric_values["evaluating_time"].append(avg_evaluating_time)
                metric_values["evaluating_memory"].append(avg_eval_mem_usage / (1024 ** 2))  # Convert to MB
                metric_values["total_time"].append(avg_training_time + avg_evaluating_time)
                metric_values["total_memory"].append(avg_total_mem_usage / (1024 ** 2))  # Convert to MB

        y_labels = {
            "precision": "Precision",
            "recall": "Recall",
            "f1-score": "F1-Score",
            "accuracy": "Accuracy",
            "training_time": "Time (s)",
            "training_memory": "Memory (MB)",
            "evaluating_time": "Time (s)",
            "evaluating_memory": "Memory (MB)",
            "total_time": "Time (s)",
            "total_memory": "Memory (MB)"
        }
        
        for i, metric in enumerate(metrics):
            axes[i].plot(shapes, metric_values[metric], marker='o', linestyle='-', label=metric)
            axes[i].set_title(f'{metric.replace("_", " ").capitalize()} for Sampling Fraction {frac}')
            axes[i].set_xlabel("SOM Shape")
            axes[i].set_ylabel(y_labels[metric])
            axes[i].legend()
        
        plt.tight_layout()
        plt.show()

# Mostra i grafici delle metriche
plot_metrics(results)
# Out:
# Evaluating for sampling fraction: 0.1
# Evaluating for som_shape: (10, 10)
#
# Average Metrics Across All Folds:
# ****************************
#
# Sampling Fraction: 0.1
# SOM SHAPE: (10, 10)
#
# Class 0:
# precision: 0.9918
# recall: 0.7105
# f1-score: 0.8279
#
# Class 1:
# precision: 0.8591
# recall: 0.9967
# f1-score: 0.9228
#
# Class macro avg:
# precision: 0.9254
# recall: 0.8536
# f1-score: 0.8753
#
# Class weighted avg:
# precision: 0.9070
# recall: 0.8934
# f1-score: 0.8886
#
# accuracy: 0.8934
# Average Training Time: 0 minutes and 2.89 seconds
# Average Training Memory Usage: 0.32 MB
# Average Evaluating Time: 0 minutes and 1.34 seconds
# Average Evaluating Memory Usage: 0.78 MB
# Average Total Memory Usage: 1.09 MB
# ---------------------------------------
# Evaluating for som_shape: (15, 15)
#
# Average Metrics Across All Folds:
# ****************************
#
# Sampling Fraction: 0.1
# SOM SHAPE: (15, 15)
#
# Class 0:
# precision: 0.9923
# recall: 0.7124
# f1-score: 0.8294
#
# Class 1:
# precision: 0.8599
# recall: 0.9969
# f1-score: 0.9234
#
# Class macro avg:
# precision: 0.9261
# recall: 0.8547
# f1-score: 0.8764
#
# Class weighted avg:
# precision: 0.9077
# recall: 0.8942
# f1-score: 0.8895
#
# accuracy: 0.8942
# Average Training Time: 0 minutes and 4.07 seconds
# Average Training Memory Usage: 0.41 MB
# Average Evaluating Time: 0 minutes and 2.03 seconds
# Average Evaluating Memory Usage: 0.91 MB
# Average Total Memory Usage: 1.33 MB
# ---------------------------------------
# Evaluating for som_shape: (20, 20)
#
# Average Metrics Across All Folds:
# ****************************
#
# Sampling Fraction: 0.1
# SOM SHAPE: (20, 20)
#
# Class 0:
# precision: 0.9697
# recall: 0.7298
# f1-score: 0.8328
#
# Class 1:
# precision: 0.8662
# recall: 0.9871
# f1-score: 0.9227
#
# Class macro avg:
# precision: 0.9180
# recall: 0.8585
# f1-score: 0.8777
#
# Class weighted avg:
# precision: 0.9036
# recall: 0.8943
# f1-score: 0.8903
#
# accuracy: 0.8943
# Average Training Time: 0 minutes and 5.63 seconds
# Average Training Memory Usage: 0.54 MB
# Average Evaluating Time: 0 minutes and 2.84 seconds
# Average Evaluating Memory Usage: 1.08 MB
# Average Total Memory Usage: 1.62 MB
# ---------------------------------------
# Evaluating for som_shape: (25, 25)
#
# Average Metrics Across All Folds:
# ****************************
#
# Sampling Fraction: 0.1
# SOM SHAPE: (25, 25)
#
# Class 0:
# precision: 0.9446
# recall: 0.7469
# f1-score: 0.8341
#
# Class 1:
# precision: 0.8722
# recall: 0.9752
# f1-score: 0.9208
#
# Class macro avg:
# precision: 0.9084
# recall: 0.8611
# f1-score: 0.8775
#
# Class weighted avg:
# precision: 0.8984
# recall: 0.8928
# f1-score: 0.8896
#
# accuracy: 0.8928
# Average Training Time: 0 minutes and 7.61 seconds
# Average Training Memory Usage: 0.72 MB
# Average Evaluating Time: 0 minutes and 3.65 seconds
# Average Evaluating Memory Usage: 1.30 MB
# Average Total Memory Usage: 2.01 MB
# ---------------------------------------
# Evaluating for som_shape: (30, 30)
#
# Average Metrics Across All Folds:
# ****************************
#
# Sampling Fraction: 0.1
# SOM SHAPE: (30, 30)
#
# Class 0:
# precision: 0.9434
# recall: 0.7494
# f1-score: 0.8352
#
# Class 1:
# precision: 0.8732
# recall: 0.9747
# f1-score: 0.9211
#
# Class macro avg:
# precision: 0.9083
# recall: 0.8620
# f1-score: 0.8782
#
# Class weighted avg:
# precision: 0.8986
# recall: 0.8933
# f1-score: 0.8901
#
# accuracy: 0.8933
# Average Training Time: 0 minutes and 10.29 seconds
# Average Training Memory Usage: 0.94 MB
# Average Evaluating Time: 0 minutes and 4.89 seconds
# Average Evaluating Memory Usage: 1.54 MB
# Average Total Memory Usage: 2.48 MB
# ---------------------------------------
# Evaluating for sampling fraction: 0.3
# Evaluating for som_shape: (10, 10)
#
# Average Metrics Across All Folds:
# ****************************
#
# Sampling Fraction: 0.3
# SOM SHAPE: (10, 10)
#
# Class 0:
# precision: 0.9955
# recall: 0.7081
# f1-score: 0.8275
#
# Class 1:
# precision: 0.8582
# recall: 0.9982
# f1-score: 0.9229
#
# Class macro avg:
# precision: 0.9268
# recall: 0.8531
# f1-score: 0.8752
#
# Class weighted avg:
# precision: 0.9078
# recall: 0.8935
# f1-score: 0.8885
#
# accuracy: 0.8935
# Average Training Time: 0 minutes and 8.62 seconds
# Average Training Memory Usage: 0.94 MB
# Average Evaluating Time: 0 minutes and 4.12 seconds
# Average Evaluating Memory Usage: 2.05 MB
# Average Total Memory Usage: 3.00 MB
# ---------------------------------------
# Evaluating for som_shape: (15, 15)
#
# Average Metrics Across All Folds:
# ****************************
#
# Sampling Fraction: 0.3
# SOM SHAPE: (15, 15)
#
# Class 0:
# precision: 0.9961
# recall: 0.7091
# f1-score: 0.8284
#
# Class 1:
# precision: 0.8587
# recall: 0.9984
# f1-score: 0.9233
#
# Class macro avg:
# precision: 0.9274
# recall: 0.8538
# f1-score: 0.8758
#
# Class weighted avg:
# precision: 0.9083
# recall: 0.8940
# f1-score: 0.8890
#
# accuracy: 0.8940
# Average Training Time: 0 minutes and 12.55 seconds
# Average Training Memory Usage: 0.94 MB
# Average Evaluating Time: 0 minutes and 6.02 seconds
# Average Evaluating Memory Usage: 2.20 MB
# Average Total Memory Usage: 3.14 MB
# ---------------------------------------
# Evaluating for som_shape: (20, 20)
#
# Average Metrics Across All Folds:
# ****************************
#
# Sampling Fraction: 0.3
# SOM SHAPE: (20, 20)
#
# Class 0:
# precision: 0.9919
# recall: 0.7136
# f1-score: 0.8301
#
# Class 1:
# precision: 0.8604
# recall: 0.9967
# f1-score: 0.9235
#
# Class macro avg:
# precision: 0.9261
# recall: 0.8552
# f1-score: 0.8768
#
# Class weighted avg:
# precision: 0.9079
# recall: 0.8945
# f1-score: 0.8898
#
# accuracy: 0.8945
# Average Training Time: 0 minutes and 17.26 seconds
# Average Training Memory Usage: 0.94 MB
# Average Evaluating Time: 0 minutes and 8.35 seconds
# Average Evaluating Memory Usage: 2.36 MB
# Average Total Memory Usage: 3.30 MB
# ---------------------------------------
# Evaluating for som_shape: (25, 25)
#
# Average Metrics Across All Folds:
# ****************************
#
# Sampling Fraction: 0.3
# SOM SHAPE: (25, 25)
#
# Class 0:
# precision: 0.9842
# recall: 0.7187
# f1-score: 0.8307
#
# Class 1:
# precision: 0.8621
# recall: 0.9935
# f1-score: 0.9231
#
# Class macro avg:
# precision: 0.9232
# recall: 0.8561
# f1-score: 0.8769
#
# Class weighted avg:
# precision: 0.9062
# recall: 0.8943
# f1-score: 0.8898
#
# accuracy: 0.8943
# Average Training Time: 0 minutes and 24.01 seconds
# Average Training Memory Usage: 1.03 MB
# Average Evaluating Time: 0 minutes and 11.73 seconds
# Average Evaluating Memory Usage: 2.58 MB
# Average Total Memory Usage: 3.61 MB
# ---------------------------------------
# Evaluating for som_shape: (30, 30)
#
# Average Metrics Across All Folds:
# ****************************
#
# Sampling Fraction: 0.3
# SOM SHAPE: (30, 30)
#
# Class 0:
# precision: 0.9704
# recall: 0.7306
# f1-score: 0.8335
#
# Class 1:
# precision: 0.8664
# recall: 0.9874
# f1-score: 0.9229
#
# Class macro avg:
# precision: 0.9184
# recall: 0.8590
# f1-score: 0.8782
#
# Class weighted avg:
# precision: 0.9040
# recall: 0.8946
# f1-score: 0.8907
#
# accuracy: 0.8946
# Average Training Time: 0 minutes and 31.51 seconds
# Average Training Memory Usage: 1.25 MB
# Average Evaluating Time: 0 minutes and 15.61 seconds
# Average Evaluating Memory Usage: 2.85 MB
# Average Total Memory Usage: 4.10 MB
# ---------------------------------------
# Evaluating for sampling fraction: 0.5
# Evaluating for som_shape: (10, 10)
#
# Average Metrics Across All Folds:
# ****************************
#
# Sampling Fraction: 0.5
# SOM SHAPE: (10, 10)
#
# Class 0:
# precision: 0.9970
# recall: 0.7060
# f1-score: 0.8267
#
# Class 1:
# precision: 0.8575
# recall: 0.9988
# f1-score: 0.9228
#
# Class macro avg:
# precision: 0.9272
# recall: 0.8524
# f1-score: 0.8747
#
# Class weighted avg:
# precision: 0.9078
# recall: 0.8931
# f1-score: 0.8881
#
# accuracy: 0.8931
# Average Training Time: 0 minutes and 14.43 seconds
# Average Training Memory Usage: 1.57 MB
# Average Evaluating Time: 0 minutes and 6.79 seconds
# Average Evaluating Memory Usage: 3.32 MB
# Average Total Memory Usage: 4.90 MB
# ---------------------------------------
# Evaluating for som_shape: (15, 15)
#
# Average Metrics Across All Folds:
# ****************************
#
# Sampling Fraction: 0.5
# SOM SHAPE: (15, 15)
#
# Class 0:
# precision: 0.9963
# recall: 0.7071
# f1-score: 0.8271
#
# Class 1:
# precision: 0.8579
# recall: 0.9985
# f1-score: 0.9229
#
# Class macro avg:
# precision: 0.9271
# recall: 0.8528
# f1-score: 0.8750
#
# Class weighted avg:
# precision: 0.9078
# recall: 0.8933
# f1-score: 0.8883
#
# accuracy: 0.8933
# Average Training Time: 0 minutes and 20.18 seconds
# Average Training Memory Usage: 1.57 MB
# Average Evaluating Time: 0 minutes and 9.79 seconds
# Average Evaluating Memory Usage: 3.46 MB
# Average Total Memory Usage: 5.03 MB
# ---------------------------------------
# Evaluating for som_shape: (20, 20)
#
# Average Metrics Across All Folds:
# ****************************
#
# Sampling Fraction: 0.5
# SOM SHAPE: (20, 20)
#
# Class 0:
# precision: 0.9949
# recall: 0.7108
# f1-score: 0.8291
#
# Class 1:
# precision: 0.8593
# recall: 0.9979
# f1-score: 0.9235
#
# Class macro avg:
# precision: 0.9271
# recall: 0.8543
# f1-score: 0.8763
#
# Class weighted avg:
# precision: 0.9083
# recall: 0.8943
# f1-score: 0.8894
#
# accuracy: 0.8943
# Average Training Time: 0 minutes and 29.14 seconds
# Average Training Memory Usage: 1.57 MB
# Average Evaluating Time: 0 minutes and 14.33 seconds
# Average Evaluating Memory Usage: 3.62 MB
# Average Total Memory Usage: 5.19 MB
# ---------------------------------------
# Evaluating for som_shape: (25, 25)
#
# Average Metrics Across All Folds:
# ****************************
#
# Sampling Fraction: 0.5
# SOM SHAPE: (25, 25)
#
# Class 0:
# precision: 0.9873
# recall: 0.7175
# f1-score: 0.8310
#
# Class 1:
# precision: 0.8618
# recall: 0.9948
# f1-score: 0.9235
#
# Class macro avg:
# precision: 0.9246
# recall: 0.8561
# f1-score: 0.8773
#
# Class weighted avg:
# precision: 0.9071
# recall: 0.8947
# f1-score: 0.8902
#
# accuracy: 0.8947
# Average Training Time: 0 minutes and 39.36 seconds
# Average Training Memory Usage: 1.57 MB
# Average Evaluating Time: 0 minutes and 19.25 seconds
# Average Evaluating Memory Usage: 3.85 MB
# Average Total Memory Usage: 5.42 MB
# ---------------------------------------
# Evaluating for som_shape: (30, 30)
#
# Average Metrics Across All Folds:
# ****************************
#
# Sampling Fraction: 0.5
# SOM SHAPE: (30, 30)
#
# Class 0:
# precision: 0.9751
# recall: 0.7286
# f1-score: 0.8340
#
# Class 1:
# precision: 0.8658
# recall: 0.9895
# f1-score: 0.9236
#
# Class macro avg:
# precision: 0.9205
# recall: 0.8590
# f1-score: 0.8788
#
# Class weighted avg:
# precision: 0.9053
# recall: 0.8953
# f1-score: 0.8912
#
# accuracy: 0.8953
# Average Training Time: 0 minutes and 52.47 seconds
# Average Training Memory Usage: 1.57 MB
# Average Evaluating Time: 0 minutes and 25.59 seconds
# Average Evaluating Memory Usage: 4.12 MB
# Average Total Memory Usage: 5.69 MB
# ---------------------------------------
