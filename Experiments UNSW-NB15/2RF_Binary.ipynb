# %%
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier
import numpy as np
import time
import warnings
from joblib import Parallel, delayed
import tracemalloc

# %%
# Funzione per convertire l'uso della memoria in unità appropriate
def format_memory_usage(mem_usage):
    if mem_usage >= 1024 ** 3:
        return f"{mem_usage / (1024 ** 3):.2f} GB"
    else:
        return f"{mem_usage / (1024 ** 2):.2f} MB"

# Funzione per monitorare l'uso della memoria durante una funzione
def monitor_memory_usage(func, *args, **kwargs):
    tracemalloc.start()
    result = func(*args, **kwargs)
    current, peak = tracemalloc.get_traced_memory()
    tracemalloc.stop()
    return result, peak

# Funzione per il training e l'evaluation con monitoraggio della memoria
def train_and_evaluate(train_idx, test_idx, X, y, n_estimators):
    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    model = RandomForestClassifier(n_estimators=n_estimators, random_state=42)

    start_train = time.time()
    _, training_mem_usage = monitor_memory_usage(model.fit, X_train, y_train)
    end_train = time.time()

    start_eval = time.time()
    y_pred, eval_mem_usage = monitor_memory_usage(model.predict, X_test)
    end_eval = time.time()

    report = classification_report(y_test, y_pred, digits=4, output_dict=True, zero_division=0)

    training_time = end_train - start_train
    evaluating_time = end_eval - start_eval
    total_mem_usage = training_mem_usage + eval_mem_usage

    return report, training_time, training_mem_usage, evaluating_time, eval_mem_usage, total_mem_usage

# %%
# Inizializzazione del dataset e dei parametri
DATA_PATH = "/users/mik2002/som/dataset-processed UNSW-NB15/"
DATA_FILE = "dataset-processed-UNSW-NB15.csv"

# Carichiamo il dataset combinato e processato
df_dataset = pd.read_csv(DATA_PATH + DATA_FILE)

# Drop the 'attack_cat' column se ancora presente (può essere già stato rimosso nel dataset processato)
if 'attack_cat' in df_dataset.columns:
    df_dataset = df_dataset.drop(columns=['attack_cat'])

# Display label distribution
print("Distribution:")
display(df_dataset["label"].value_counts())
# Out:
# Distribution:
# label
# 1    164673
# 0     93000
# Name: count, dtype: int64

# %%
# Parametri per la Random Forest
n_estimators = 100
sampling_fractions = [0.1, 0.3, 0.5, 0.7, 1]  # Diversi frazioni di campionamento
results = []

# %%
# Funzione wrapper per il parallelismo
def parallel_train_and_evaluate(train_idx, test_idx, data, target, n_estimators):
    report, training_time, training_mem_usage, evaluating_time, eval_mem_usage, total_mem_usage = train_and_evaluate(train_idx, test_idx, data, target, n_estimators)
    return report, training_time, training_mem_usage, evaluating_time, eval_mem_usage, total_mem_usage

def display_report_and_times(all_reports, all_training_times, all_training_mem_usages, all_evaluating_times, all_eval_mem_usages, all_total_mem_usages):
    print("\nAll Reports and Times for this Model:")
    
    for i, (report, train_time, train_mem_usage, eval_time, eval_mem_usage, total_mem_usage) in enumerate(zip(all_reports, all_training_times, all_training_mem_usages, all_evaluating_times, all_eval_mem_usages, all_total_mem_usages)):
        print(f"\nReport for Fold {i+1}:")
        for label, metrics in report.items():
            if isinstance(metrics, dict):
                print(f"\nLabel {label}:")
                for metric_name, metric_value in metrics.items():
                    print(f"  {metric_name.capitalize()}: {metric_value:.4f}")
            else:
                print(f"\n{label.capitalize()}: {metrics:.4f}")
        print(f"\nTraining Time: {train_time:.4f} seconds")
        print(f"Training Memory Usage: {format_memory_usage(train_mem_usage)}")
        print(f"Evaluating Time: {eval_time:.4f} seconds")
        print(f"Evaluating Memory Usage: {format_memory_usage(eval_mem_usage)}")
        print(f"Total Memory Usage: {format_memory_usage(total_mem_usage)}")

# Inizializzazione del KFold
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# Loop su diverse frazioni di campionamento
for frac in sampling_fractions:
    print(f"Evaluating for sampling fraction: {frac}")
    
    # Esegui campionamento casuale stratificato mantenendo le proporzioni delle classi
    with warnings.catch_warnings():
        warnings.simplefilter("ignore", DeprecationWarning)
        sampled_df = df_dataset.groupby("label", group_keys=False).apply(lambda x: x.sample(frac=frac, random_state=42))

    scaler = MinMaxScaler()
    data = scaler.fit_transform(sampled_df.iloc[:, :-1])
    target = sampled_df.iloc[:, -1].values

    # Split del dataset con K-Fold e parallelismo
    parallel_results = Parallel(n_jobs=-1)(delayed(parallel_train_and_evaluate)(train_idx, test_idx, data, target, n_estimators) for train_idx, test_idx in kf.split(data))
        
    reports, training_times, training_mem_usages, evaluating_times, eval_mem_usages, total_mem_usages = zip(*parallel_results)
        
    # Aggrega metriche dai report
    class_metrics = {}
    for report in reports:
        for key, metrics in report.items():
            if key.isdigit() or key in ['macro avg', 'weighted avg']:
                if key not in class_metrics:
                    class_metrics[key] = {m: [] for m in metrics.keys() if m != 'support'}
                for metric, value in metrics.items():
                    if metric != 'support':
                        class_metrics[key][metric].append(value)

    # Calcola medie e prepara output formattato
    averages = {key: {metric: np.mean(values) for metric, values in metrics.items()} for key, metrics in class_metrics.items()}

    # Calcola i tempi medi di training e valutazione e l'uso della memoria
    avg_training_time = np.mean(training_times)
    avg_training_mem_usage = np.mean(training_mem_usages)
    avg_evaluating_time = np.mean(evaluating_times)
    avg_eval_mem_usage = np.mean(eval_mem_usages)
    avg_total_mem_usage = np.mean(total_mem_usages)

    results.append((frac, averages, avg_training_time, avg_training_mem_usage, avg_evaluating_time, avg_eval_mem_usage, avg_total_mem_usage, reports, training_times, training_mem_usages, evaluating_times, eval_mem_usages, total_mem_usages))

# Mostra i risultati
print("\nAverage Metrics Across All Folds:")
for result in results:
    frac, metrics, avg_training_time, avg_training_mem_usage, avg_evaluating_time, avg_eval_mem_usage, avg_total_mem_usage, all_reports, all_training_times, all_training_mem_usages, all_evaluating_times, all_eval_mem_usages, all_total_mem_usages = result
    print("****************************")
    print(f"\nSampling Fraction: {frac}")
    for class_id, class_metrics in metrics.items():
        print(f"\nClass {class_id}:")
        for metric, value in class_metrics.items():
            print(f"{metric}: {value:.4f}")

    # Mostra i tempi medi di training e valutazione e l'uso della memoria
    minutes_train, seconds_train = divmod(avg_training_time, 60)
    minutes_eval, seconds_eval = divmod(avg_evaluating_time, 60)
    print(f"Average Training Time: {int(minutes_train)} minutes and {seconds_train:.2f} seconds")
    print(f"Average Training Memory Usage: {format_memory_usage(avg_training_mem_usage)}")
    print(f"Average Evaluating Time: {int(minutes_eval)} minutes and {seconds_eval:.2f} seconds")
    print(f"Average Evaluating Memory Usage: {format_memory_usage(avg_eval_mem_usage)}")
    print(f"Average Total Memory Usage: {format_memory_usage(avg_total_mem_usage)}")
    print("---------------------------------------")
    display_report_and_times(all_reports, all_training_times, all_training_mem_usages, all_evaluating_times, all_eval_mem_usages, all_total_mem_usages)
# Out:
# Evaluating for sampling fraction: 0.1
# Evaluating for sampling fraction: 0.3
# Evaluating for sampling fraction: 0.5
# Evaluating for sampling fraction: 0.7
# Evaluating for sampling fraction: 0.9
#
# Average Metrics Across All Folds:
# ****************************
#
# Sampling Fraction: 0.1
#
# Class 0:
# precision: 0.9145
# recall: 0.8895
# f1-score: 0.9018
#
# Class 1:
# precision: 0.9385
# recall: 0.9531
# f1-score: 0.9457
#
# Class macro avg:
# precision: 0.9265
# recall: 0.9213
# f1-score: 0.9238
#
# Class weighted avg:
# precision: 0.9299
# recall: 0.9301
# f1-score: 0.9299
# Average Training Time: 0 minutes and 2.71 seconds
# Average Training Memory Usage: 5.85 MB
# Average Evaluating Time: 0 minutes and 0.05 seconds
# Average Evaluating Memory Usage: 1.21 MB
# Average Total Memory Usage: 7.06 MB
# ---------------------------------------
#
# All Reports and Times for this Model:
#
# Report for Fold 1:
#
# Label 0:
#   Precision: 0.9149
#   Recall: 0.8915
#   F1-score: 0.9031
#   Support: 1881.0000
#
# Label 1:
#   Precision: 0.9386
#   Recall: 0.9523
#   F1-score: 0.9454
#   Support: 3273.0000
#
# Accuracy: 0.9302
#
# Label macro avg:
#   Precision: 0.9267
#   Recall: 0.9219
#   F1-score: 0.9242
#   Support: 5154.0000
#
# Label weighted avg:
#   Precision: 0.9299
#   Recall: 0.9302
#   F1-score: 0.9300
#   Support: 5154.0000
#
# Training Time: 2.7594 seconds
# Training Memory Usage: 5.85 MB
# Evaluating Time: 0.0503 seconds
# Evaluating Memory Usage: 1.21 MB
# Total Memory Usage: 7.06 MB
#
# Report for Fold 2:
#
# Label 0:
#   Precision: 0.9083
#   Recall: 0.8965
#   F1-score: 0.9024
#   Support: 1846.0000
#
# Label 1:
#   Precision: 0.9427
#   Recall: 0.9495
#   F1-score: 0.9461
#   Support: 3308.0000
#
# Accuracy: 0.9305
#
# Label macro avg:
#   Precision: 0.9255
#   Recall: 0.9230
#   F1-score: 0.9242
#   Support: 5154.0000
#
# Label weighted avg:
#   Precision: 0.9304
#   Recall: 0.9305
#   F1-score: 0.9304
#   Support: 5154.0000
#
# Training Time: 2.6988 seconds
# Training Memory Usage: 5.85 MB
# Evaluating Time: 0.0501 seconds
# Evaluating Memory Usage: 1.21 MB
# Total Memory Usage: 7.06 MB
#
# Report for Fold 3:
#
# Label 0:
#   Precision: 0.9200
#   Recall: 0.8844
#   F1-score: 0.9019
#   Support: 1860.0000
#
# Label 1:
#   Precision: 0.9361
#   Recall: 0.9566
#   F1-score: 0.9462
#   Support: 3293.0000
#
# Accuracy: 0.9305
#
# Label macro avg:
#   Precision: 0.9281
#   Recall: 0.9205
#   F1-score: 0.9240
#   Support: 5153.0000
#
# Label weighted avg:
#   Precision: 0.9303
#   Recall: 0.9305
#   F1-score: 0.9302
#   Support: 5153.0000
#
# Training Time: 2.7119 seconds
# Training Memory Usage: 5.85 MB
# Evaluating Time: 0.0498 seconds
# Evaluating Memory Usage: 1.21 MB
# Total Memory Usage: 7.06 MB
#
# Report for Fold 4:
#
# Label 0:
#   Precision: 0.9201
#   Recall: 0.8852
#   F1-score: 0.9023
#   Support: 1899.0000
#
# Label 1:
#   Precision: 0.9345
#   Recall: 0.9551
#   F1-score: 0.9447
#   Support: 3254.0000
#
# Accuracy: 0.9294
#
# Label macro avg:
#   Precision: 0.9273
#   Recall: 0.9202
#   F1-score: 0.9235
#   Support: 5153.0000
#
# Label weighted avg:
#   Precision: 0.9292
#   Recall: 0.9294
#   F1-score: 0.9291
#   Support: 5153.0000
#
# Training Time: 2.6773 seconds
# Training Memory Usage: 5.85 MB
# Evaluating Time: 0.0496 seconds
# Evaluating Memory Usage: 1.21 MB
# Total Memory Usage: 7.06 MB
#
# Report for Fold 5:
#
# Label 0:
#   Precision: 0.9093
#   Recall: 0.8897
#   F1-score: 0.8994
#   Support: 1814.0000
#
# Label 1:
#   Precision: 0.9408
#   Recall: 0.9518
#   F1-score: 0.9463
#   Support: 3339.0000
#
# Accuracy: 0.9299
#
# Label macro avg:
#   Precision: 0.9250
#   Recall: 0.9208
#   F1-score: 0.9228
#   Support: 5153.0000
#
# Label weighted avg:
#   Precision: 0.9297
#   Recall: 0.9299
#   F1-score: 0.9298
#   Support: 5153.0000
#
# Training Time: 2.7083 seconds
# Training Memory Usage: 5.85 MB
# Evaluating Time: 0.0508 seconds
# Evaluating Memory Usage: 1.21 MB
# Total Memory Usage: 7.06 MB
# ****************************
#
# Sampling Fraction: 0.3
#
# Class 0:
# precision: 0.9142
# recall: 0.9023
# f1-score: 0.9082
#
# Class 1:
# precision: 0.9452
# recall: 0.9521
# f1-score: 0.9486
#
# Class macro avg:
# precision: 0.9297
# recall: 0.9272
# f1-score: 0.9284
#
# Class weighted avg:
# precision: 0.9340
# recall: 0.9341
# f1-score: 0.9340
# Average Training Time: 0 minutes and 8.03 seconds
# Average Training Memory Usage: 17.21 MB
# Average Evaluating Time: 0 minutes and 0.14 seconds
# Average Evaluating Memory Usage: 3.61 MB
# Average Total Memory Usage: 20.82 MB
# ---------------------------------------
#
# All Reports and Times for this Model:
#
# Report for Fold 1:
#
# Label 0:
#   Precision: 0.9178
#   Recall: 0.8939
#   F1-score: 0.9057
#   Support: 5495.0000
#
# Label 1:
#   Precision: 0.9423
#   Recall: 0.9558
#   F1-score: 0.9490
#   Support: 9966.0000
#
# Accuracy: 0.9338
#
# Label macro avg:
#   Precision: 0.9301
#   Recall: 0.9249
#   F1-score: 0.9274
#   Support: 15461.0000
#
# Label weighted avg:
#   Precision: 0.9336
#   Recall: 0.9338
#   F1-score: 0.9336
#   Support: 15461.0000
#
# Training Time: 8.1185 seconds
# Training Memory Usage: 17.21 MB
# Evaluating Time: 0.1457 seconds
# Evaluating Memory Usage: 3.61 MB
# Total Memory Usage: 20.82 MB
#
# Report for Fold 2:
#
# Label 0:
#   Precision: 0.9090
#   Recall: 0.9103
#   F1-score: 0.9096
#   Support: 5496.0000
#
# Label 1:
#   Precision: 0.9505
#   Recall: 0.9497
#   F1-score: 0.9501
#   Support: 9965.0000
#
# Accuracy: 0.9357
#
# Label macro avg:
#   Precision: 0.9297
#   Recall: 0.9300
#   F1-score: 0.9299
#   Support: 15461.0000
#
# Label weighted avg:
#   Precision: 0.9357
#   Recall: 0.9357
#   F1-score: 0.9357
#   Support: 15461.0000
#
# Training Time: 7.9469 seconds
# Training Memory Usage: 17.21 MB
# Evaluating Time: 0.1443 seconds
# Evaluating Memory Usage: 3.61 MB
# Total Memory Usage: 20.82 MB
#
# Report for Fold 3:
#
# Label 0:
#   Precision: 0.9176
#   Recall: 0.9055
#   F1-score: 0.9115
#   Support: 5619.0000
#
# Label 1:
#   Precision: 0.9464
#   Recall: 0.9536
#   F1-score: 0.9500
#   Support: 9841.0000
#
# Accuracy: 0.9361
#
# Label macro avg:
#   Precision: 0.9320
#   Recall: 0.9295
#   F1-score: 0.9307
#   Support: 15460.0000
#
# Label weighted avg:
#   Precision: 0.9360
#   Recall: 0.9361
#   F1-score: 0.9360
#   Support: 15460.0000
#
# Training Time: 8.0508 seconds
# Training Memory Usage: 17.21 MB
# Evaluating Time: 0.1388 seconds
# Evaluating Memory Usage: 3.61 MB
# Total Memory Usage: 20.83 MB
#
# Report for Fold 4:
#
# Label 0:
#   Precision: 0.9121
#   Recall: 0.9070
#   F1-score: 0.9095
#   Support: 5559.0000
#
# Label 1:
#   Precision: 0.9479
#   Recall: 0.9509
#   F1-score: 0.9494
#   Support: 9901.0000
#
# Accuracy: 0.9351
#
# Label macro avg:
#   Precision: 0.9300
#   Recall: 0.9290
#   F1-score: 0.9295
#   Support: 15460.0000
#
# Label weighted avg:
#   Precision: 0.9351
#   Recall: 0.9351
#   F1-score: 0.9351
#   Support: 15460.0000
#
# Training Time: 8.1336 seconds
# Training Memory Usage: 17.21 MB
# Evaluating Time: 0.1476 seconds
# Evaluating Memory Usage: 3.61 MB
# Total Memory Usage: 20.83 MB
#
# Report for Fold 5:
#
# Label 0:
#   Precision: 0.9144
#   Recall: 0.8946
#   F1-score: 0.9044
#   Support: 5731.0000
#
# Label 1:
#   Precision: 0.9387
#   Recall: 0.9507
#   F1-score: 0.9446
#   Support: 9729.0000
#
# Accuracy: 0.9299
#
# Label macro avg:
#   Precision: 0.9265
#   Recall: 0.9226
#   F1-score: 0.9245
#   Support: 15460.0000
#
# Label weighted avg:
#   Precision: 0.9297
#   Recall: 0.9299
#   F1-score: 0.9297
#   Support: 15460.0000
#
# Training Time: 7.9015 seconds
# Training Memory Usage: 17.21 MB
# Evaluating Time: 0.1381 seconds
# Evaluating Memory Usage: 3.61 MB
# Total Memory Usage: 20.82 MB
# ****************************
#
# Sampling Fraction: 0.5
#
# Class 0:
# precision: 0.9169
# recall: 0.9057
# f1-score: 0.9113
#
# Class 1:
# precision: 0.9471
# recall: 0.9537
# f1-score: 0.9504
#
# Class macro avg:
# precision: 0.9320
# recall: 0.9297
# f1-score: 0.9308
#
# Class weighted avg:
# precision: 0.9362
# recall: 0.9364
# f1-score: 0.9363
# Average Training Time: 0 minutes and 13.95 seconds
# Average Training Memory Usage: 28.58 MB
# Average Evaluating Time: 0 minutes and 0.24 seconds
# Average Evaluating Memory Usage: 6.01 MB
# Average Total Memory Usage: 34.59 MB
# ---------------------------------------
#
# All Reports and Times for this Model:
#
# Report for Fold 1:
#
# Label 0:
#   Precision: 0.9250
#   Recall: 0.9065
#   F1-score: 0.9157
#   Support: 9413.0000
#
# Label 1:
#   Precision: 0.9468
#   Recall: 0.9577
#   F1-score: 0.9522
#   Support: 16355.0000
#
# Accuracy: 0.9390
#
# Label macro avg:
#   Precision: 0.9359
#   Recall: 0.9321
#   F1-score: 0.9339
#   Support: 25768.0000
#
# Label weighted avg:
#   Precision: 0.9388
#   Recall: 0.9390
#   F1-score: 0.9389
#   Support: 25768.0000
#
# Training Time: 13.9504 seconds
# Training Memory Usage: 28.58 MB
# Evaluating Time: 0.2349 seconds
# Evaluating Memory Usage: 6.01 MB
# Total Memory Usage: 34.59 MB
#
# Report for Fold 2:
#
# Label 0:
#   Precision: 0.9153
#   Recall: 0.9120
#   F1-score: 0.9136
#   Support: 9203.0000
#
# Label 1:
#   Precision: 0.9512
#   Recall: 0.9531
#   F1-score: 0.9521
#   Support: 16564.0000
#
# Accuracy: 0.9384
#
# Label macro avg:
#   Precision: 0.9332
#   Recall: 0.9325
#   F1-score: 0.9329
#   Support: 25767.0000
#
# Label weighted avg:
#   Precision: 0.9384
#   Recall: 0.9384
#   F1-score: 0.9384
#   Support: 25767.0000
#
# Training Time: 13.8283 seconds
# Training Memory Usage: 28.58 MB
# Evaluating Time: 0.2340 seconds
# Evaluating Memory Usage: 6.01 MB
# Total Memory Usage: 34.59 MB
#
# Report for Fold 3:
#
# Label 0:
#   Precision: 0.9197
#   Recall: 0.8997
#   F1-score: 0.9096
#   Support: 9373.0000
#
# Label 1:
#   Precision: 0.9434
#   Recall: 0.9551
#   F1-score: 0.9492
#   Support: 16394.0000
#
# Accuracy: 0.9350
#
# Label macro avg:
#   Precision: 0.9315
#   Recall: 0.9274
#   F1-score: 0.9294
#   Support: 25767.0000
#
# Label weighted avg:
#   Precision: 0.9348
#   Recall: 0.9350
#   F1-score: 0.9348
#   Support: 25767.0000
#
# Training Time: 13.9135 seconds
# Training Memory Usage: 28.58 MB
# Evaluating Time: 0.2387 seconds
# Evaluating Memory Usage: 6.01 MB
# Total Memory Usage: 34.59 MB
#
# Report for Fold 4:
#
# Label 0:
#   Precision: 0.9096
#   Recall: 0.9033
#   F1-score: 0.9065
#   Support: 9146.0000
#
# Label 1:
#   Precision: 0.9470
#   Recall: 0.9506
#   F1-score: 0.9488
#   Support: 16621.0000
#
# Accuracy: 0.9338
#
# Label macro avg:
#   Precision: 0.9283
#   Recall: 0.9270
#   F1-score: 0.9276
#   Support: 25767.0000
#
# Label weighted avg:
#   Precision: 0.9337
#   Recall: 0.9338
#   F1-score: 0.9338
#   Support: 25767.0000
#
# Training Time: 13.9377 seconds
# Training Memory Usage: 28.58 MB
# Evaluating Time: 0.2386 seconds
# Evaluating Memory Usage: 6.01 MB
# Total Memory Usage: 34.59 MB
#
# Report for Fold 5:
#
# Label 0:
#   Precision: 0.9150
#   Recall: 0.9070
#   F1-score: 0.9110
#   Support: 9365.0000
#
# Label 1:
#   Precision: 0.9472
#   Recall: 0.9519
#   F1-score: 0.9495
#   Support: 16402.0000
#
# Accuracy: 0.9356
#
# Label macro avg:
#   Precision: 0.9311
#   Recall: 0.9294
#   F1-score: 0.9303
#   Support: 25767.0000
#
# Label weighted avg:
#   Precision: 0.9355
#   Recall: 0.9356
#   F1-score: 0.9355
#   Support: 25767.0000
#
# Training Time: 14.1172 seconds
# Training Memory Usage: 28.58 MB
# Evaluating Time: 0.2389 seconds
# Evaluating Memory Usage: 6.01 MB
# Total Memory Usage: 34.59 MB
# ****************************
#
# Sampling Fraction: 0.7
#
# Class 0:
# precision: 0.9197
# recall: 0.9103
# f1-score: 0.9150
#
# Class 1:
# precision: 0.9497
# recall: 0.9551
# f1-score: 0.9524
#
# Class macro avg:
# precision: 0.9347
# recall: 0.9327
# f1-score: 0.9337
#
# Class weighted avg:
# precision: 0.9388
# recall: 0.9390
# f1-score: 0.9389
# Average Training Time: 0 minutes and 20.68 seconds
# Average Training Memory Usage: 39.94 MB
# Average Evaluating Time: 0 minutes and 0.35 seconds
# Average Evaluating Memory Usage: 8.41 MB
# Average Total Memory Usage: 48.35 MB
# ---------------------------------------
#
# All Reports and Times for this Model:
#
# Report for Fold 1:
#
# Label 0:
#   Precision: 0.9192
#   Recall: 0.9131
#   F1-score: 0.9162
#   Support: 12940.0000
#
# Label 1:
#   Precision: 0.9516
#   Recall: 0.9551
#   F1-score: 0.9534
#   Support: 23135.0000
#
# Accuracy: 0.9401
#
# Label macro avg:
#   Precision: 0.9354
#   Recall: 0.9341
#   F1-score: 0.9348
#   Support: 36075.0000
#
# Label weighted avg:
#   Precision: 0.9400
#   Recall: 0.9401
#   F1-score: 0.9400
#   Support: 36075.0000
#
# Training Time: 21.2200 seconds
# Training Memory Usage: 39.94 MB
# Evaluating Time: 0.3403 seconds
# Evaluating Memory Usage: 8.41 MB
# Total Memory Usage: 48.35 MB
#
# Report for Fold 2:
#
# Label 0:
#   Precision: 0.9204
#   Recall: 0.9146
#   F1-score: 0.9175
#   Support: 13011.0000
#
# Label 1:
#   Precision: 0.9520
#   Recall: 0.9554
#   F1-score: 0.9537
#   Support: 23063.0000
#
# Accuracy: 0.9407
#
# Label macro avg:
#   Precision: 0.9362
#   Recall: 0.9350
#   F1-score: 0.9356
#   Support: 36074.0000
#
# Label weighted avg:
#   Precision: 0.9406
#   Recall: 0.9407
#   F1-score: 0.9406
#   Support: 36074.0000
#
# Training Time: 20.1492 seconds
# Training Memory Usage: 39.94 MB
# Evaluating Time: 0.3446 seconds
# Evaluating Memory Usage: 8.41 MB
# Total Memory Usage: 48.35 MB
#
# Report for Fold 3:
#
# Label 0:
#   Precision: 0.9183
#   Recall: 0.9108
#   F1-score: 0.9145
#   Support: 13078.0000
#
# Label 1:
#   Precision: 0.9495
#   Recall: 0.9539
#   F1-score: 0.9517
#   Support: 22996.0000
#
# Accuracy: 0.9383
#
# Label macro avg:
#   Precision: 0.9339
#   Recall: 0.9324
#   F1-score: 0.9331
#   Support: 36074.0000
#
# Label weighted avg:
#   Precision: 0.9382
#   Recall: 0.9383
#   F1-score: 0.9382
#   Support: 36074.0000
#
# Training Time: 20.9243 seconds
# Training Memory Usage: 39.94 MB
# Evaluating Time: 0.3524 seconds
# Evaluating Memory Usage: 8.41 MB
# Total Memory Usage: 48.35 MB
#
# Report for Fold 4:
#
# Label 0:
#   Precision: 0.9224
#   Recall: 0.9066
#   F1-score: 0.9144
#   Support: 13139.0000
#
# Label 1:
#   Precision: 0.9470
#   Recall: 0.9563
#   F1-score: 0.9516
#   Support: 22935.0000
#
# Accuracy: 0.9382
#
# Label macro avg:
#   Precision: 0.9347
#   Recall: 0.9315
#   F1-score: 0.9330
#   Support: 36074.0000
#
# Label weighted avg:
#   Precision: 0.9381
#   Recall: 0.9382
#   F1-score: 0.9381
#   Support: 36074.0000
#
# Training Time: 20.3371 seconds
# Training Memory Usage: 39.94 MB
# Evaluating Time: 0.3491 seconds
# Evaluating Memory Usage: 8.41 MB
# Total Memory Usage: 48.35 MB
#
# Report for Fold 5:
#
# Label 0:
#   Precision: 0.9182
#   Recall: 0.9065
#   F1-score: 0.9123
#   Support: 12932.0000
#
# Label 1:
#   Precision: 0.9481
#   Recall: 0.9548
#   F1-score: 0.9515
#   Support: 23142.0000
#
# Accuracy: 0.9375
#
# Label macro avg:
#   Precision: 0.9331
#   Recall: 0.9307
#   F1-score: 0.9319
#   Support: 36074.0000
#
# Label weighted avg:
#   Precision: 0.9374
#   Recall: 0.9375
#   F1-score: 0.9374
#   Support: 36074.0000
#
# Training Time: 20.7449 seconds
# Training Memory Usage: 39.94 MB
# Evaluating Time: 0.3522 seconds
# Evaluating Memory Usage: 8.41 MB
# Total Memory Usage: 48.35 MB
# ****************************
#
# Sampling Fraction: 0.9
#
# Class 0:
# precision: 0.9220
# recall: 0.9130
# f1-score: 0.9175
#
# Class 1:
# precision: 0.9511
# recall: 0.9564
# f1-score: 0.9538
#
# Class macro avg:
# precision: 0.9366
# recall: 0.9347
# f1-score: 0.9356
#
# Class weighted avg:
# precision: 0.9406
# recall: 0.9407
# f1-score: 0.9407
# Average Training Time: 0 minutes and 27.86 seconds
# Average Training Memory Usage: 51.30 MB
# Average Evaluating Time: 0 minutes and 0.48 seconds
# Average Evaluating Memory Usage: 10.81 MB
# Average Total Memory Usage: 62.11 MB
# ---------------------------------------
#
# All Reports and Times for this Model:
#
# Report for Fold 1:
#
# Label 0:
#   Precision: 0.9215
#   Recall: 0.9134
#   F1-score: 0.9174
#   Support: 16569.0000
#
# Label 1:
#   Precision: 0.9521
#   Recall: 0.9568
#   F1-score: 0.9544
#   Support: 29813.0000
#
# Accuracy: 0.9413
#
# Label macro avg:
#   Precision: 0.9368
#   Recall: 0.9351
#   F1-score: 0.9359
#   Support: 46382.0000
#
# Label weighted avg:
#   Precision: 0.9412
#   Recall: 0.9413
#   F1-score: 0.9412
#   Support: 46382.0000
#
# Training Time: 27.5440 seconds
# Training Memory Usage: 51.30 MB
# Evaluating Time: 0.4503 seconds
# Evaluating Memory Usage: 10.81 MB
# Total Memory Usage: 62.11 MB
#
# Report for Fold 2:
#
# Label 0:
#   Precision: 0.9228
#   Recall: 0.9124
#   F1-score: 0.9176
#   Support: 16680.0000
#
# Label 1:
#   Precision: 0.9511
#   Recall: 0.9571
#   F1-score: 0.9541
#   Support: 29701.0000
#
# Accuracy: 0.9410
#
# Label macro avg:
#   Precision: 0.9369
#   Recall: 0.9348
#   F1-score: 0.9358
#   Support: 46381.0000
#
# Label weighted avg:
#   Precision: 0.9409
#   Recall: 0.9410
#   F1-score: 0.9410
#   Support: 46381.0000
#
# Training Time: 28.2137 seconds
# Training Memory Usage: 51.30 MB
# Evaluating Time: 0.4898 seconds
# Evaluating Memory Usage: 10.81 MB
# Total Memory Usage: 62.11 MB
#
# Report for Fold 3:
#
# Label 0:
#   Precision: 0.9203
#   Recall: 0.9204
#   F1-score: 0.9204
#   Support: 16827.0000
#
# Label 1:
#   Precision: 0.9547
#   Recall: 0.9546
#   F1-score: 0.9547
#   Support: 29554.0000
#
# Accuracy: 0.9422
#
# Label macro avg:
#   Precision: 0.9375
#   Recall: 0.9375
#   F1-score: 0.9375
#   Support: 46381.0000
#
# Label weighted avg:
#   Precision: 0.9422
#   Recall: 0.9422
#   F1-score: 0.9422
#   Support: 46381.0000
#
# Training Time: 28.2891 seconds
# Training Memory Usage: 51.30 MB
# Evaluating Time: 0.4910 seconds
# Evaluating Memory Usage: 10.81 MB
# Total Memory Usage: 62.11 MB
#
# Report for Fold 4:
#
# Label 0:
#   Precision: 0.9244
#   Recall: 0.9100
#   F1-score: 0.9172
#   Support: 16898.0000
#
# Label 1:
#   Precision: 0.9489
#   Recall: 0.9574
#   F1-score: 0.9531
#   Support: 29483.0000
#
# Accuracy: 0.9401
#
# Label macro avg:
#   Precision: 0.9367
#   Recall: 0.9337
#   F1-score: 0.9352
#   Support: 46381.0000
#
# Label weighted avg:
#   Precision: 0.9400
#   Recall: 0.9401
#   F1-score: 0.9400
#   Support: 46381.0000
#
# Training Time: 26.9901 seconds
# Training Memory Usage: 51.30 MB
# Evaluating Time: 0.4622 seconds
# Evaluating Memory Usage: 10.81 MB
# Total Memory Usage: 62.11 MB
#
# Report for Fold 5:
#
# Label 0:
#   Precision: 0.9212
#   Recall: 0.9088
#   F1-score: 0.9149
#   Support: 16726.0000
#
# Label 1:
#   Precision: 0.9489
#   Recall: 0.9561
#   F1-score: 0.9525
#   Support: 29655.0000
#
# Accuracy: 0.9390
#
# Label macro avg:
#   Precision: 0.9350
#   Recall: 0.9324
#   F1-score: 0.9337
#   Support: 46381.0000
#
# Label weighted avg:
#   Precision: 0.9389
#   Recall: 0.9390
#   F1-score: 0.9390
#   Support: 46381.0000
#
# Training Time: 28.2567 seconds
# Training Memory Usage: 51.30 MB
# Evaluating Time: 0.4976 seconds
# Evaluating Memory Usage: 10.81 MB
# Total Memory Usage: 62.11 MB
